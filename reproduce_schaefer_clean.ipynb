# %%
import lfox
import lfox.lattice as lat
import lfox.evolution.hmc as lhmc
import jax
import jax.numpy as jnp
import numpy as np

# Imports below require "dev" environment
import matplotlib.pyplot as plt
import lsqfit
import gvar as gv
import tqdm

# Double precision!
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_threefry_partitionable", True)

# %%
class ScalarAction(lhmc.Action):        

    @staticmethod
    @jax.jit
    def _S(fields, params):
        phi = fields[0]
        S = phi**2
        
        for ax in range(phi.d()):
            S -= 2 * params['kappa'] * phi * phi.nn_field(ax)

        S += params['lambda'] * (phi**2 - 1)**2
        return S
    
    # Exact force function instead of autodiff, for testing purposes
    @staticmethod
    @jax.jit
    def exact_force(fields, params):
        phi = fields[0]

        J = phi.nn_field(axis=0, shift=1) + phi.nn_field(axis=0, shift=-1)
        for ax in range(1,phi.d):
            J += phi.nn_field(axis=ax, shift=1)
            J += phi.nn_field(axis=ax, shift=-1)

        F = -2 * params['kappa'] * J
        F += 2 * phi.F
        F += 4 * params['lambda'] * (phi.F**2 - 1) * phi.F

        return F

# %%
# %%time

# First test case: exercise 2.5
d = 3
Lat4 = lat.SquareLattice(st_dims=((4,)*d))
phi4 = lat.LatticeField(lattice=Lat4, F=1)

S4 = ScalarAction(field_names=['phi'], params={'kappa': 0.18169, 'lambda': 1.3282})

all_Nstep = np.array([10, 20, 30, 40, 50])
all_eps = 1/all_Nstep

all_dH_leap = []
all_dH_om = []

rng_key = jax.random.PRNGKey(48119)

for eps, Nstep in zip(all_eps, all_Nstep):
    HMC_leap = lhmc.HMCRewrite(
        action=S4,
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )
    HMC_om = lhmc.HMCRewrite(
        action=S4,
        integrator=lhmc.OmelyanIntegrator(eps=eps, Nstep=Nstep),
    )

    F4 = {'phi': phi4}
    F4, monitor_leap, rng_key = HMC_leap.evolve_many(F4, rng_key, traj=50, warmup=True)

    F4 = {'phi': phi4}
    F4, monitor_om, rng_key = HMC_om.evolve_many(F4, rng_key, traj=50, warmup=True)

    abs_dH_leap = np.abs(np.array(monitor_leap['delta_H']))
    abs_dH_om = np.abs(np.array(monitor_om['delta_H']))

    all_dH_leap.append(gv.dataset.avg_data(abs_dH_leap))
    all_dH_om.append(gv.dataset.avg_data(abs_dH_om))
# Out:
# CPU times: user 26.7 ms, sys: 1.92 ms, total: 28.6 ms
# Wall time: 27 ms

# %%
#Figure 2.2
plt.plot(all_eps**2, gv.mean(all_dH_leap), ls=' ', marker='s', color='red', label='Leapfrog')
plt.plot(all_eps**2, gv.mean(all_dH_om), ls=' ', marker='*', color='forestgreen', label='Omelyan')

def lin(x,p):
    return p['a'] + p['b']*x

fit_leap = lsqfit.nonlinear_fit(data=(all_eps**2, all_dH_leap), prior={'a': gv.gvar(0,100), 'b': gv.gvar(0,500)}, fcn=lin)
print(fit_leap)

eps_ls = np.linspace(0,0.1,100)
plt.plot(eps_ls**2, gv.mean(lin(eps_ls**2,fit_leap.p)), ls='--', color='red')

fit_om = lsqfit.nonlinear_fit(data=(all_eps**2, all_dH_om), prior={'a': gv.gvar(0,100), 'b': gv.gvar(0,500)}, fcn=lin)
print(fit_om)

plt.plot(eps_ls**2, gv.mean(lin(eps_ls**2,fit_om.p)), ls='-.', color='green')

plt.xlabel('$\epsilon^2$')
plt.ylabel('$|\Delta H|$')
plt.legend()
# Out:
# Least Square Fit:
#   chi2/dof [dof] = 1.4 [5]    Q = 0.2    logGBF = 3.8548
#
# Parameters:
#               a   0.00106 (85)      [    0 (100) ]
#               b     13.3 (1.1)      [    0 (500) ]
#
# Settings:
#   svdcut/n = 1e-12/0    tol = (1e-08*,1e-10,1e-10)    (itns/time = 3/0.0)
#   fitter = scipy_least_squares    method = trf
#
# Least Square Fit:
#   chi2/dof [dof] = 1.2 [5]    Q = 0.31    logGBF = 10.844
#
# Parameters:
#               a   -5(104)e-06     [    0 (100) ]
#               b     1.74 (14)     [    0 (500) ]
#
# Settings:
#   svdcut/n = 1e-12/0    tol = (1e-08*,1e-10,1e-10)    (itns/time = 3/0.0)
#   fitter = scipy_least_squares    method = trf

# %% [markdown]
# Another technical plot first: let's do figure 2.4.

# %%
# %%time

# First test case: exercise 2.5
d = 3
Lat6 = lat.SquareLattice(st_dims=((6,)*d))
phi6 = lat.LatticeField(lattice=Lat6, F=1)

S6 = ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689})

all_Nstep = np.array([4, 5, 7, 8, 10, 20, 30, 40, 50])
all_eps = 1/all_Nstep

all_acc_rate = []
rng_key = jax.random.PRNGKey(11134)

for eps, Nstep in zip(all_eps, all_Nstep):
    F6 = {'phi': phi6}
    HMC = lhmc.HMCRewrite(
        action=S6,
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )

#    acc_rate = []
    F6, mon, rng_key = HMC.evolve_many(F6, rng_key, traj=1000, warmup=False)
    all_acc_rate.append(np.mean(mon['accept']))
#    for _ in range(1000):
#        F6, mon, rng_key = HMC.evolve(F6, rng_key, warmup=False)
#        acc_rate.append(mon['accept'])

#    all_acc_rate.append(np.mean(np.array(acc_rate)))
# Out:
# CPU times: user 1.75 s, sys: 118 ms, total: 1.87 s
# Wall time: 1.74 s

# %%
plt.plot(all_eps**2, all_acc_rate, ls=' ', marker='o')

plt.xlabel('$\epsilon^2$')
plt.ylabel('acc rate')
# Out:
# Text(0, 0.5, 'acc rate')

# %%
plt.plot(all_eps**2, 1/all_eps/all_acc_rate, ls=' ', marker='x')
plt.xlabel('$\epsilon^2$')
plt.ylabel('$1/\epsilon/$ acc rate [cost]')
# Out:
# Text(0, 0.5, '$1/\\epsilon/$ acc rate [cost]')

# %% [markdown]
# Some additional technical tests.  Let's verify that $e^{-\Delta H}$ averages to 1 properly.

# %%
# %%time
HMC = lhmc.HMCRewrite(
    action=ScalarAction(field_names=['phi'], params={'kappa': 0.18, 'lambda': 1.145}),
    integrator=lhmc.LeapfrogIntegrator(eps=0.1, Nstep=10),
)

Ftest = {'phi': phi6}
rng_key = jax.random.PRNGKey(21245)
dH_array = []
for _ in range(10000):
    Ftest, mon, rng_key = HMC.evolve(Ftest, rng_key, warmup=False)
    dH_array.append(mon['delta_H'])
# Out:
# CPU times: user 761 ms, sys: 7.49 ms, total: 768 ms
# Wall time: 772 ms

# %%
edH = np.exp(-np.array(dH_array))
plt.plot(edH[10:])
gv.dataset.avg_data(edH[100::50])  # Block by 50, should be consistent with 1
# Out:
# 1.011(23)

# %% [markdown]
# Now on to figure 2.3 and comparing HMC to MD.

# %%
@jax.jit
def mag(phi):
    m = jnp.sum(phi.F)
    return jnp.array([m, m**2, m**4])

def mag_obs(fields, params):
    return mag(fields['phi'])

# %%
# %%prun -s cumulative

# Second test case: figure 2.3
d = 3
Lat6 = lat.SquareLattice(st_dims=((6,)*d))
phi6 = lat.LatticeField(lattice=Lat6, F=1)

all_Nstep = np.array([4,5,6,7,8,10])
all_eps = 1/all_Nstep
m2_HMC = []
m2_HMD = []

raw_HMC = []
mon_HMC = []

rng_key = jax.random.PRNGKey(73645)
F6_HMC = {'phi': phi6}
F6_HMD = {'phi': phi6}

for eps, Nstep in zip(all_eps, all_Nstep):
    print(eps, Nstep)

    raw_m2_HMC = []
    raw_m2_HMD = []

    # Only need one HMC object, HMD is the same thing but with warmups off
    HMC = lhmc.HMCRewrite(
        action=ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689}),
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )
        
    for t in range(1000):
        F6_HMC, _, rng_key = HMC.evolve_many(F6_HMC, rng_key, traj=100, warmup=False)
        F6_HMD, _, rng_key = HMC.evolve_many(F6_HMD, rng_key, traj=100, warmup=True)

        raw_m2_HMC.append(mag(F6_HMC['phi'])[1]/6**d)
        raw_m2_HMD.append(mag(F6_HMD['phi'])[1]/6**d)
    
    m2_HMC.append(gv.dataset.avg_data(raw_m2_HMC))
    m2_HMD.append(gv.dataset.avg_data(raw_m2_HMD))
# Out:
# 0.25 4
# 0.2 5
# 0.16666666666666666 6
# 0.14285714285714285 7
# 0.125 8
# 0.1 10
#          7266272 function calls (7249878 primitive calls) in 63.379 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001   63.518   63.518 {built-in method builtins.exec}
#         1   58.008   58.008   63.517   63.517 <string>:1(<module>)
# 24578/24117    0.028    0.000    3.712    0.000 core.py:388(bind_with_trace)
#     24016    0.022    0.000    3.585    0.000 core.py:820(process_primitive)
# 12133/12022    0.022    0.000    2.369    0.000 profiler.py:311(wrapper)
#     12000    0.029    0.000    2.318    0.000 array.py:297(__getitem__)
#     117/4    0.000    0.000    2.267    0.567 traceback_util.py:173(reraise_with_filtered_traceback)
#      91/4    0.000    0.000    2.267    0.567 pjit.py:253(cache_miss)
#      91/4    0.000    0.000    2.267    0.567 pjit.py:160(_python_pjit_helper)
#     12000    0.012    0.000    2.256    0.000 lax_numpy.py:4267(_rewriting_take)
#     12000    0.195    0.000    2.244    0.000 lax_numpy.py:4195(_attempt_rewriting_take_via_slice)
#    110/48    0.000    0.000    2.221    0.046 core.py:2598(bind)
#         4    0.000    0.000    2.209    0.552 pjit.py:1194(_pjit_call_impl)
#         4    0.000    0.000    2.209    0.552 pjit.py:1197(call_impl_cache_miss)
#         4    0.000    0.000    2.209    0.552 pjit.py:1122(_pjit_call_impl_python)
# 24468/24466    0.028    0.000    1.762    0.000 core.py:383(bind)
#         6    0.000    0.000    1.385    0.231 pxla.py:2261(compile)
#         6    0.001    0.000    1.385    0.231 pxla.py:2566(from_hlo)
#         6    0.000    0.000    1.383    0.231 pxla.py:2455(_cached_compilation)
#         6    0.000    0.000    1.377    0.230 compiler.py:266(compile_or_get_cached)
#         6    0.000    0.000    1.377    0.229 compiler.py:228(backend_compile)
#         6    1.373    0.229    1.373    0.229 {built-in method jaxlib.xla_extension.compile}
#     24010    0.088    0.000    1.298    0.000 dispatch.py:113(apply_primitive)
#     12008    0.012    0.000    1.027    0.000 slicing.py:54(slice)
#     12000    0.045    0.000    0.857    0.000 slicing.py:1159(_slice_impl)
#         4    0.000    0.000    0.828    0.207 pjit.py:1254(_pjit_lower)
#         4    0.000    0.000    0.827    0.207 pjit.py:1265(_pjit_lower_cached)
#         6    0.000    0.000    0.826    0.138 pxla.py:1948(lower_sharding_computation)
#         6    0.001    0.000    0.787    0.131 pxla.py:1773(_cached_lowering_to_hlo)
#         6    0.000    0.000    0.786    0.131 mlir.py:663(lower_jaxpr_to_module)
#     390/6    0.019    0.000    0.776    0.129 mlir.py:899(lower_jaxpr_to_fun)
#     478/6    0.055    0.000    0.773    0.129 mlir.py:1248(jaxpr_subcomp)
#      58/4    0.000    0.000    0.770    0.192 mlir.py:1379(f_lowered)
#      10/2    0.001    0.000    0.755    0.377 loops.py:1579(_while_lowering)
#     384/2    0.008    0.000    0.746    0.373 pjit.py:1369(_pjit_lowering)
#     12008    0.034    0.000    0.728    0.000 lax.py:1315(squeeze)
#     60135    0.338    0.000    0.596    0.000 _module.py:687(_flatten_module)
#     24016    0.093    0.000    0.588    0.000 util.py:258(wrapper)
#     24010    0.016    0.000    0.327    0.000 dispatch.py:118(<listcomp>)
#     36007    0.073    0.000    0.311    0.000 dispatch.py:86(_arg_spec)
#     24390    0.094    0.000    0.293    0.000 config.py:479(_trace_context)
#     47398    0.029    0.000    0.260    0.000 {jaxlib.utils.safe_map}
#    233101    0.187    0.000    0.236    0.000 config.py:269(get_state)
#     83/62    0.000    0.000    0.206    0.003 partial_eval.py:2193(trace_to_jaxpr_dynamic)
#     85/64    0.001    0.000    0.204    0.003 partial_eval.py:2209(trace_to_subjaxpr_dynamic)
#     85/64    0.000    0.000    0.191    0.003 linear_util.py:176(call_wrapped)
#     37009    0.032    0.000    0.186    0.000 xla.py:169(abstractify)
#     24010    0.185    0.000    0.185    0.000 dispatch.py:164(<lambda>)
# 561561/561559    0.096    0.000    0.169    0.000 {built-in method builtins.isinstance}
#     19/18    0.000    0.000    0.146    0.008 common.py:62(_initial_style_jaxpr)
#     19/18    0.000    0.000    0.145    0.008 common.py:53(_initial_style_open_jaxpr)
#     12128    0.014    0.000    0.143    0.000 xla.py:180(_make_abstract_python_scalar)
#     60282    0.084    0.000    0.141    0.000 dataclasses.py:1233(fields)
#     12066    0.096    0.000    0.140    0.000 array_methods.py:251(deferring_binary_op)
#     12422    0.027    0.000    0.133    0.000 dtypes.py:251(_scalar_type_to_dtype)
#     24578    0.041    0.000    0.126    0.000 core.py:1237(find_top_trace)
#         3    0.000    0.000    0.117    0.039 prng.py:746(random_split_lowering)
#         3    0.000    0.000    0.117    0.039 mlir.py:104(delegate_lowering)
#         9    0.000    0.000    0.117    0.013 loops.py:1138(while_loop)
#         8    0.000    0.000    0.114    0.014 loops.py:411(_scan_impl)
#         8    0.000    0.000    0.114    0.014 loops.py:357(_scan_impl_loop)
# 65065/64993    0.037    0.000    0.112    0.000 {built-in method builtins.all}
#     25366    0.023    0.000    0.111    0.000 core.py:479(full_raise)
#         9    0.000    0.000    0.108    0.012 loops.py:1204(_create_jaxpr)
#     12000    0.004    0.000    0.107    0.000 array.py:264(__float__)
#      2708    0.017    0.000    0.103    0.000 mlir.py:345(_source_info_to_location)
#     28918    0.019    0.000    0.103    0.000 dtypes.py:214(canonicalize_dtype)
#        79    0.002    0.000    0.097    0.001 core.py:436(eval_jaxpr)
#         8    0.000    0.000    0.090    0.011 loops.py:365(body_fun)
#         8    0.000    0.000    0.086    0.011 core.py:233(jaxpr_as_fun)
#     12024    0.026    0.000    0.082    0.000 array.py:555(_value)
#     24008    0.025    0.000    0.076    0.000 dispatch.py:106(__eq__)
#    129830    0.035    0.000    0.073    0.000 <frozen abc>:117(__instancecheck__)
#     16001    0.016    0.000    0.070    0.000 core.py:1537(__init__)
#     60052    0.040    0.000    0.070    0.000 <string>:2(__eq__)
#         3    0.000    0.000    0.067    0.022 prng.py:833(random_bits_lowering)
#      1219    0.003    0.000    0.066    0.000 lax.py:1689(_nary_lower_hlo)
#     91/50    0.000    0.000    0.066    0.001 api.py:317(infer_params)
#     91/50    0.002    0.000    0.066    0.001 pjit.py:394(common_infer_params)
#      1561    0.006    0.000    0.063    0.000 mlir.py:1506(multi_broadcast_in_dim)
#      6488    0.006    0.000    0.062    0.000 mlir.py:1262(read)
#     27238    0.021    0.000    0.061    0.000 dtypes.py:324(issubdtype)
#       234    0.000    0.000    0.059    0.000 core.py:1370(concrete_aval)
#       409    0.000    0.000    0.059    0.000 core.py:1380(get_aval)
#       144    0.000    0.000    0.058    0.000 partial_eval.py:1836(new_const)
#       160    0.000    0.000    0.058    0.000 abstract_arrays.py:78(_make_concrete_python_scalar)
#     72823    0.043    0.000    0.057    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#     93/52    0.000    0.000    0.057    0.001 linear_util.py:334(memoized_fun)
#    849567    0.057    0.000    0.057    0.000 {method 'append' of 'list' objects}
#     91/50    0.000    0.000    0.057    0.001 pjit.py:963(_pjit_jaxpr)
# 491624/491297    0.054    0.000    0.055    0.000 {built-in method builtins.getattr}
# 1090/1066    0.002    0.000    0.054    0.000 mlir.py:218(ir_constants)
#       6/4    0.000    0.000    0.054    0.014 pjit.py:908(_create_pjit_jaxpr)
#     73194    0.037    0.000    0.054    0.000 config.py:306(get_state)
#     24014    0.012    0.000    0.051    0.000 tree_util.py:110(tree_structure)
#      1066    0.007    0.000    0.051    0.000 mlir.py:262(_ndarray_constant_handler)
#    357910    0.050    0.000    0.050    0.000 config.py:111(_read)
#         2    0.000    0.000    0.050    0.025 hmc.py:431(evolve_many)
# 25130/25126    0.017    0.000    0.049    0.000 {built-in method builtins.max}
#       9/8    0.000    0.000    0.049    0.006 loops.py:1841(fori_loop)
#     49003    0.019    0.000    0.049    0.000 {built-in method builtins.any}
#         8    0.000    0.000    0.048    0.006 loops.py:102(scan)
#     14009    0.019    0.000    0.046    0.000 dtypes.py:579(dtype)
#     12015    0.007    0.000    0.046    0.000 lax_numpy.py:123(_dtype)
# 12780/12604    0.004    0.000    0.044    0.000 {built-in method builtins.next}
#      3625    0.002    0.000    0.044    0.000 mlir.py:175(aval_to_ir_types)
#     12051    0.041    0.000    0.043    0.000 _module.py:732(_unflatten_module)
#     16001    0.011    0.000    0.043    0.000 core.py:1463(_dtype_object)
#      1030    0.005    0.000    0.043    0.000 mlir.py:1478(broadcast_in_dim)
#    241111    0.043    0.000    0.043    0.000 dataclasses.py:1248(<genexpr>)
#         8    0.000    0.000    0.043    0.005 loops.py:234(_create_jaxpr)
#      3625    0.007    0.000    0.042    0.000 mlir.py:160(_array_ir_types)
#     36016    0.021    0.000    0.042    0.000 array.py:233(ndim)
#   562/490    0.001    0.000    0.041    0.000 partial_eval.py:1894(process_primitive)
#     24732    0.040    0.000    0.041    0.000 {built-in method jaxlib.xla_extension.flatten}
#     36887    0.031    0.000    0.041    0.000 core.py:1570(__hash__)
#      1938    0.006    0.000    0.041    0.000 source_info_util.py:159(<genexpr>)
#     24010    0.028    0.000    0.040    0.000 dispatch.py:103(__hash__)
#    129830    0.031    0.000    0.038    0.000 {built-in method _abc._abc_instancecheck}
#     24578    0.022    0.000    0.037    0.000 core.py:865(with_cur_sublevel)
#      3128    0.004    0.000    0.037    0.000 mlir.py:511(replace)
#     14337    0.016    0.000    0.036    0.000 numerictypes.py:357(issubdtype)
#         2    0.000    0.000    0.036    0.018 loops.py:1836(scanned_fun)
#     51591    0.026    0.000    0.036    0.000 config.py:471(get_state)
#       491    0.002    0.000    0.036    0.000 partial_eval.py:1899(default_process_primitive)
#      3141    0.025    0.000    0.035    0.000 dataclasses.py:1453(replace)
#         2    0.000    0.000    0.035    0.017 hmc.py:439(ev_loop)
#       342    0.001    0.000    0.033    0.000 lax.py:2272(_compare_lower_hlo)
#    406084    0.033    0.000    0.033    0.000 {method 'get' of 'dict' objects}
#     24220    0.026    0.000    0.032    0.000 util.py:90(unzip2)
#     19522    0.014    0.000    0.032    0.000 source_info_util.py:128(is_user_filename)
#     25562    0.010    0.000    0.032    0.000 core.py:1238(<genexpr>)
#        66    0.000    0.000    0.032    0.000 array_methods.py:727(op)
#     24723    0.009    0.000    0.032    0.000 core.py:1231(full_lower)
#       588    0.001    0.000    0.032    0.000 source_info_util.py:162(user_frame)
#     72037    0.031    0.000    0.031    0.000 array.py:225(shape)
#     12000    0.010    0.000    0.031    0.000 lax_numpy.py:4207(<setcomp>)
#     60012    0.023    0.000    0.031    0.000 dispatch.py:109(<genexpr>)
#     12010    0.006    0.000    0.029    0.000 lattice.py:73(__eq__)
# 12891/1690    0.004    0.000    0.026    0.000 dispatch.py:291(jaxpr_shardings)
#     12175    0.009    0.000    0.026    0.000 {built-in method builtins.sorted}
#       456    0.000    0.000    0.024    0.000 core.py:421(abstract_eval_)
#     24648    0.024    0.000    0.024    0.000 getlimits.py:685(__init__)
#     60050    0.023    0.000    0.023    0.000 array.py:241(sharding)
#     12006    0.012    0.000    0.023    0.000 dispatch.py:244(is_single_device_sharding)
#       432    0.002    0.000    0.023    0.000 utils.py:49(standard_abstract_eval)
#     12109    0.005    0.000    0.022    0.000 fromnumeric.py:3176(ndim)
#     12428    0.015    0.000    0.022    0.000 fromnumeric.py:1980(shape)
#    180472    0.021    0.000    0.021    0.000 {method 'get' of 'mappingproxy' objects}
#      1066    0.004    0.000    0.021    0.000 mlir.py:246(_numpy_array_constant)
#     12000    0.008    0.000    0.021    0.000 lax_numpy.py:4175(_is_valid_integer_index_for_slice)
#      1718    0.001    0.000    0.021    0.000 mlir.py:950(aval_to_types)
#     24032    0.009    0.000    0.019    0.000 array.py:524(_check_if_deleted)
#         2    0.001    0.000    0.019    0.010 util.py:254(cached)
#      2708    0.003    0.000    0.019    0.000 core.py:3028(str_eqn_compact)
#        85    0.005    0.000    0.019    0.000 partial_eval.py:1679(to_jaxpr)
#         2    0.000    0.000    0.019    0.009 dispatch.py:135(xla_primitive_callable)
#     28674    0.013    0.000    0.019    0.000 numerictypes.py:283(issubclass_)
#         1    0.000    0.000    0.018    0.018 hmc.py:405(evolve)
#      23/4    0.000    0.000    0.018    0.004 _module.py:873(__call__)
#    115179    0.014    0.000    0.018    0.000 {built-in method builtins.hasattr}
#     24016    0.007    0.000    0.017    0.000 lax.py:1318(<genexpr>)
#      1071    0.003    0.000    0.017    0.000 dtypes.py:634(result_type)
#         1    0.000    0.000    0.017    0.017 hmc.py:386(MD_traj)
# 163498/163497    0.017    0.000    0.017    0.000 {built-in method builtins.len}
#      5133    0.003    0.000    0.016    0.000 core.py:1877(is_constant_shape)
#      2722    0.009    0.000    0.016    0.000 source_info_util.py:100(__str__)
#      1216    0.001    0.000    0.016    0.000 mlir.py:190(aval_to_ir_type)
#      1119    0.002    0.000    0.016    0.000 dtypes.py:600(_lattice_result_type)
#      2434    0.003    0.000    0.016    0.000 core.py:167(subjaxprs)
#      6020    0.003    0.000    0.016    0.000 {method 'join' of 'str' objects}
#       381    0.000    0.000    0.016    0.000 source_info_util.py:173(summarize)
#         6    0.000    0.000    0.015    0.003 prng.py:1011(_threefry2x32_lowering)
#        38    0.000    0.000    0.014    0.000 lax.py:2057(_integer_pow_lowering)
#       381    0.001    0.000    0.014    0.000 source_info_util.py:175(<listcomp>)
#         6    0.000    0.000    0.014    0.002 array_methods.py:473(set)
#         6    0.000    0.000    0.014    0.002 scatter.py:46(_scatter_update)
#      4691    0.008    0.000    0.013    0.000 mlir.py:146(dtype_to_ir_type)
#      1030    0.003    0.000    0.013    0.000 _stablehlo_ops_gen.py:681(__init__)
#     12000    0.008    0.000    0.013    0.000 lax_numpy.py:4206(<setcomp>)
#     12000    0.010    0.000    0.013    0.000 lax_numpy.py:4167(_is_integer_index)
#      2845    0.001    0.000    0.013    0.000 dtypes.py:601(<genexpr>)
#      8485    0.009    0.000    0.013    0.000 core.py:157(jaxprs_in_params)
#      8715    0.004    0.000    0.013    0.000 mlir.py:1269(aval)
#      6356    0.005    0.000    0.013    0.000 core.py:3030(<genexpr>)
#       391    0.006    0.000    0.013    0.000 _func_ops_ext.py:90(add_entry_block)
#     24560    0.012    0.000    0.012    0.000 {built-in method jaxlib.xla_extension.jax_jit.thread_local_state}
#     58190    0.012    0.000    0.012    0.000 {built-in method __new__ of type object at 0x102c855f0}
#         6    0.000    0.000    0.012    0.002 scatter.py:86(_scatter_impl)
#        89    0.000    0.000    0.012    0.000 pjit.py:1314(pjit_staging_rule)
#      1726    0.002    0.000    0.012    0.000 dtypes.py:409(_dtype_and_weaktype)
#      3125    0.002    0.000    0.012    0.000 core.py:1884(definitely_equal_shape)
#     42621    0.012    0.000    0.012    0.000 {jaxlib.utils.safe_zip}
#     16094    0.010    0.000    0.012    0.000 core.py:1986(canonicalize_shape)
# 3436/3351    0.002    0.000    0.012    0.000 contextlib.py:132(__enter__)
#       110    0.000    0.000    0.012    0.000 core.py:2502(used_axis_names)
#   516/110    0.001    0.000    0.012    0.000 core.py:2507(subst_axis_names)
#     24323    0.011    0.000    0.011    0.000 {built-in method numpy.array}
#       342    0.001    0.000    0.011    0.000 mlir.py:1661(compare_hlo)
#     27238    0.008    0.000    0.011    0.000 dtypes.py:294(_issubclass)
#     12000    0.006    0.000    0.011    0.000 lax_numpy.py:4209(<setcomp>)
#     24032    0.011    0.000    0.011    0.000 {built-in method ArrayImpl.}
#   148/119    0.001    0.000    0.011    0.000 core.py:2577(subst_axis_names_jaxpr)
#     74932    0.011    0.000    0.011    0.000 {built-in method builtins.issubclass}
#      1066    0.002    0.000    0.011    0.000 _stablehlo_ops_gen.py:1149(__init__)
#     44858    0.007    0.000    0.010    0.000 source_info_util.py:131(<genexpr>)
#     42/39    0.000    0.000    0.010    0.000 lax_numpy.py:2005(array)
#     17897    0.006    0.000    0.010    0.000 core.py:1879(<genexpr>)
#     12517    0.010    0.000    0.010    0.000 core.py:1564(__eq__)
#        85    0.002    0.000    0.010    0.000 partial_eval.py:1777(_inline_literals)
#      7262    0.006    0.000    0.010    0.000 _ods_common.py:129(get_op_result_or_value)
#       287    0.001    0.000    0.010    0.000 lax.py:1542(naryop_dtype_rule)
#     49/41    0.000    0.000    0.010    0.000 _module.py:443(__call__)
# 64368/64343    0.010    0.000    0.010    0.000 {built-in method builtins.hash}
#     12000    0.005    0.000    0.010    0.000 array.py:335(is_fully_replicated)
#         6    0.000    0.000    0.010    0.002 pxla.py:1134(__call__)
#     12019    0.008    0.000    0.010    0.000 util.py:327(canonicalize_axis)
#         1    0.000    0.000    0.010    0.010 hmc.py:272(integrate)
#     24000    0.008    0.000    0.010    0.000 lax_numpy.py:4250(<genexpr>)
#        44    0.000    0.000    0.009    0.000 mlir.py:1380(<lambda>)
#         6    0.009    0.002    0.009    0.002 {built-in method jaxlib.xla_extension.execute_sharded}
#     60017    0.009    0.000    0.009    0.000 dispatch.py:104(<genexpr>)
#     24663    0.009    0.000    0.009    0.000 core.py:474(__init__)
#      3678    0.002    0.000    0.009    0.000 core.py:1444(physical_aval)
#     27/26    0.000    0.000    0.009    0.000 core.py:2571(used_axis_names_jaxpr)
#     27/26    0.000    0.000    0.009    0.000 core.py:2556(do_subst_axis_names_jaxpr)
#     14562    0.008    0.000    0.008    0.000 {built-in method numpy.asarray}
#      6100    0.005    0.000    0.008    0.000 source_info_util.py:207(user_context)
#      6012    0.005    0.000    0.008    0.000 source_info_util.py:118(replace)
#        91    0.000    0.000    0.008    0.000 api_util.py:614(debug_info)
#      1818    0.001    0.000    0.008    0.000 lax.py:1550(<genexpr>)
#     12006    0.008    0.000    0.008    0.000 sharding_impls.py:415(device_set)
#         1    0.000    0.000    0.008    0.008 hmc.py:275(_integrate)
#     13685    0.008    0.000    0.008    0.000 _module.py:485(__getattribute__)
#      4188    0.002    0.000    0.008    0.000 core.py:1259(definitely_equal)
#      3050    0.005    0.000    0.008    0.000 core.py:3116(clean_up_dead_vars)
#     70796    0.008    0.000    0.008    0.000 {method 'values' of 'dict' objects}
#      3436    0.004    0.000    0.008    0.000 contextlib.py:287(helper)
#       385    0.001    0.000    0.007    0.000 _func_ops_ext.py:244(__init__)
#     49/41    0.000    0.000    0.007    0.000 _better_abstract.py:218(__call__)
#         6    0.000    0.000    0.007    0.001 lax_numpy.py:4398(_index_to_gather)
#     24000    0.006    0.000    0.007    0.000 lax_numpy.py:4199(<genexpr>)
#      2710    0.005    0.000    0.007    0.000 mlir.py:879(subset)
#        91    0.001    0.000    0.007    0.000 api_util.py:635(_arg_names)
#       391    0.001    0.000    0.007    0.000 _func_ops_ext.py:33(__init__)
#      3134    0.003    0.000    0.007    0.000 mlir.py:455(__init__)
#       869    0.001    0.000    0.007    0.000 xla.py:191(_make_shaped_array_for_numpy_array)
#      17/8    0.000    0.000    0.007    0.001 _module.py:236(__post_init__)
#       385    0.001    0.000    0.007    0.000 _func_ops_gen.py:62(__init__)
# 3436/3351    0.002    0.000    0.007    0.000 contextlib.py:141(__exit__)
#      4062    0.003    0.000    0.007    0.000 core.py:3020(_compact_eqn_should_include)
#     27/26    0.000    0.000    0.007    0.000 core.py:2564(<listcomp>)
#   406/397    0.001    0.000    0.006    0.000 core.py:2546(subst_axis_names_eqn)
#       501    0.001    0.000    0.006    0.000 _stablehlo_ops_gen.py:3040(__init__)
#     431/4    0.001    0.000    0.006    0.002 dispatch.py:275(jaxpr_has_primitive)
#     24663    0.006    0.000    0.006    0.000 core.py:991(cur_sublevel)
#     26958    0.006    0.000    0.006    0.000 source_info_util.py:58(wrap)
#        83    0.000    0.000    0.006    0.000 lax.py:515(_convert_element_type)
#         6    0.000    0.000    0.006    0.001 lax_numpy.py:4049(_normalize_index)
#     12000    0.004    0.000    0.006    0.000 lax_numpy.py:4170(_is_simple_reverse_slice)
#     397/6    0.001    0.000    0.006    0.001 pxla.py:1925(jaxpr_transfer_mem_kinds)
#     12324    0.005    0.000    0.005    0.000 getlimits.py:696(min)
#      1061    0.001    0.000    0.005    0.000 xla.py:136(canonicalize_dtype)
#      5521    0.005    0.000    0.005    0.000 _ods_common.py:117(get_default_loc_context)
#      1066    0.001    0.000    0.005    0.000 fromnumeric.py:2322(any)
#       634    0.002    0.000    0.005    0.000 core.py:2531(subst_axis_names_var)
#       391    0.001    0.000    0.005    0.000 _func_ops_gen.py:241(__init__)
#         6    0.000    0.000    0.005    0.001 compiler.py:97(use_detailed_logging)
#      46/6    0.005    0.000    0.005    0.001 compiler.py:84(_walk_operations)
#       342    0.001    0.000    0.005    0.000 _stablehlo_ops_gen.py:991(__init__)
#       113    0.000    0.000    0.005    0.000 slicing.py:1170(_slice_lower)
#       391    0.001    0.000    0.005    0.000 _func_ops_gen.py:130(__init__)
#      2719    0.005    0.000    0.005    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.name}
#       228    0.001    0.000    0.005    0.000 lax.py:3600(_select_hlo_lowering)
#       113    0.001    0.000    0.005    0.000 mlir.py:1534(slice_op)
#     12000    0.004    0.000    0.005    0.000 lax_numpy.py:4189(_is_contiguous_slice)
#         3    0.000    0.000    0.005    0.002 prng.py:837(<lambda>)
#         3    0.000    0.000    0.005    0.002 prng.py:1281(threefry_random_bits)
#      3050    0.004    0.000    0.005    0.000 source_info_util.py:94(__add__)
#         3    0.000    0.000    0.005    0.002 prng.py:1293(_threefry_random_bits_partitionable)
#         2    0.000    0.000    0.005    0.002 dispatch.py:169(sharded_lowering)
#      1966    0.002    0.000    0.005    0.000 core.py:692(__getattr__)
#     42488    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
#     12807    0.003    0.000    0.005    0.000 core.py:1866(is_constant_dim)
#        35    0.000    0.000    0.004    0.000 lax_numpy.py:2088(asarray)
#      1447    0.001    0.000    0.004    0.000 mlir.py:69(dense_int_elements)
#         8    0.000    0.000    0.004    0.001 loops.py:361(cond_fun)
#         6    0.000    0.000    0.004    0.001 mlir.py:369(make_ir_context)
#       105    0.000    0.000    0.004    0.000 lax.py:2405(_convert_element_type_lower)
#       872    0.001    0.000    0.004    0.000 _ods_common.py:151(get_op_results_or_values)
#       124    0.000    0.000    0.004    0.000 inspect.py:3278(signature)
#      1066    0.002    0.000    0.004    0.000 fromnumeric.py:71(_wrapreduction)
#         2    0.000    0.000    0.004    0.002 hmc.py:349(H_density)
#     12000    0.004    0.000    0.004    0.000 lax_numpy.py:4252(<listcomp>)
#       124    0.000    0.000    0.004    0.000 inspect.py:3024(from_callable)
#     24000    0.004    0.000    0.004    0.000 lax_numpy.py:4203(<genexpr>)
#       557    0.003    0.000    0.004    0.000 core.py:3106(last_used)
#       124    0.001    0.000    0.004    0.000 inspect.py:2428(_signature_from_callable)
#         1    0.000    0.000    0.004    0.004 lattice.py:63(__post_init__)
#         6    0.004    0.001    0.004    0.001 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.verify}
#     12000    0.004    0.000    0.004    0.000 lax_numpy.py:4251(<listcomp>)
#       391    0.004    0.000    0.004    0.000 _func_ops_ext.py:72(type)
#      2708    0.001    0.000    0.004    0.000 mlir.py:316(get_canonical_source_file)
#       814    0.001    0.000    0.004    0.000 util.py:160(unflatten)
#      1718    0.001    0.000    0.004    0.000 mlir.py:1204(_to_physical_op_sharding)
#      3436    0.003    0.000    0.004    0.000 contextlib.py:104(__init__)
#       406    0.000    0.000    0.004    0.000 core.py:2549(<listcomp>)
#         6    0.000    0.000    0.004    0.001 compiler.py:222(_module_to_bytecode)
#         6    0.004    0.001    0.004    0.001 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.write_bytecode}
#      5521    0.004    0.000    0.004    0.000 {slot wrapper '__init__' of 'object' objects}
#      2708    0.004    0.000    0.004    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.file}
#       969    0.001    0.000    0.004    0.000 source_info_util.py:149(user_frames)
#      2736    0.003    0.000    0.004    0.000 effects.py:100(filter_in)
#       628    0.002    0.000    0.004    0.000 partial_eval.py:1880(makevar)
#      1976    0.001    0.000    0.004    0.000 partial_eval.py:1793(<lambda>)
#     12324    0.004    0.000    0.004    0.000 getlimits.py:709(max)
#        85    0.002    0.000    0.004    0.000 partial_eval.py:1731(_const_folding_and_forwarding)
#       390    0.001    0.000    0.004    0.000 mlir.py:1016(<listcomp>)
#       228    0.001    0.000    0.004    0.000 _stablehlo_ops_gen.py:4300(__init__)
#       384    0.000    0.000    0.004    0.000 mlir.py:843(token_type)
#        38    0.000    0.000    0.003    0.000 lax.py:2039(_integer_pow)
#        27    0.000    0.000    0.003    0.000 lax.py:422(mul)
#       105    0.000    0.000    0.003    0.000 mlir.py:1697(convert_hlo)
#       872    0.001    0.000    0.003    0.000 _ods_common.py:169(<listcomp>)
#        71    0.000    0.000    0.003    0.000 lax.py:3015(_broadcast_in_dim_lower)
#      1923    0.001    0.000    0.003    0.000 core.py:326(<lambda>)
#         6    0.000    0.000    0.003    0.001 pxla.py:1675(wrapped)
#      4287    0.003    0.000    0.003    0.000 mlir.py:858(__init__)
#       234    0.000    0.000    0.003    0.000 abstract_arrays.py:56(canonical_concrete_aval)
#        85    0.000    0.000    0.003    0.000 partial_eval.py:2473(_input_type_to_tracers)
#         8    0.000    0.000    0.003    0.000 loops.py:1107(scan_bind)
#       124    0.001    0.000    0.003    0.000 inspect.py:2333(_signature_from_function)
#       716    0.000    0.000    0.003    0.000 core.py:1543(update)
#       224    0.001    0.000    0.003    0.000 tree_util.py:206(tree_map)
#     25336    0.003    0.000    0.003    0.000 {method 'startswith' of 'str' objects}
#         6    0.000    0.000    0.003    0.000 pxla.py:1693(_trace_to_jaxpr_and_dce)
#     24020    0.003    0.000    0.003    0.000 core.py:817(pure)
#         3    0.000    0.000    0.003    0.001 lattice.py:184(op)
#     28938    0.003    0.000    0.003    0.000 {built-in method _operator.index}
#      1279    0.003    0.000    0.003    0.000 util.py:122(split_list)
#      1600    0.002    0.000    0.003    0.000 core.py:191(in_avals)
#      3050    0.002    0.000    0.003    0.000 core.py:3119(<setcomp>)
#      2801    0.002    0.000    0.003    0.000 util.py:152(concatenate)
#      1683    0.002    0.000    0.003    0.000 core.py:195(out_avals)
#       814    0.001    0.000    0.003    0.000 util.py:165(<listcomp>)
#       896    0.001    0.000    0.003    0.000 xla.py:152(_canonicalize_ndarray_dtype)
#         2    0.000    0.000    0.003    0.001 hmc.py:376(delta_P)
#      1027    0.001    0.000    0.003    0.000 partial_eval.py:1708(newvar)
#     19522    0.003    0.000    0.003    0.000 {method 'endswith' of 'str' objects}
#      5665    0.002    0.000    0.003    0.000 mlir.py:561(_unwrap_singleton_ir_values)
#       306    0.001    0.000    0.003    0.000 partial_eval.py:1829(new_arg)
#       204    0.001    0.000    0.003    0.000 _stablehlo_ops_gen.py:54(__init__)
#       969    0.001    0.000    0.003    0.000 source_info_util.py:135(raw_frame_to_frame)
#       166    0.000    0.000    0.003    0.000 core.py:1086(new_main)
#         5    0.000    0.000    0.002    0.000 prng.py:1178(iota_2x32_shape_lowering)
#       474    0.000    0.000    0.002    0.000 partial_eval.py:1812(<listcomp>)
#       390    0.000    0.000    0.002    0.000 mlir.py:1145(<listcomp>)
#       969    0.002    0.000    0.002    0.000 {built-in method jaxlib.xla_extension.raw_frames}
#         1    0.000    0.000    0.002    0.002 loops.py:1828(while_body_fun)
#       468    0.001    0.000    0.002    0.000 {built-in method jaxlib.xla_extension.pytree.unflatten}
#       385    0.002    0.000    0.002    0.000 _func_ops_ext.py:80(name)
#       896    0.001    0.000    0.002    0.000 partial_eval.py:1792(<lambda>)
#      4363    0.002    0.000    0.002    0.000 mlir.py:562(wrap_singleton_ir_values)
#         6    0.000    0.000    0.002    0.000 lax_numpy.py:887(squeeze)
#         1    0.000    0.000    0.002    0.002 lattice.py:70(<listcomp>)
#         3    0.000    0.000    0.002    0.001 lattice.py:190(op)
#         3    0.000    0.000    0.002    0.001 lax_numpy.py:2303(arange)
#       198    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:374(__init__)
#       234    0.001    0.000    0.002    0.000 core.py:1618(__init__)
#         1    0.000    0.000    0.002    0.002 hmc.py:283(mid_step)
#       342    0.002    0.000    0.002    0.000 {built-in method importlib._bootstrap.get}
#       224    0.000    0.000    0.002    0.000 tree_util.py:795(generate_key_paths)
#      2178    0.002    0.000    0.002    0.000 dtypes.py:562(is_weakly_typed)
#         6    0.000    0.000    0.002    0.000 pxla.py:1683(prune_unused_inputs)
#      1090    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       579    0.000    0.000    0.002    0.000 tree_util.py:63(tree_flatten)
#         6    0.000    0.000    0.002    0.000 partial_eval.py:1438(dce_jaxpr_consts)
#     12000    0.002    0.000    0.002    0.000 lax_numpy.py:4217(<genexpr>)
#      5759    0.002    0.000    0.002    0.000 mlir.py:1357(<genexpr>)
#      4006    0.001    0.000    0.002    0.000 mlir.py:1500(<genexpr>)
#        23    0.000    0.000    0.002    0.000 _module.py:534(__get__)
#         1    0.000    0.000    0.002    0.002 2186373298.py:1(mag)
#       269    0.000    0.000    0.002    0.000 api_util.py:646(<genexpr>)
#       290    0.001    0.000    0.002    0.000 lax.py:1570(broadcasting_shape_rule)
#      2599    0.001    0.000    0.002    0.000 core.py:285(__init__)
#        49    0.000    0.000    0.002    0.000 _module.py:455(<setcomp>)
#   950/508    0.001    0.000    0.002    0.000 tree_util.py:803(_generate_key_paths_)
#      5680    0.001    0.000    0.002    0.000 core.py:3024(<genexpr>)
#       170    0.000    0.000    0.002    0.000 core.py:937(_update_thread_local_jit_state)
#         6    0.000    0.000    0.002    0.000 __init__.py:96(__init__)
#       391    0.002    0.000    0.002    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.insert}
#       158    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:4498(__init__)
#       119    0.002    0.000    0.002    0.000 {built-in method builtins.dir}
#       113    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:4578(__init__)
#         3    0.000    0.000    0.002    0.001 {built-in method _operator.mul}
#       390    0.000    0.000    0.002    0.000 mlir.py:1029(<listcomp>)
#        24    0.000    0.000    0.002    0.000 array.py:722(_array_mlir_constant_handler)
#        27    0.000    0.000    0.002    0.000 core.py:2562(<listcomp>)
#      2714    0.001    0.000    0.002    0.000 <string>:2(__hash__)
#     12109    0.002    0.000    0.002    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#     12428    0.002    0.000    0.002    0.000 fromnumeric.py:1976(_shape_dispatcher)
#      2988    0.001    0.000    0.002    0.000 core.py:1831(raise_to_shaped)
#        14    0.000    0.000    0.002    0.000 lax.py:776(broadcast_in_dim)
#         1    0.000    0.000    0.002    0.002 lax_numpy.py:2513(meshgrid)
#         6    0.000    0.000    0.002    0.000 lattice.py:273(copy_new_F)
#       395    0.000    0.000    0.002    0.000 mlir.py:567(flatten_lowering_ir_args)
#      5759    0.001    0.000    0.002    0.000 mlir.py:1356(<genexpr>)
#      12/6    0.000    0.000    0.002    0.000 partial_eval.py:1430(dce_jaxpr)
#      4099    0.001    0.000    0.002    0.000 core.py:1970(_canonicalize_dimension)
#        12    0.000    0.000    0.002    0.000 lax.py:1496(<genexpr>)
#      3141    0.001    0.000    0.002    0.000 dataclasses.py:1251(_is_dataclass_instance)
#         8    0.000    0.000    0.002    0.000 slicing.py:777(index_in_dim)
#         8    0.000    0.000    0.002    0.000 loops.py:273(_check_scan_carry_type)
#      1044    0.001    0.000    0.002    0.000 tree_util.py:244(<genexpr>)
#         3    0.000    0.000    0.002    0.001 lax.py:1225(iota)
#         3    0.000    0.000    0.002    0.001 lax.py:1232(broadcasted_iota)
#       192    0.000    0.000    0.002    0.000 common.py:39(_abstractify)
#       170    0.001    0.000    0.002    0.000 config.py:653(update_thread_local_jit_state)
#       184    0.000    0.000    0.002    0.000 api_util.py:581(shaped_abstractify)
#      12/6    0.000    0.000    0.002    0.000 partial_eval.py:1448(_dce_jaxpr)
#      4505    0.002    0.000    0.002    0.000 mlir.py:1275(write)
#       391    0.001    0.000    0.002    0.000 _func_ops_ext.py:64(is_external)
#      1371    0.001    0.000    0.002    0.000 core.py:249(replace)
#       432    0.001    0.000    0.001    0.000 source_info_util.py:74(extend)
#         6    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.load_all_available_dialects}
#       133    0.000    0.000    0.001    0.000 xla.py:155(_canonicalize_python_scalar_dtype)
#        98    0.000    0.000    0.001    0.000 _module.py:652(_convert_fields)
#      5717    0.001    0.000    0.001    0.000 sharding_impls.py:939(is_unspecified)
#        42    0.000    0.000    0.001    0.000 lax.py:3331(_squeeze_lower)
#        43    0.000    0.000    0.001    0.000 mlir.py:1524(reshape)
#       390    0.000    0.000    0.001    0.000 mlir.py:1080(<listcomp>)
#         7    0.000    0.000    0.001    0.000 lattice.py:144(__post_init__)
#       115    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:1183(__init__)
#        85    0.000    0.000    0.001    0.000 partial_eval.py:1808(<listcomp>)
#       505    0.001    0.000    0.001    0.000 core.py:270(new_jaxpr_eqn)
#       178    0.000    0.000    0.001    0.000 dispatch.py:354(check_arg)
#         5    0.000    0.000    0.001    0.000 prng.py:1170(bcast_iotas_to_reshaped_iota)
#         2    0.000    0.000    0.001    0.001 loops.py:843(_scan_dce_rule)
#       890    0.000    0.000    0.001    0.000 source_info_util.py:187(current)
#     13309    0.001    0.000    0.001    0.000 typing.py:2256(cast)
#       985    0.001    0.000    0.001    0.000 partial_eval.py:1874(getvar)
#        12    0.000    0.000    0.001    0.000 lax.py:498(convert_element_type)
#       432    0.001    0.000    0.001    0.000 utils.py:107(standard_named_shape_rule)
#        32    0.000    0.000    0.001    0.000 api_util.py:562(_shaped_abstractify_slow)
#       108    0.000    0.000    0.001    0.000 _dtype.py:34(__str__)
#      6904    0.001    0.000    0.001    0.000 dtypes.py:411(<genexpr>)
#       782    0.001    0.000    0.001    0.000 _func_ops_ext.py:68(body)
#        12    0.000    0.000    0.001    0.000 function_base.py:2530(cov)
#       452    0.000    0.000    0.001    0.000 mlir.py:1548(<genexpr>)
#        24    0.000    0.000    0.001    0.000 lax.py:3273(_pad_lower)
#         1    0.000    0.000    0.001    0.001 hmc.py:361(momentum_refresh)
#        91    0.000    0.000    0.001    0.000 inspect.py:3207(bind)
#      6848    0.001    0.000    0.001    0.000 partial_eval.py:1825(frame)
#         7    0.000    0.000    0.001    0.000 lax.py:414(add)
#         5    0.000    0.000    0.001    0.000 prng.py:1176(<listcomp>)
#         6    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._mlirHlo.register_mhlo_dialect}
#         9    0.000    0.000    0.001    0.000 prng.py:1185(_mul)
#         2    0.000    0.000    0.001    0.001 reductions.py:216(sum)
#        48    0.000    0.000    0.001    0.000 core.py:1356(valid_jaxtype)
#       289    0.000    0.000    0.001    0.000 lax.py:1596(_naryop_weak_type_rule)
#        91    0.001    0.000    0.001    0.000 inspect.py:3076(_bind)
#         3    0.000    0.000    0.001    0.000 prng.py:749(<lambda>)
#         3    0.000    0.000    0.001    0.000 prng.py:1247(threefry_split)
#         2    0.000    0.000    0.001    0.001 {built-in method _operator.add}
#        25    0.000    0.000    0.001    0.000 partial_eval.py:2150(debug_info)
#       272    0.001    0.000    0.001    0.000 inspect.py:2686(__init__)
#        24    0.000    0.000    0.001    0.000 mlir.py:1614(pad)
#        93    0.000    0.000    0.001    0.000 partial_eval.py:1847(_new_const)
#         6    0.000    0.000    0.001    0.000 slicing.py:2447(_scatter_lower)
#       396    0.001    0.000    0.001    0.000 mlir.py:867(create)
#         6    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._stablehlo.register_dialect}
#        32    0.000    0.000    0.001    0.000 slicing.py:1074(_slice_shape_rule)
#         9    0.000    0.000    0.001    0.000 lax.py:1323(expand_dims)
#       491    0.000    0.000    0.001    0.000 partial_eval.py:1909(<listcomp>)
#        85    0.001    0.000    0.001    0.000 partial_eval.py:1801(<setcomp>)
#       384    0.001    0.000    0.001    0.000 pjit.py:1377(<listcomp>)
#        58    0.000    0.000    0.001    0.000 mlir.py:1365(_ir_consts)
#         7    0.000    0.000    0.001    0.000 util.py:267(promote_dtypes)
#         8    0.000    0.000    0.001    0.000 slicing.py:702(slice_in_dim)
#        66    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:4735(__init__)
#        95    0.000    0.000    0.001    0.000 pjit.py:194(_get_fastpath_data)
#       108    0.000    0.000    0.001    0.000 _dtype.py:346(_name_get)
#      1027    0.001    0.000    0.001    0.000 partial_eval.py:1567(__init__)
#       384    0.000    0.000    0.001    0.000 mlir.py:883(update_tokens)
#       390    0.001    0.000    0.001    0.000 _func_ops_ext.py:105(arg_attrs)
#       474    0.001    0.000    0.001    0.000 partial_eval.py:1811(<listcomp>)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:2517(<listcomp>)
#         6    0.000    0.000    0.001    0.000 slicing.py:635(scatter)
#         5    0.000    0.000    0.001    0.000 lax.py:3951(_unary_reduce_lower)
#     12000    0.001    0.000    0.001    0.000 sharding_impls.py:436(is_fully_replicated)
#        15    0.000    0.000    0.001    0.000 lax.py:2956(_broadcast_in_dim_staging_rule)
#         1    0.000    0.000    0.001    0.001 mlir.py:1770(cached_lowering)
#         4    0.000    0.000    0.001    0.000 ufuncs.py:308(power)
#        94    0.000    0.000    0.001    0.000 lax.py:4836(_check_shapelike)
#       537    0.000    0.000    0.001    0.000 lax.py:1580(<genexpr>)
#       391    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.get}
#         6    0.000    0.000    0.001    0.000 lax.py:897(select)
#      2180    0.001    0.000    0.001    0.000 mlir.py:231(<genexpr>)
#      1428    0.001    0.000    0.001    0.000 source_info_util.py:64(wrap)
#      4398    0.001    0.000    0.001    0.000 dtypes.py:318(_is_typeclass)
#      5263    0.001    0.000    0.001    0.000 core.py:182(<lambda>)
#        10    0.000    0.000    0.001    0.000 pxla.py:1633(_get_and_check_device_assignment)
#      1690    0.000    0.000    0.001    0.000 pxla.py:2006(<genexpr>)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:2529(<listcomp>)
#       174    0.000    0.000    0.001    0.000 core.py:1846(<lambda>)
#         1    0.000    0.000    0.001    0.001 mlir.py:1213(_emit_lowering_rule_as_fun)
#        58    0.000    0.000    0.001    0.000 mlir.py:1367(<dictcomp>)
#        12    0.000    0.000    0.001    0.000 function_base.py:398(average)
#        14    0.000    0.000    0.001    0.000 mlir.py:237(ir_constant)
#         6    0.001    0.000    0.001    0.000 pxla.py:1935(are_all_shardings_default_mem_kind)
#       546    0.000    0.000    0.001    0.000 core.py:440(write)
#       170    0.000    0.000    0.001    0.000 source_info_util.py:257(reset_name_stack)
#        28    0.000    0.000    0.001    0.000 lax.py:3199(_concatenate_lower)
#       390    0.000    0.000    0.001    0.000 mlir.py:1102(<listcomp>)
#        24    0.000    0.000    0.001    0.000 _methods.py:101(_mean)
#       769    0.001    0.000    0.001    0.000 mlir.py:876(effects)
#         1    0.000    0.000    0.001    0.001 lax_numpy.py:1783(stack)
#        23    0.000    0.000    0.001    0.000 _module.py:935(_module_update_wrapper)
#        97    0.000    0.000    0.001    0.000 pxla.py:2705(reflatten_outputs_for_dispatch)
#         2    0.000    0.000    0.001    0.000 partial_eval.py:2271(trace_to_jaxpr_final)
#       201    0.000    0.000    0.001    0.000 core.py:1253(same_referent)
#         7    0.000    0.000    0.001    0.000 util.py:275(<listcomp>)
#       969    0.001    0.000    0.001    0.000 {built-in method jaxlib.xla_extension.code_addr2location}
#      1066    0.001    0.000    0.001    0.000 fromnumeric.py:72(<dictcomp>)
#       299    0.000    0.000    0.001    0.000 utils.py:32(_input_dtype)
#      1600    0.001    0.000    0.001    0.000 core.py:193(<listcomp>)
#         6    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#       516    0.000    0.000    0.001    0.000 core.py:2518(<listcomp>)
#        35    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:3872(__init__)
#      2976    0.001    0.000    0.001    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.get_dynamic_size}
#       390    0.001    0.000    0.001    0.000 _func_ops_ext.py:122(result_attrs)
#        40    0.000    0.000    0.001    0.000 {method 'send' of 'generator' objects}
#        40    0.000    0.000    0.001    0.000 mlir.py:1654(add_jaxvals_lowering)
#       182    0.000    0.000    0.001    0.000 pjit.py:786(_create_sharding_for_array)
#      12/4    0.000    0.000    0.001    0.000 pjit.py:1726(dce_jaxpr_pjit_rule)
#     47/41    0.000    0.000    0.001    0.000 _module.py:293(__init__)
#       169    0.001    0.000    0.001    0.000 {built-in method jaxlib.xla_extension.get_traceback}
#       678    0.000    0.000    0.001    0.000 lax_numpy.py:2049(<genexpr>)
#         8    0.000    0.000    0.001    0.000 tree_util.py:764(tree_flatten_with_path)
#       238    0.000    0.000    0.001    0.000 tree_util.py:86(tree_unflatten)
#         2    0.000    0.000    0.001    0.000 lax.py:1195(full)
#       116    0.000    0.000    0.001    0.000 api_util.py:624(fun_sourceinfo)
#         6    0.000    0.000    0.001    0.000 pxla.py:1042(__call__)
#       182    0.000    0.000    0.001    0.000 pjit.py:779(hashable_pytree)
#        43    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:3850(__init__)
#      2708    0.001    0.000    0.001    0.000 mlir.py:1279(get_lowering)
#       240    0.000    0.000    0.001    0.000 inspect.py:735(unwrap)
#       203    0.000    0.000    0.001    0.000 linear_util.py:246(transformation_with_aux)
#        78    0.000    0.000    0.001    0.000 tree_util.py:639(flatten_with_keys)
#        24    0.000    0.000    0.001    0.000 iostream.py:626(write)
#      2736    0.001    0.000    0.001    0.000 effects.py:101(<listcomp>)
#       557    0.000    0.000    0.001    0.000 core.py:3108(<dictcomp>)
#       402    0.000    0.000    0.001    0.000 core.py:1250(get_referent)
#         6    0.000    0.000    0.001    0.000 pxla.py:124(shard_args)
#      1683    0.001    0.000    0.001    0.000 core.py:197(<listcomp>)
#         6    0.000    0.000    0.001    0.000 pxla.py:145(<listcomp>)
#       124    0.000    0.000    0.001    0.000 inspect.py:2972(__init__)
#      3231    0.001    0.000    0.001    0.000 core.py:96(<lambda>)
#        28    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:1113(__init__)
#        14    0.000    0.000    0.001    0.000 pxla.py:108(shard_arg)
#        36    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:5141(__init__)
#       178    0.000    0.000    0.000    0.000 __init__.py:452(_replace)
#         1    0.000    0.000    0.000    0.000 random.py:173(PRNGKey)
#         2    0.000    0.000    0.000    0.000 conditionals.py:830(_cond_lowering)
#        15    0.000    0.000    0.000    0.000 lax.py:3033(_broadcast_in_dim_abstract_eval)
#         1    0.000    0.000    0.000    0.000 random.py:637(normal)
#      3903    0.000    0.000    0.000    0.000 core.py:97(<lambda>)
#      3433    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:144(__call__)
#        12    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#       384    0.000    0.000    0.000    0.000 pjit.py:1380(<listcomp>)
#      2710    0.000    0.000    0.000    0.000 mlir.py:881(<genexpr>)
#       2/1    0.000    0.000    0.000    0.000 pjit.py:1718(_dce_jaxpr_pjit)
#      2986    0.000    0.000    0.000    0.000 core.py:95(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2177(ones)
#       435    0.000    0.000    0.000    0.000 core.py:2148(join_named_shapes)
#         1    0.000    0.000    0.000    0.000 random.py:142(_key)
#       108    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#      2144    0.000    0.000    0.000    0.000 dtypes.py:647(<genexpr>)
#      1202    0.000    0.000    0.000    0.000 utils.py:51(<genexpr>)
#         6    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._chlo.register_dialect}
#        24    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3219(__init__)
#      1212    0.000    0.000    0.000    0.000 core.py:907(__eq__)
#         1    0.000    0.000    0.000    0.000 prng.py:412(seed_with_impl)
#        54    0.000    0.000    0.000    0.000 pxla.py:2736(unsafe_call)
#        85    0.000    0.000    0.000    0.000 partial_eval.py:1786(<dictcomp>)
#      1762    0.000    0.000    0.000    0.000 partial_eval.py:1619(_assert_live)
#         1    0.000    0.000    0.000    0.000 prng.py:687(random_seed)
#       370    0.000    0.000    0.000    0.000 util.py:423(__hash__)
#        83    0.000    0.000    0.000    0.000 dtypes.py:656(check_user_dtype_supported)
#       352    0.000    0.000    0.000    0.000 util.py:418(__eq__)
#         1    0.000    0.000    0.000    0.000 ufuncs.py:252(true_divide)
#         6    0.000    0.000    0.000    0.000 partial_eval.py:2159(debug_info_final)
#        30    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3147(__init__)
#        15    0.000    0.000    0.000    0.000 lax.py:4863(_const)
#        33    0.000    0.000    0.000    0.000 lax.py:3295(_squeeze_shape_rule)
#        24    0.000    0.000    0.000    0.000 iostream.py:548(_schedule_flush)
#        91    0.000    0.000    0.000    0.000 pjit.py:454(<lambda>)
#         6    0.000    0.000    0.000    0.000 pxla.py:2543(build_unsafe_call)
#         6    0.000    0.000    0.000    0.000 compiler.py:103(get_compile_options)
#      3428    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        30    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3804(__init__)
#         6    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#      1197    0.000    0.000    0.000    0.000 partial_eval.py:1796(vars_in_shape)
#        28    0.000    0.000    0.000    0.000 mlir.py:574(sharded_aval)
#         6    0.000    0.000    0.000    0.000 mlir.py:802(_set_up_aliases)
#       170    0.000    0.000    0.000    0.000 linear_util.py:260(wrap_init)
#       944    0.000    0.000    0.000    0.000 partial_eval.py:2493(_substitute_vars_in_type)
#        27    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4438(__init__)
#        18    0.000    0.000    0.000    0.000 api_util.py:649(result_paths)
#        85    0.000    0.000    0.000    0.000 linear_util.py:170(populate_stores)
#       197    0.000    0.000    0.000    0.000 tree_util.py:607(keystr)
#        15    0.000    0.000    0.000    0.000 lax.py:2835(_broadcast_in_dim_shape_rule)
#       144    0.000    0.000    0.000    0.000 _module.py:594(__setattr__)
#       752    0.000    0.000    0.000    0.000 core.py:437(read)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:903(expand_dims)
#         5    0.000    0.000    0.000    0.000 prng.py:1200(<listcomp>)
# ...
#        17    0.000    0.000    0.000    0.000 partial_eval.py:1744(<listcomp>)
#        12    0.000    0.000    0.000    0.000 partial_eval.py:1479(<listcomp>)
#         3    0.000    0.000    0.000    0.000 core.py:1414(concrete_dim_or_error)
#        28    0.000    0.000    0.000    0.000 util.py:319(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1994(<listcomp>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1035(__init__)
#         6    0.000    0.000    0.000    0.000 compiler.py:168(<lambda>)
#         4    0.000    0.000    0.000    0.000 pxla.py:2907(check_device_backend_on_shardings)
#         6    0.000    0.000    0.000    0.000 xla_bridge.py:434(is_known_platform)
#         6    0.000    0.000    0.000    0.000 slicing.py:269(from_any)
#         2    0.000    0.000    0.000    0.000 sharding.py:30(_addressable_devices_indices_map)
#         3    0.000    0.000    0.000    0.000 lax.py:1236(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:231(<listcomp>)
#         6    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#         4    0.000    0.000    0.000    0.000 lax_numpy.py:2522(<genexpr>)
#         6    0.000    0.000    0.000    0.000 conditionals.py:832(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pxla.py:178(<listcomp>)
#         6    0.000    0.000    0.000    0.000 mlir.py:413(__init__)
#        24    0.000    0.000    0.000    0.000 lax.py:3492(<genexpr>)
#         9    0.000    0.000    0.000    0.000 lax.py:1492(<genexpr>)
#        15    0.000    0.000    0.000    0.000 pjit.py:1208(<genexpr>)
#        46    0.000    0.000    0.000    0.000 lax.py:2326(_convert_element_type_weak_type_rule)
#         4    0.000    0.000    0.000    0.000 pjit.py:782(<lambda>)
#         4    0.000    0.000    0.000    0.000 pjit.py:1051(<listcomp>)
#        21    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 prng.py:732(random_split_abstract_eval)
#         2    0.000    0.000    0.000    0.000 lattice.py:266(__copy__)
#        12    0.000    0.000    0.000    0.000 slicing.py:1931(<listcomp>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1136(<listcomp>)
#        12    0.000    0.000    0.000    0.000 partial_eval.py:1480(<listcomp>)
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        33    0.000    0.000    0.000    0.000 lax.py:3292(_squeeze_dtype_rule)
#        31    0.000    0.000    0.000    0.000 partial_eval.py:1486(<genexpr>)
#         1    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         3    0.000    0.000    0.000    0.000 lax.py:1237(<listcomp>)
#         8    0.000    0.000    0.000    0.000 lax.py:3820(<genexpr>)
#         3    0.000    0.000    0.000    0.000 core.py:1874(is_dim)
#         9    0.000    0.000    0.000    0.000 prng.py:1294(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pxla.py:165(<listcomp>)
#         6    0.000    0.000    0.000    0.000 mlir.py:1049(<listcomp>)
#         6    0.000    0.000    0.000    0.000 config.py:346(get_state)
#         3    0.000    0.000    0.000    0.000 util.py:321(__eq__)
#        36    0.000    0.000    0.000    0.000 lax.py:3512(<genexpr>)
#         6    0.000    0.000    0.000    0.000 enum.py:1188(__str__)
#         5    0.000    0.000    0.000    0.000 pjit.py:901(<genexpr>)
#         2    0.000    0.000    0.000    0.000 prng.py:279(dtype)
#         2    0.000    0.000    0.000    0.000 partial_eval.py:1461(has_effects)
#        32    0.000    0.000    0.000    0.000 pxla.py:106(identity)
#        12    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 api_util.py:312(<dictcomp>)
#        26    0.000    0.000    0.000    0.000 utils.py:36(<genexpr>)
#        20    0.000    0.000    0.000    0.000 pxla.py:1717(<genexpr>)
#        15    0.000    0.000    0.000    0.000 prng.py:979(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:2158(as_named_shape)
#        24    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        12    0.000    0.000    0.000    0.000 pxla.py:2436(<genexpr>)
#        25    0.000    0.000    0.000    0.000 partial_eval.py:1487(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pxla.py:2248(__init__)
#         6    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.device_count}
#        12    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 <string>:2(__init__)
#        16    0.000    0.000    0.000    0.000 pjit.py:1209(<genexpr>)
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:135(__hash__)
#        12    0.000    0.000    0.000    0.000 pjit.py:1746(<listcomp>)
#         7    0.000    0.000    0.000    0.000 prng.py:647(iterated_vmap_unary)
#         4    0.000    0.000    0.000    0.000 dtypes.py:172(to_numeric_dtype)
#         8    0.000    0.000    0.000    0.000 pjit.py:955(<genexpr>)
#         8    0.000    0.000    0.000    0.000 pjit.py:211(<listcomp>)
#        20    0.000    0.000    0.000    0.000 pxla.py:1718(<genexpr>)
#        24    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#        34    0.000    0.000    0.000    0.000 partial_eval.py:1746(<genexpr>)
#        20    0.000    0.000    0.000    0.000 pxla.py:1982(<genexpr>)
#        12    0.000    0.000    0.000    0.000 lax_numpy.py:4363(<genexpr>)
#        23    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#        12    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#        12    0.000    0.000    0.000    0.000 pjit.py:1747(<listcomp>)
#         1    0.000    0.000    0.000    0.000 util.py:240(<listcomp>)
#        26    0.000    0.000    0.000    0.000 tree_util.py:278(<lambda>)
#         6    0.000    0.000    0.000    0.000 xla_bridge.py:442(canonicalize_platform)
#        24    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         6    0.000    0.000    0.000    0.000 prng.py:999(rotate_list)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2331(result)
#        11    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#        20    0.000    0.000    0.000    0.000 tree_util.py:277(<lambda>)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:2527(<listcomp>)
#         4    0.000    0.000    0.000    0.000 api_util.py:302(<listcomp>)
#         2    0.000    0.000    0.000    0.000 sharding_impls.py:426(devices_indices_map)
#        14    0.000    0.000    0.000    0.000 util.py:303(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 prng.py:609(__hash__)
#        20    0.000    0.000    0.000    0.000 dtypes.py:622(<genexpr>)
#        12    0.000    0.000    0.000    0.000 lax_numpy.py:4663(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:2082(__init__)
#         4    0.000    0.000    0.000    0.000 pjit.py:1052(<listcomp>)
#         9    0.000    0.000    0.000    0.000 lax.py:1335(<listcomp>)
#        12    0.000    0.000    0.000    0.000 lax_numpy.py:4732(<genexpr>)
#        10    0.000    0.000    0.000    0.000 core.py:910(__lt__)
#        13    0.000    0.000    0.000    0.000 api_util.py:138(__init__)
#         1    0.000    0.000    0.000    0.000 lax.py:194(_merge_dyn_shape)
#         2    0.000    0.000    0.000    0.000 loops.py:1833(_fori_scan_body_fun)
#         6    0.000    0.000    0.000    0.000 pxla.py:1689(<setcomp>)
#         9    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 pjit.py:1181(_get_jaxpr_as_fun)
#        12    0.000    0.000    0.000    0.000 function_base.py:2525(_cov_dispatcher)
#         1    0.000    0.000    0.000    0.000 lattice.py:167(dims)
#         6    0.000    0.000    0.000    0.000 pxla.py:1995(<listcomp>)
#        18    0.000    0.000    0.000    0.000 core.py:1405(<lambda>)
#         6    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.replica_count}
#         6    0.000    0.000    0.000    0.000 pxla.py:1058(__init__)
#         2    0.000    0.000    0.000    0.000 core.py:2144(__hash__)
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#        12    0.000    0.000    0.000    0.000 multiarray.py:741(dot)
#        15    0.000    0.000    0.000    0.000 lax.py:2852(<genexpr>)
#         6    0.000    0.000    0.000    0.000 mlir.py:984(<listcomp>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1688(<setcomp>)
#         6    0.000    0.000    0.000    0.000 lax.py:1539(<lambda>)
#        15    0.000    0.000    0.000    0.000 prng.py:981(<genexpr>)
#        15    0.000    0.000    0.000    0.000 {method 'issubset' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 prng.py:103(__str__)
#         3    0.000    0.000    0.000    0.000 {built-in method math.prod}
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:4737(<genexpr>)
#        10    0.000    0.000    0.000    0.000 loops.py:1610(<listcomp>)
#        10    0.000    0.000    0.000    0.000 loops.py:1631(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:3134(<setcomp>)
#         3    0.000    0.000    0.000    0.000 api_util.py:331(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1716(<listcomp>)
#         6    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.computation_count}
#         6    0.000    0.000    0.000    0.000 array_methods.py:450(__init__)
#         6    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#         4    0.000    0.000    0.000    0.000 pjit.py:1211(<listcomp>)
#        10    0.000    0.000    0.000    0.000 loops.py:1670(<listcomp>)
#        12    0.000    0.000    0.000    0.000 slicing.py:1943(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 core.py:2255(primitive_uses_outfeed)
#         2    0.000    0.000    0.000    0.000 lax.py:125(asarray)
#         4    0.000    0.000    0.000    0.000 pxla.py:2803(<genexpr>)
#         6    0.000    0.000    0.000    0.000 dispatch.py:347(apply_outfeed_rewriter)
#         2    0.000    0.000    0.000    0.000 prng.py:134(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 function_base.py:393(_average_dispatcher)
#         9    0.000    0.000    0.000    0.000 util.py:309(__eq__)
#         5    0.000    0.000    0.000    0.000 prng.py:592(__init__)
#        12    0.000    0.000    0.000    0.000 stride_tricks.py:363(_broadcast_to_dispatcher)
#         2    0.000    0.000    0.000    0.000 loops.py:864(<listcomp>)
#        10    0.000    0.000    0.000    0.000 loops.py:1611(<listcomp>)
#        10    0.000    0.000    0.000    0.000 loops.py:1674(<listcomp>)
#         6    0.000    0.000    0.000    0.000 util.py:315(__init__)
#         6    0.000    0.000    0.000    0.000 dispatch.py:266(should_tuple_args)
#         2    0.000    0.000    0.000    0.000 core.py:203(eqns)
#         8    0.000    0.000    0.000    0.000 loops.py:193(<listcomp>)
#         6    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         2    0.000    0.000    0.000    0.000 loops.py:871(<listcomp>)
#         9    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 lax.py:3823(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {built-in method jaxlib.mlir._mlir_libs._mlir.ir.isinstance}
#         8    0.000    0.000    0.000    0.000 loops.py:202(<genexpr>)
#         2    0.000    0.000    0.000    0.000 loops.py:869(<listcomp>)
#         9    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 sharding_impls.py:440(is_fully_addressable)
#         6    0.000    0.000    0.000    0.000 array_methods.py:431(__init__)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:2330(<genexpr>)
#         4    0.000    0.000    0.000    0.000 lax.py:3130(<genexpr>)
#         2    0.000    0.000    0.000    0.000 pxla.py:2806(<listcomp>)
#         2    0.000    0.000    0.000    0.000 loops.py:870(<listcomp>)
#         6    0.000    0.000    0.000    0.000 partial_eval.py:981(<genexpr>)
#         8    0.000    0.000    0.000    0.000 loops.py:232(<listcomp>)
#         2    0.000    0.000    0.000    0.000 prng.py:423(base_arr_shape_to_keys_shape)
#         8    0.000    0.000    0.000    0.000 loops.py:231(<listcomp>)
#         2    0.000    0.000    0.000    0.000 util.py:239(<genexpr>)
#         2    0.000    0.000    0.000    0.000 prng.py:100(__hash__)
#         6    0.000    0.000    0.000    0.000 compilation_cache.py:124(is_initialized)
#         2    0.000    0.000    0.000    0.000 pxla.py:2807(<listcomp>)
#         1    0.000    0.000    0.000    0.000 lax.py:3140(<listcomp>)
#         6    0.000    0.000    0.000    0.000 prng.py:883(random_wrap_lowering)
#         2    0.000    0.000    0.000    0.000 mlir.py:861(__len__)
#         6    0.000    0.000    0.000    0.000 mlir.py:966(<listcomp>)
#         6    0.000    0.000    0.000    0.000 mlir.py:967(<listcomp>)
#         2    0.000    0.000    0.000    0.000 pxla.py:2808(<listcomp>)
#         6    0.000    0.000    0.000    0.000 core.py:1928(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:2137(__eq__)
#         6    0.000    0.000    0.000    0.000 {method '__format__' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 compiler.py:80(get_latest_profile_version)
#         2    0.000    0.000    0.000    0.000 slicing.py:1198(<genexpr>)
#         6    0.000    0.000    0.000    0.000 lax.py:179(_identity)
#         1    0.000    0.000    0.000    0.000 dtypes.py:178(to_inexact_dtype)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:3104(_cumprod_dispatcher)
#         2    0.000    0.000    0.000    0.000 prng.py:606(__eq__)
#         6    0.000    0.000    0.000    0.000 tree_util.py:281(<lambda>)
#         4    0.000    0.000    0.000    0.000 lax.py:3149(<genexpr>)
#         4    0.000    0.000    0.000    0.000 conditionals.py:857(<listcomp>)
#         4    0.000    0.000    0.000    0.000 pjit.py:243(_get_cpp_global_cache)
#         1    0.000    0.000    0.000    0.000 loops.py:1825(_fori_body_fun)
#         2    0.000    0.000    0.000    0.000 dispatch.py:174(<listcomp>)
#         4    0.000    0.000    0.000    0.000 conditionals.py:852(<listcomp>)
#         1    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 prng.py:909(random_unwrap_impl)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:2528(<lambda>)
#         3    0.000    0.000    0.000    0.000 prng.py:913(random_unwrap_lowering)
#         3    0.000    0.000    0.000    0.000 multiarray.py:1176(packbits)
#         2    0.000    0.000    0.000    0.000 core.py:901(__init__)
#         2    0.000    0.000    0.000    0.000 slicing.py:1194(<genexpr>)
#         1    0.000    0.000    0.000    0.000 hmc.py:375(delta_mom)
#         2    0.000    0.000    0.000    0.000 lax.py:200(<genexpr>)
#         3    0.000    0.000    0.000    0.000 hmc.py:370(delta_X)
#         2    0.000    0.000    0.000    0.000 conditionals.py:836(<listcomp>)
#         2    0.000    0.000    0.000    0.000 reductions.py:185(force)
#         1    0.000    0.000    0.000    0.000 hmc.py:369(delta_fields)
#         2    0.000    0.000    0.000    0.000 inspect.py:2743(default)
#         1    0.000    0.000    0.000    0.000 mlir.py:1223(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
plt.errorbar(all_eps**2, gv.mean(m2_HMD), gv.sdev(m2_HMD), ls=' ', marker='s', color='red', label='MD')
plt.errorbar(all_eps**2, gv.mean(m2_HMC), gv.sdev(m2_HMC), ls=' ', marker='*', color='forestgreen', label='HMC')

plt.xlim(0,0.07)
plt.xlabel('$\epsilon^2$')
plt.ylabel('$<m^2>$')
plt.legend()

# %% [markdown]
# Finally the big physics result, figure 2.5!

# %%
from tqdm import tqdm

d = 3

all_kappa = np.array([0.05, 0.10, 0.15, 0.16, 0.17, 0.175, 0.18, 0.185, 0.19, 0.195, 0.2, 0.21, 0.22])
all_L = (6,8,10)

mag_k = {}
rng_key = jax.random.PRNGKey(58105)

for L in tqdm(all_L):
    mag_k[L] = []

    Lat = lat.SquareLattice(st_dims=((L,)*d))
    phi_L = lat.LatticeField(lattice=Lat, F=1)

    for k in all_kappa:
        raw_mag = []
        fields = {'phi': phi_L}
        Sk = ScalarAction(field_names=['phi'], params={'kappa': k, 'lambda': 1.1689})
    
        HMC = lhmc.HMCRewrite(
            action=Sk,
            integrator=lhmc.OmelyanIntegrator(eps=0.1, Nstep=10),
        )

        fields, _, rng_key = HMC.evolve_many(fields, rng_key, traj=100, warmup=True)
    
        for _ in range(200):
            fields, _, rng_key = HMC.evolve_many(fields, rng_key, traj=100)
            raw_mag.append(mag(fields['phi'])[0])
    
        raw_m = np.abs(np.array(raw_mag))/L**d
    
        mag_k[L].append(gv.dataset.avg_data(raw_m))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [02:04<00:00, 41.54s/it]

# %%
plt.plot(all_kappa, gv.mean(mag_k[6]), ls=' ', marker='x')
plt.plot(all_kappa, gv.mean(mag_k[8]), ls=' ', marker='o', color='red')
plt.plot(all_kappa, gv.mean(mag_k[10]), ls=' ', marker='^', color='green')

plt.xlim(0.15, 0.22)
# Out:
# (0.15, 0.22)

# %% [markdown]
# Autocorrelation analysis...

# %%
d = 3
Lat6 = lat.SquareLattice(dims=((6,)*d))
phi6 = lat.LatticeField(Lat6)

HMC = lhmc.HMCEvolver(
    action=ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689}),
    seed=21245,
    init_fields={'phi': phi6},
    integrator=lhmc.OmelyanIntegrator(eps=0.1, Nstep=10),
    observables={'mag': (mag_obs, 1)},
)

HMC.evolve(ntraj=1000, warmup=True)

for _ in tqdm(range(1000)):
    HMC.evolve(ntraj=1000)
# Out:
# 100%|██████████████████████████████████████████████████████████| 1000/1000 [03:00<00:00,  5.55it/s]

# %%
dH = np.array(HMC.monitor['delta_H'])
gv.dataset.avg_data(np.exp(-dH))
# Out:
# 1.000003(36)

# %%
m = np.array(HMC.obs_chain['mag'])[:,0]
plt.plot(m[::100])

gv.dataset.avg_data(m[::100]/6**3)
# Out:
# 0.0096(39)

# %%
mu, Ns = np.mean(m), len(m)
print(mu, Ns)

def Gamma(t):
    C1 = m - mu
    C2 = np.roll(m, t) - mu
    return gv.dataset.avg_data(C1[:Ns-t] * C2[:Ns-t] / (Ns - t))
# Out:
# 2.301753935610712 1001000

# %%
gam = [ Gamma(t)/Gamma(0) for t in range(0,1600) ]
plt.errorbar(range(0,1600), gv.mean(gam), gv.sdev(gam), ls=' ', marker='.')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def tau(W):
    return 0.5 + np.sum(gam[:W])

taus = [ tau(W) for W in range(0,1200,5) ]
plt.errorbar(range(0,1200,5), gv.mean(taus), gv.sdev(taus), ls=' ', marker='.', color='red')
# Out:
# <ErrorbarContainer object of 3 artists>
