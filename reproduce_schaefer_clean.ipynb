# %%
import lfox
import lfox.lattice as lat
import lfox.evolution.hmc as lhmc
import jax
import jax.numpy as jnp
import numpy as np

# Imports below require "dev" environment
import matplotlib.pyplot as plt
import lsqfit
import gvar as gv
import tqdm

# Double precision!
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_threefry_partitionable", True)

# Disable metal due to issues...
jax.config.update('jax_platform_name', 'cpu')

# %%
class ScalarAction(lhmc.Action):        

    @staticmethod
    @jax.jit
    def _S(fields, params):
        phi = fields[0]
        S = phi**2
        
        for ax in range(phi.d()):
            S -= 2 * params['kappa'] * phi * phi.nn_field(ax)

        S += params['lambda'] * (phi**2 - 1)**2
        return S
    
    # Exact force function instead of autodiff, for testing purposes
    @staticmethod
    @jax.jit
    def exact_force(fields, params):
        phi = fields[0]

        J = phi.nn_field(axis=0, shift=1) + phi.nn_field(axis=0, shift=-1)
        for ax in range(1,phi.d):
            J += phi.nn_field(axis=ax, shift=1)
            J += phi.nn_field(axis=ax, shift=-1)

        F = -2 * params['kappa'] * J
        F += 2 * phi.F
        F += 4 * params['lambda'] * (phi.F**2 - 1) * phi.F

        return F

# %%
# %%time

# First test case: exercise 2.5
d = 3
Lat4 = lat.SquareLattice(st_dims=((4,)*d))
phi4 = lat.LatticeField(lattice=Lat4, F=1)

S4 = ScalarAction(field_names=['phi'], params={'kappa': 0.18169, 'lambda': 1.3282})

all_Nstep = np.array([10, 20, 30, 40, 50])
all_eps = 1/all_Nstep

all_dH_leap = []
all_dH_om = []

rng_key = jax.random.PRNGKey(48119)

for eps, Nstep in zip(all_eps, all_Nstep):
    HMC_leap = lhmc.HMCRewrite(
        action=S4,
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )
    HMC_om = lhmc.HMCRewrite(
        action=S4,
        integrator=lhmc.OmelyanIntegrator(eps=eps, Nstep=Nstep),
    )

    F4 = {'phi': phi4}
    F4, monitor_leap, rng_key = HMC_leap.evolve_many(F4, rng_key, traj=50, warmup=True)

    F4 = {'phi': phi4}
    F4, monitor_om, rng_key = HMC_om.evolve_many(F4, rng_key, traj=50, warmup=True)

    abs_dH_leap = np.abs(np.array(monitor_leap['delta_H']))
    abs_dH_om = np.abs(np.array(monitor_om['delta_H']))

    all_dH_leap.append(gv.dataset.avg_data(abs_dH_leap))
    all_dH_om.append(gv.dataset.avg_data(abs_dH_om))
# Out:
# CPU times: user 21 ms, sys: 2.89 ms, total: 23.9 ms
# Wall time: 23.3 ms
# <timed exec>:4: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.

# %%
#Figure 2.2
plt.plot(all_eps**2, gv.mean(all_dH_leap), ls=' ', marker='s', color='red', label='Leapfrog')
plt.plot(all_eps**2, gv.mean(all_dH_om), ls=' ', marker='*', color='forestgreen', label='Omelyan')

def lin(x,p):
    return p['a'] + p['b']*x

fit_leap = lsqfit.nonlinear_fit(data=(all_eps**2, all_dH_leap), prior={'a': gv.gvar(0,100), 'b': gv.gvar(0,500)}, fcn=lin)
print(fit_leap)

eps_ls = np.linspace(0,0.1,100)
plt.plot(eps_ls**2, gv.mean(lin(eps_ls**2,fit_leap.p)), ls='--', color='red')

fit_om = lsqfit.nonlinear_fit(data=(all_eps**2, all_dH_om), prior={'a': gv.gvar(0,100), 'b': gv.gvar(0,500)}, fcn=lin)
print(fit_om)

plt.plot(eps_ls**2, gv.mean(lin(eps_ls**2,fit_om.p)), ls='-.', color='green')

plt.xlabel('$\\epsilon^2$')
plt.ylabel('$|\\Delta H|$')
plt.legend()
# Out:
# Least Squares Fit:
#   chi2/dof [dof] = 1.4 [5]    Q = 0.2    logGBF = 3.8548
#
# Parameters:
#               a   0.00106 (85)      [ 0 ± 1.0e+02 ]
#               b     13.3 (1.1)      [ 0 ± 5.0e+02 ]
#
# Settings:
#   svdcut/n = 1e-12/0    tol = (1e-08*,1e-10,1e-10)    (itns/time = 3/0.0s)
#   fitter = scipy_least_squares    method = trf
#
# Least Squares Fit:
#   chi2/dof [dof] = 1.2 [5]    Q = 0.31    logGBF = 10.844
#
# Parameters:
#               a   -0.000005 (104)       [ 0 ± 1.0e+02 ]
#               b         1.74 (14)       [ 0 ± 5.0e+02 ]
#
# Settings:
#   svdcut/n = 1e-12/0    tol = (1e-08,1e-10*,1e-10)    (itns/time = 3/0.0s)
#   fitter = scipy_least_squares    method = trf

# %% [markdown]
# Another technical plot first: let's do figure 2.4.

# %%
# %%time

# First test case: exercise 2.5
d = 3
Lat6 = lat.SquareLattice(st_dims=((6,)*d))
phi6 = lat.LatticeField(lattice=Lat6, F=1)

S6 = ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689})

all_Nstep = np.array([4, 5, 7, 8, 10, 20, 30, 40, 50])
all_eps = 1/all_Nstep

all_acc_rate = []
rng_key = jax.random.PRNGKey(11134)

for eps, Nstep in zip(all_eps, all_Nstep):
    F6 = {'phi': phi6}
    HMC = lhmc.HMCRewrite(
        action=S6,
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )

#    acc_rate = []
    F6, mon, rng_key = HMC.evolve_many(F6, rng_key, traj=1000, warmup=False)
    all_acc_rate.append(np.mean(mon['accept']))
#    for _ in range(1000):
#        F6, mon, rng_key = HMC.evolve(F6, rng_key, warmup=False)
#        acc_rate.append(mon['accept'])

#    all_acc_rate.append(np.mean(np.array(acc_rate)))
# Out:
# CPU times: user 9.62 ms, sys: 3.14 ms, total: 12.8 ms
# Wall time: 7.9 ms
# <timed exec>:4: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.

# %%
plt.plot(all_eps**2, all_acc_rate, ls=' ', marker='o')

plt.xlabel('$\epsilon^2$')
plt.ylabel('acc rate')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\e'
# <>:3: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/vz/k6mgc8_d28v0gskwh5xd08mr0000gn/T/ipykernel_28206/1767568451.py:3: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\epsilon^2$')
# Text(0, 0.5, 'acc rate')

# %%
plt.plot(all_eps**2, 1/all_eps/all_acc_rate, ls=' ', marker='x')
plt.xlabel('$\\epsilon^2$')
plt.ylabel('$1/\\epsilon/$ acc rate [cost]')
# Out:
# Text(0, 0.5, '$1/\\epsilon/$ acc rate [cost]')

# %% [markdown]
# Some additional technical tests.  Let's verify that $e^{-\Delta H}$ averages to 1 properly.

# %%
# %%time
HMC = lhmc.HMCRewrite(
    action=ScalarAction(field_names=['phi'], params={'kappa': 0.18, 'lambda': 1.145}),
    integrator=lhmc.LeapfrogIntegrator(eps=0.1, Nstep=10),
)

Ftest = {'phi': phi6}
rng_key = jax.random.PRNGKey(21245)
dH_array = []
for _ in range(10000):
    Ftest, mon, rng_key = HMC.evolve(Ftest, rng_key, warmup=False)
    dH_array.append(mon['delta_H'])
# Out:
# CPU times: user 1.23 s, sys: 220 ms, total: 1.45 s
# Wall time: 607 ms

# %%
edH = np.exp(-np.array(dH_array))
plt.plot(edH[10:])
gv.dataset.avg_data(edH[100::50])  # Block by 50, should be consistent with 1
# Out:
# 0.995(23)

# %% [markdown]
# Now on to figure 2.3 and comparing HMC to MD.

# %%
@jax.jit
def mag(phi):
    m = jnp.sum(phi.F)
    return jnp.array([m, m**2, m**4])

def mag_obs(fields, params):
    return mag(fields['phi'])

# %%
# %%prun -s cumulative

# Second test case: figure 2.3
d = 3
Lat6 = lat.SquareLattice(st_dims=((6,)*d))
phi6 = lat.LatticeField(lattice=Lat6, F=1)

all_Nstep = np.array([4,5,6,7,8,10])
all_eps = 1/all_Nstep
m2_HMC = []
m2_HMD = []

raw_HMC = []
mon_HMC = []

rng_key = jax.random.PRNGKey(73645)
F6_HMC = {'phi': phi6}
F6_HMD = {'phi': phi6}

for eps, Nstep in zip(all_eps, all_Nstep):
    print(eps, Nstep)

    raw_m2_HMC = []
    raw_m2_HMD = []

    # Only need one HMC object, HMD is the same thing but with warmups off
    HMC = lhmc.HMCRewrite(
        action=ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689}),
        integrator=lhmc.LeapfrogIntegrator(eps=eps, Nstep=Nstep),
    )
        
    for t in range(1000):
        F6_HMC, _, rng_key = HMC.evolve_many(F6_HMC, rng_key, traj=100, warmup=False)
        F6_HMD, _, rng_key = HMC.evolve_many(F6_HMD, rng_key, traj=100, warmup=True)

        raw_m2_HMC.append(mag(F6_HMC['phi'])[1]/6**d)
        raw_m2_HMD.append(mag(F6_HMD['phi'])[1]/6**d)
    
    m2_HMC.append(gv.dataset.avg_data(raw_m2_HMC))
    m2_HMD.append(gv.dataset.avg_data(raw_m2_HMD))
# Out:
# <string>:4: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
# 0.25 4
# 0.2 5
# 0.16666666666666666 6
# 0.14285714285714285 7
# 0.125 8
# 0.1 10
#          3455826 function calls (3451618 primitive calls) in 33.706 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     12000    0.025    0.000   15.812    0.001 array.py:346(__getitem__)
#     12000    0.007    0.000   15.765    0.001 indexing.py:616(rewriting_take)
#     12000    0.139    0.000   15.757    0.001 indexing.py:525(_attempt_rewriting_take_via_slice)
# 24223/24221    0.019    0.000   15.432    0.001 core.py:494(bind)
# 24223/24221    0.025    0.000   15.345    0.001 core.py:498(_true_bind)
# 24223/24221    0.007    0.000   15.299    0.001 core.py:516(bind_with_trace)
#     24011    0.022    0.000   15.273    0.001 core.py:1008(process_primitive)
#     12008    0.008    0.000   15.224    0.001 slicing.py:57(slice)
#     24009   15.106    0.001   15.189    0.001 dispatch.py:82(apply_primitive)
#     12000    0.030    0.000   15.115    0.001 slicing.py:1427(_slice_impl)
#         1    0.000    0.000    6.954    6.954 {built-in method builtins.exec}
#         1    3.524    3.524    6.954    6.954 <string>:1(<module>)
#     116/6    0.000    0.000    1.032    0.172 traceback_util.py:178(reraise_with_filtered_traceback)
#      93/6    0.000    0.000    1.032    0.172 pjit.py:333(cache_miss)
#      93/6    0.001    0.000    1.032    0.172 pjit.py:177(_python_pjit_helper)
#         6    0.000    0.000    1.001    0.167 pjit.py:1776(_pjit_call_impl_python)
# 12086/12024    0.007    0.000    0.984    0.000 profiler.py:331(wrapper)
#         6    0.000    0.000    0.760    0.127 pxla.py:2457(compile)
#         6    0.000    0.000    0.760    0.127 pxla.py:2947(from_hlo)
#         6    0.000    0.000    0.759    0.126 pxla.py:2777(_cached_compilation)
#         6    0.000    0.000    0.757    0.126 compiler.py:354(compile_or_get_cached)
#         6    0.000    0.000    0.678    0.113 compiler.py:685(_compile_and_write_cache)
#         6    0.677    0.113    0.678    0.113 compiler.py:287(backend_compile)
#     12008    0.018    0.000    0.241    0.000 lax.py:3503(squeeze)
#         6    0.000    0.000    0.240    0.040 pjit.py:1758(_resolve_and_lower)
#         6    0.000    0.000    0.240    0.040 pjit.py:1883(_pjit_lower)
#         6    0.000    0.000    0.240    0.040 pxla.py:2214(lower_sharding_computation)
#         6    0.000    0.000    0.236    0.039 pxla.py:1898(_cached_lowering_to_hlo)
#         6    0.001    0.000    0.236    0.039 mlir.py:1108(lower_jaxpr_to_module)
#     160/6    0.006    0.000    0.226    0.038 mlir.py:1393(lower_jaxpr_to_fun)
#     207/6    0.020    0.000    0.225    0.037 mlir.py:1884(jaxpr_subcomp)
#   2039/13    0.006    0.000    0.223    0.017 mlir.py:2037(lower_per_platform)
#      19/3    0.000    0.000    0.223    0.074 mlir.py:2195(f_lowered)
#       9/2    0.001    0.000    0.218    0.109 loops.py:1854(_while_lowering)
#       7/2    0.000    0.000    0.216    0.108 mlir.py:2323(core_call_lowering)
#       7/2    0.000    0.000    0.216    0.108 mlir.py:2302(call_lowering)
#       7/2    0.000    0.000    0.216    0.108 mlir.py:2273(lower_called_computation)
#       7/2    0.000    0.000    0.216    0.108 mlir.py:2237(_lower_jaxpr_to_fun_cached)
#     278/2    0.003    0.000    0.212    0.106 pjit.py:2056(_pjit_lowering)
#     278/2    0.001    0.000    0.212    0.106 pjit.py:2023(_pjit_cached_lower_jaxpr_to_fun)
#     60173    0.134    0.000    0.199    0.000 _module.py:498(flatten_module)
#     12066    0.083    0.000    0.118    0.000 array_methods.py:574(deferring_binary_op)
#     56152    0.022    0.000    0.116    0.000 {jaxlib.utils.safe_map}
#     44/25    0.001    0.000    0.063    0.003 partial_eval.py:2208(trace_to_jaxpr_dynamic)
# 440918/440862    0.048    0.000    0.062    0.000 {built-in method builtins.isinstance}
#     24214    0.014    0.000    0.059    0.000 core.py:1779(canonicalize_value)
#     44/25    0.000    0.000    0.058    0.002 linear_util.py:209(call_wrapped)
#     44/25    0.001    0.000    0.058    0.002 linear_util.py:400(_get_result_paths_thunk)
#    550096    0.055    0.000    0.058    0.000 {method 'get' of 'dict' objects}
# 26493/26484    0.023    0.000    0.052    0.000 util.py:275(wrapper)
#     12000    0.007    0.000    0.049    0.000 array.py:309(__float__)
#         3    0.000    0.000    0.047    0.016 prng.py:609(random_split_lowering)
#         3    0.000    0.000    0.046    0.015 mlir.py:142(delegate_lowering)
#     25349    0.012    0.000    0.041    0.000 core.py:1556(get_aval)
#     60035    0.017    0.000    0.038    0.000 <string>:2(__eq__)
#     93/46    0.000    0.000    0.036    0.001 pjit.py:708(_infer_params)
#     93/46    0.002    0.000    0.036    0.001 pjit.py:718(_infer_params_internal)
#     17/16    0.000    0.000    0.034    0.002 common.py:51(_initial_style_open_jaxpr)
# 34199/34127    0.014    0.000    0.033    0.000 {built-in method builtins.all}
#      1092    0.003    0.000    0.033    0.000 lax.py:4056(_nary_lower_hlo)
#     12018    0.026    0.000    0.031    0.000 array.py:634(_value)
#      2039    0.003    0.000    0.030    0.000 mlir.py:497(_source_info_to_location)
#       8/6    0.000    0.000    0.030    0.005 pjit.py:561(_infer_params_impl)
#       8/6    0.000    0.000    0.029    0.005 linear_util.py:467(memoized_fun)
#       8/6    0.000    0.000    0.029    0.005 pjit.py:1420(_create_pjit_jaxpr)
#     17/16    0.000    0.000    0.029    0.002 api_util.py:86(flatten_fun_nokwargs)
#     24339    0.028    0.000    0.028    0.000 config.py:218(trace_context)
#      12/6    0.000    0.000    0.028    0.005 api_util.py:277(_argnums_partial)
#       8/6    0.000    0.000    0.028    0.005 api_util.py:69(flatten_fun)
#    266431    0.028    0.000    0.028    0.000 {method 'append' of 'list' objects}
#       8/7    0.000    0.000    0.026    0.004 loops.py:2125(fori_loop)
#       4/2    0.000    0.000    0.026    0.013 api_util.py:311(_argnames_partial)
#         2    0.000    0.000    0.026    0.013 hmc.py:431(evolve_many)
#         7    0.000    0.000    0.026    0.004 loops.py:112(scan)
#     49739    0.015    0.000    0.026    0.000 {built-in method builtins.any}
#     12053    0.023    0.000    0.025    0.000 _module.py:918(_unflatten_module)
#         3    0.000    0.000    0.024    0.008 prng.py:688(random_bits_lowering)
#         7    0.000    0.000    0.022    0.003 loops.py:277(_create_jaxpr)
#         7    0.000    0.000    0.022    0.003 common.py:73(_initial_style_jaxpr_attrs)
#      1185    0.002    0.000    0.021    0.000 mlir.py:2409(multi_broadcast_in_dim)
#     12028    0.010    0.000    0.021    0.000 numerictypes.py:471(issubdtype)
#     48013    0.012    0.000    0.021    0.000 array.py:269(ndim)
#     24021    0.010    0.000    0.021    0.000 array.py:1093(_get_aval_array)
#     12007    0.004    0.000    0.021    0.000 lattice.py:74(__eq__)
#         2    0.000    0.000    0.020    0.010 loops.py:2120(scanned_fun)
#         2    0.000    0.000    0.019    0.010 hmc.py:439(ev_loop)
#         8    0.000    0.000    0.019    0.002 loops.py:1358(while_loop)
#      2039    0.007    0.000    0.018    0.000 mlir.py:454(_traceback_to_location)
#         7    0.000    0.000    0.018    0.003 loops.py:475(_scan_impl)
#     12226    0.007    0.000    0.017    0.000 {built-in method builtins.sorted}
#     12194    0.011    0.000    0.017    0.000 fromnumeric.py:2118(shape)
#         8    0.000    0.000    0.017    0.002 loops.py:1424(_create_jaxpr)
#        66    0.000    0.000    0.016    0.000 array_methods.py:1059(op)
#     48534    0.015    0.000    0.015    0.000 core.py:1115(set_trace)
#     24067    0.010    0.000    0.015    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       731    0.001    0.000    0.015    0.000 mlir.py:2380(broadcast_in_dim)
#        15    0.000    0.000    0.015    0.001 common.py:63(_initial_style_jaxpr)
#       212    0.000    0.000    0.015    0.000 partial_eval.py:1966(process_primitive)
#      3096    0.001    0.000    0.014    0.000 mlir.py:222(aval_to_ir_type)
#     12028    0.004    0.000    0.014    0.000 sharding_impls.py:1157(is_single_device_sharding)
#     55/41    0.001    0.000    0.014    0.000 _module.py:561(__call__)
#     12203    0.003    0.000    0.014    0.000 <frozen abc>:117(__instancecheck__)
# 159577/159576    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#      3096    0.004    0.000    0.013    0.000 mlir.py:209(_array_ir_types)
#     12000    0.004    0.000    0.011    0.000 indexing.py:505(_is_valid_integer_index_for_slice)
#     12203    0.005    0.000    0.011    0.000 {built-in method _abc._abc_instancecheck}
#     24056    0.006    0.000    0.011    0.000 numerictypes.py:289(issubclass_)
#     29208    0.007    0.000    0.010    0.000 mesh.py:487(empty)
#      2324    0.003    0.000    0.010    0.000 core.py:1912(__init__)
#     24016    0.005    0.000    0.010    0.000 lax.py:3506(<genexpr>)
#         5    0.000    0.000    0.010    0.002 prng.py:866(_threefry2x32_lowering)
#         1    0.000    0.000    0.010    0.010 hmc.py:405(evolve)
#      29/4    0.000    0.000    0.009    0.002 _module.py:1058(__call__)
#     12111    0.003    0.000    0.009    0.000 fromnumeric.py:3523(ndim)
#     55/41    0.000    0.000    0.009    0.000 _better_abstract.py:220(__call__)
#        48    0.000    0.000    0.009    0.000 ufunc_api.py:173(__call__)
#       135    0.000    0.000    0.009    0.000 api_util.py:593(debug_info)
#      2051    0.003    0.000    0.009    0.000 source_info_util.py:121(__str__)
#     12966    0.007    0.000    0.009    0.000 dtypes.py:800(dtype)
#     84029    0.009    0.000    0.009    0.000 array.py:261(shape)
#     24106    0.009    0.000    0.009    0.000 {built-in method numpy.array}
#      6767    0.003    0.000    0.009    0.000 {jaxlib.utils.foreach}
#         1    0.000    0.000    0.008    0.008 hmc.py:386(MD_traj)
#         6    0.000    0.000    0.008    0.001 mlir.py:729(__init__)
#         6    0.000    0.000    0.008    0.001 array_methods.py:789(set)
#         6    0.000    0.000    0.008    0.001 scatter.py:45(_scatter_update)
#     24039    0.004    0.000    0.008    0.000 core.py:1512(update_aval_with_sharding)
#         6    0.008    0.001    0.008    0.001 mlir.py:602(make_ir_context)
#        44    0.000    0.000    0.008    0.000 partial_eval.py:2169(to_jaxpr)
#        44    0.001    0.000    0.008    0.000 partial_eval.py:1722(to_jaxpr)
#       141    0.001    0.000    0.008    0.000 partial_eval.py:1974(default_process_primitive)
#     24017    0.005    0.000    0.008    0.000 core.py:1001(check_eval_args)
#     12009    0.004    0.000    0.008    0.000 sharding_impls.py:162(num_devices)
#      5102    0.002    0.000    0.008    0.000 mlir.py:1901(read)
#         6    0.000    0.000    0.007    0.001 scatter.py:85(_scatter_impl)
#     12000    0.005    0.000    0.007    0.000 indexing.py:497(_is_integer_index)
#     31/29    0.000    0.000    0.007    0.000 events.py:86(_run)
#      4244    0.001    0.000    0.007    0.000 core.py:2295(is_constant_shape)
#     31/29    0.000    0.000    0.007    0.000 {method 'run' of '_contextvars.Context' objects}
#       135    0.001    0.000    0.007    0.000 api_util.py:669(_non_static_arg_names)
#     24022    0.004    0.000    0.007    0.000 core.py:1401(full_lower)
#     13755    0.007    0.000    0.007    0.000 _module.py:634(__getattribute__)
#     60104    0.007    0.000    0.007    0.000 array.py:277(sharding)
#     12337    0.006    0.000    0.006    0.000 {built-in method numpy.asarray}
#     36172    0.006    0.000    0.006    0.000 {built-in method builtins.issubclass}
#        16    0.000    0.000    0.006    0.000 zmqstream.py:573(_handle_events)
#     17270    0.005    0.000    0.005    0.000 {jaxlib.utils.safe_zip}
#     33/30    0.000    0.000    0.005    0.000 lax_numpy.py:5372(array)
#     12019    0.004    0.000    0.005    0.000 util.py:372(canonicalize_axis)
#      6946    0.001    0.000    0.005    0.000 mlir.py:1913(aval)
#        44    0.001    0.000    0.005    0.000 partial_eval.py:1839(_inline_literals)
#     24000    0.004    0.000    0.005    0.000 indexing.py:595(<genexpr>)
#        15    0.000    0.000    0.005    0.000 asyncio.py:206(_handle_events)
#     38001    0.005    0.000    0.005    0.000 {built-in method builtins.hasattr}
#     27736    0.003    0.000    0.005    0.000 mlir.py:446(_is_user_file)
#     12000    0.001    0.000    0.005    0.000 core.py:700(check_scalar_conversion)
#         7    0.000    0.000    0.005    0.001 loops.py:527(cond_fun)
#      1092    0.001    0.000    0.005    0.000 lax.py:4046(multi_sharding_in_dim)
#       799    0.000    0.000    0.005    0.000 core.py:1550(abstractify)
#     19928    0.003    0.000    0.005    0.000 source_info_util.py:89(wrap)
#       103    0.000    0.000    0.005    0.000 core.py:548(abstract_eval_)
#     14745    0.002    0.000    0.004    0.000 core.py:2297(<genexpr>)
#         6    0.000    0.000    0.004    0.001 compiler.py:464(_resolve_compilation_strategy)
#         6    0.000    0.000    0.004    0.001 compiler.py:543(_get_cache_key)
#        80    0.000    0.000    0.004    0.000 lax.py:1656(_convert_element_type)
#         6    0.000    0.000    0.004    0.001 compilation_cache.py:284(get_cache_key)
#         6    0.000    0.000    0.004    0.001 cache_key.py:74(get)
#         6    0.000    0.000    0.004    0.001 indexing.py:768(index_to_gather)
#     24026    0.004    0.000    0.004    0.000 array.py:604(_check_if_deleted)
#     24000    0.003    0.000    0.004    0.000 indexing.py:529(<genexpr>)
#         1    0.000    0.000    0.004    0.004 hmc.py:272(integrate)
#      3636    0.004    0.000    0.004    0.000 mlir.py:2346(wrap_compute_type_in_place)
#        87    0.001    0.000    0.004    0.000 pjit.py:1910(pjit_staging_rule)
#        19    0.000    0.000    0.004    0.000 lax.py:2692(broadcast_in_dim)
#     12018    0.002    0.000    0.004    0.000 array.py:399(is_fully_replicated)
#   290/272    0.000    0.000    0.004    0.000 mlir.py:257(ir_constant)
#      2380    0.001    0.000    0.004    0.000 core.py:2302(definitely_equal_shape)
#         6    0.000    0.000    0.004    0.001 cache_key.py:103(<lambda>)
#         6    0.000    0.000    0.004    0.001 cache_key.py:214(_hash_computation)
#     29349    0.003    0.000    0.003    0.000 mesh.py:469(size)
#        79    0.000    0.000    0.003    0.000 utils.py:104(standard_abstract_eval)
#         2    0.000    0.000    0.003    0.002 hmc.py:349(H_density)
#         7    0.000    0.000    0.003    0.000 lattice.py:145(__post_init__)
#        13    0.000    0.000    0.003    0.000 dataclasses.py:1540(replace)
#     12000    0.002    0.000    0.003    0.000 indexing.py:534(<genexpr>)
#         6    0.000    0.000    0.003    0.001 lattice.py:276(copy_new_F)
#     12000    0.002    0.000    0.003    0.000 indexing.py:500(_is_simple_reverse_slice)
#         1    0.000    0.000    0.003    0.003 hmc.py:275(_integrate)
#     12000    0.002    0.000    0.003    0.000 indexing.py:519(_is_contiguous_slice)
#       708    0.001    0.000    0.003    0.000 abstract_arrays.py:55(_make_shaped_array_for_numpy_array)
#      4580    0.002    0.000    0.003    0.000 mlir.py:883(flatten_ir_values)
#         6    0.002    0.000    0.003    0.001 cache_key.py:202(_canonicalize_ir)
#       731    0.001    0.000    0.003    0.000 _stablehlo_ops_gen.py:736(broadcast_in_dim)
#       272    0.000    0.000    0.003    0.000 mlir.py:292(_ndarray_constant_handler)
#      3368    0.002    0.000    0.003    0.000 mlir.py:195(dtype_to_ir_type)
#       272    0.001    0.000    0.003    0.000 mlir.py:276(_numpy_array_constant)
#         7    0.000    0.000    0.003    0.000 mlir.py:2196(<lambda>)
#         1    0.000    0.000    0.003    0.003 lattice.py:63(__post_init__)
#       136    0.000    0.000    0.003    0.000 inspect.py:3272(bind)
#         1    0.000    0.000    0.003    0.003 lax_numpy.py:6680(meshgrid)
#       141    0.002    0.000    0.003    0.000 inspect.py:3133(_bind)
#        12    0.002    0.000    0.003    0.000 _function_base_impl.py:2680(cov)
#       669    0.000    0.000    0.003    0.000 partial_eval.py:1902(to_jaxpr_tracer)
#        93    0.000    0.000    0.003    0.000 lax.py:4727(_compare_lower_hlo)
#       720    0.001    0.000    0.003    0.000 linear_util.py:396(_clean_keystr_arg_names)
#     13548    0.003    0.000    0.003    0.000 {built-in method __new__ of type object at 0x104a223f8}
#       167    0.000    0.000    0.003    0.000 lax.py:6513(_broadcast_in_dim_lower)
#     12009    0.003    0.000    0.003    0.000 sharding_impls.py:166(device_set)
#         6    0.000    0.000    0.003    0.000 indexing.py:189(_normalize_index)
#       247    0.000    0.000    0.003    0.000 abstract_arrays.py:75(_make_abstract_python_scalar)
#        29    0.000    0.000    0.002    0.000 _module.py:695(__get__)
#       356    0.000    0.000    0.002    0.000 core.py:1702(update_weak_type)
#        16    0.000    0.000    0.002    0.000 zmqstream.py:614(_handle_recv)
#      30/3    0.000    0.000    0.002    0.001 base_events.py:1922(_run_once)
#      6347    0.001    0.000    0.002    0.000 mlir.py:1992(<genexpr>)
#        33    0.000    0.000    0.002    0.000 lax.py:4873(_convert_element_type_bind_with_trace)
#      3143    0.001    0.000    0.002    0.000 core.py:1639(physical_aval)
#      2041    0.001    0.000    0.002    0.000 mlir.py:1379(subset)
#         3    0.000    0.000    0.002    0.001 prng.py:692(<lambda>)
#       359    0.000    0.000    0.002    0.000 core.py:1920(update)
#         3    0.000    0.000    0.002    0.001 prng.py:1151(threefry_random_bits)
#         3    0.000    0.000    0.002    0.001 prng.py:1163(_threefry_random_bits_partitionable)
#       683    0.000    0.000    0.002    0.000 api_util.py:715(<genexpr>)
#        44    0.000    0.000    0.002    0.000 dtypes.py:824(_lattice_result_type)
#      2381    0.001    0.000    0.002    0.000 core.py:1724(canonicalize_shape)
#      2627    0.002    0.000    0.002    0.000 mlir.py:2113(<lambda>)
#         3    0.000    0.000    0.002    0.001 lattice.py:193(op)
#     10540    0.002    0.000    0.002    0.000 core.py:2284(is_constant_dim)
#       731    0.002    0.000    0.002    0.000 _stablehlo_ops_gen.py:707(__init__)
#        71    0.001    0.000    0.002    0.000 partial_eval.py:2615(inline_jaxpr_into_trace)
#        15    0.000    0.000    0.002    0.000 loops.py:389(_check_carry_type)
#        93    0.000    0.000    0.002    0.000 partial_eval.py:1921(new_const)
#         3    0.000    0.000    0.002    0.001 lattice.py:187(op)
#        59    0.000    0.000    0.002    0.000 inspect.py:3343(signature)
#        59    0.000    0.000    0.002    0.000 inspect.py:3081(from_callable)
#     24000    0.002    0.000    0.002    0.000 indexing.py:538(<genexpr>)
#     24000    0.002    0.000    0.002    0.000 indexing.py:531(<genexpr>)
#     64/59    0.000    0.000    0.002    0.000 inspect.py:2501(_signature_from_callable)
#       137    0.000    0.000    0.002    0.000 core.py:2725(typematch)
#        16    0.000    0.000    0.002    0.000 zmqstream.py:546(_run_callback)
#      3364    0.002    0.000    0.002    0.000 named_sharding.py:154(__eq__)
#       862    0.001    0.000    0.002    0.000 pxla.py:1856(__hash__)
#     24779    0.002    0.000    0.002    0.000 {built-in method _operator.index}
#         6    0.002    0.000    0.002    0.000 mlir.py:578(module_to_bytecode)
#      1151    0.000    0.000    0.002    0.000 partial_eval.py:1857(<lambda>)
#        79    0.000    0.000    0.002    0.000 utils.py:84(call_shape_dtype_sharding_rule)
#       586    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:3433(multiply)
#      2081    0.001    0.000    0.002    0.000 mlir.py:2647(lower_with_sharding_in_types)
#       274    0.000    0.000    0.002    0.000 core.py:1451(normalize)
#        44    0.000    0.000    0.002    0.000 api_util.py:624(fun_signature)
#         7    0.000    0.000    0.002    0.000 loops.py:515(body_fun)
#       695    0.000    0.000    0.002    0.000 dtypes.py:825(<genexpr>)
#       286    0.000    0.000    0.002    0.000 func.py:255(__init__)
#       274    0.000    0.000    0.002    0.000 core.py:1448(strip_weak_type)
#       272    0.000    0.000    0.002    0.000 _stablehlo_ops_gen.py:1369(constant)
#       161    0.001    0.000    0.002    0.000 func.py:95(add_entry_block)
#       216    0.000    0.000    0.002    0.000 linear_util.py:403(<genexpr>)
#         4    0.000    0.000    0.002    0.000 prng.py:1035(iota_2x32_shape_lowering)
#         7    0.000    0.000    0.002    0.000 array_creation.py:82(ones)
#       131    0.001    0.000    0.002    0.000 {built-in method builtins.dir}
#        26    0.000    0.000    0.002    0.000 lax_numpy.py:5635(asarray)
#         8    0.000    0.000    0.002    0.000 lax.py:3319(full)
#      4314    0.001    0.000    0.002    0.000 source_info_util.py:146(replace)
#         8    0.000    0.000    0.002    0.000 ioloop.py:750(_run_callback)
#      2958    0.001    0.000    0.002    0.000 mlir.py:1358(__init__)
#      2039    0.001    0.000    0.002    0.000 source_info_util.py:115(__add__)
#       651    0.000    0.000    0.002    0.000 dtypes.py:592(_dtype_and_weaktype)
#       333    0.001    0.000    0.002    0.000 dtypes.py:345(_scalar_type_to_dtype)
#        44    0.000    0.000    0.002    0.000 partial_eval.py:2475(_input_type_to_tracers)
#         2    0.000    0.000    0.002    0.001 hmc.py:376(delta_P)
#        95    0.000    0.000    0.002    0.000 mlir.py:2437(slice_op)
#        44    0.001    0.000    0.002    0.000 partial_eval.py:1786(_const_folding_and_forwarding)
#      2039    0.001    0.000    0.002    0.000 core.py:3367(clean_up_dead_vars)
#      3695    0.001    0.000    0.002    0.000 core.py:1416(definitely_equal)
#         6    0.002    0.000    0.002    0.000 cache_key.py:192(_serialize_ir)
#      2324    0.000    0.000    0.002    0.000 core.py:1897(get_vma)
#      2039    0.001    0.000    0.002    0.000 source_info_util.py:244(__enter__)
#      2119    0.001    0.000    0.001    0.000 dtypes.py:404(issubdtype)
#        33    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#       272    0.001    0.000    0.001    0.000 _stablehlo_ops_gen.py:1342(__init__)
#      5608    0.001    0.000    0.001    0.000 mlir.py:154(_is_ir_values)
#        71    0.000    0.000    0.001    0.000 slicing.py:1438(_slice_lower)
#         6    0.000    0.000    0.001    0.000 pxla.py:1779(_dce_jaxpr)
#     20/14    0.000    0.000    0.001    0.000 partial_eval.py:1416(dce_jaxpr)
#       286    0.001    0.000    0.001    0.000 _func_ops_gen.py:105(__init__)
#     19/13    0.000    0.000    0.001    0.000 partial_eval.py:1453(_dce_jaxpr)
#      4659    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#       239    0.001    0.000    0.001    0.000 partial_eval.py:1914(new_arg)
#        93    0.000    0.000    0.001    0.000 pjit.py:746(_infer_input_type)
#         7    0.000    0.000    0.001    0.000 iostream.py:616(_flush)
#         6    0.000    0.000    0.001    0.000 pxla.py:1769(prune_unused_inputs)
#         6    0.000    0.000    0.001    0.000 partial_eval.py:1436(dce_jaxpr_consts)
#        28    0.000    0.000    0.001    0.000 typing.py:1221(__instancecheck__)
#         3    0.000    0.000    0.001    0.000 lax_numpy.py:6225(arange)
#        28    0.000    0.000    0.001    0.000 typing.py:1492(__subclasscheck__)
#       207    0.001    0.000    0.001    0.000 core.py:3357(last_used)
#        59    0.000    0.000    0.001    0.000 inspect.py:2397(_signature_from_function)
#       586    0.001    0.000    0.001    0.000 _stablehlo_ops_gen.py:3410(__init__)
#         3    0.000    0.000    0.001    0.000 lax_numpy.py:6305(_arange)
#        33    0.001    0.000    0.001    0.000 attrsettr.py:66(_get_attr_opt)
#       187    0.000    0.000    0.001    0.000 core.py:1530(shaped_abstractify)
#         1    0.000    0.000    0.001    0.001 loops.py:2112(while_body_fun)
#      3648    0.001    0.000    0.001    0.000 mlir.py:1919(write)
#        12    0.000    0.000    0.001    0.000 lax.py:3841(<genexpr>)
#     12000    0.001    0.000    0.001    0.000 indexing.py:557(<genexpr>)
#      2039    0.001    0.000    0.001    0.000 source_info_util.py:249(__exit__)
#     12194    0.001    0.000    0.001    0.000 fromnumeric.py:2114(_shape_dispatcher)
#         8    0.000    0.000    0.001    0.000 slicing.py:977(index_in_dim)
#       533    0.001    0.000    0.001    0.000 source_info_util.py:216(current)
#        93    0.001    0.000    0.001    0.000 mlir.py:2556(compare_hlo)
#         6    0.000    0.000    0.001    0.000 lax_numpy.py:2290(squeeze)
#        17    0.000    0.000    0.001    0.000 zmqstream.py:653(_rebuild_io_state)
#       300    0.000    0.000    0.001    0.000 partial_eval.py:1956(makevar)
#      2324    0.001    0.000    0.001    0.000 core.py:1660(_dtype_object)
#      2799    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#       377    0.000    0.000    0.001    0.000 tree_util.py:1116(generate_key_paths)
#      2058    0.001    0.000    0.001    0.000 core.py:292(__enter__)
#         1    0.000    0.000    0.001    0.001 hmc.py:361(momentum_refresh)
#       621    0.000    0.000    0.001    0.000 partial_eval.py:1762(newvar)
#       161    0.000    0.000    0.001    0.000 func.py:38(__init__)
#         1    0.000    0.000    0.001    0.001 hmc.py:283(mid_step)
#       476    0.001    0.000    0.001    0.000 mlir.py:920(unflatten_ir_values_like_types)
#       647    0.000    0.000    0.001    0.000 partial_eval.py:1859(<lambda>)
#      2638    0.001    0.000    0.001    0.000 mlir.py:2117(<lambda>)
#     12111    0.001    0.000    0.001    0.000 fromnumeric.py:3519(_ndim_dispatcher)
#         6    0.000    0.000    0.001    0.000 slicing.py:800(scatter)
#      2058    0.001    0.000    0.001    0.000 core.py:320(__exit__)
#       726    0.001    0.000    0.001    0.000 {method 'sub' of 're.Pattern' objects}
#       720    0.001    0.000    0.001    0.000 tree_util.py:719(keystr)
#         1    0.000    0.000    0.001    0.001 2186373298.py:1(mag)
#       377    0.000    0.000    0.001    0.000 tree_util.py:1107(tree_leaves_with_path)
# 3038/3001    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#       269    0.000    0.000    0.001    0.000 xla.py:95(canonicalize_dtype)
#        77    0.001    0.000    0.001    0.000 socket.py:623(send)
#         6    0.000    0.000    0.001    0.000 pxla.py:1279(__call__)
# 2944/2753    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.001    0.000 prng.py:1027(bcast_iotas_to_reshaped_iota)
#        12    0.000    0.000    0.001    0.000 lax.py:1621(convert_element_type)
#        49    0.000    0.000    0.001    0.000 tree_util.py:87(tree_leaves)
#        15    0.000    0.000    0.001    0.000 lax.py:6448(_broadcast_in_dim_staging_rule)
#      2638    0.001    0.000    0.001    0.000 mlir.py:98(_is_not_block_argument)
#         7    0.000    0.000    0.001    0.000 session.py:754(send)
#         2    0.000    0.000    0.001    0.000 loops.py:1042(_scan_dce_rule)
#       724    0.001    0.000    0.001    0.000 util.py:146(split_list)
#         3    0.000    0.000    0.001    0.000 lax.py:3376(iota)
#       392    0.001    0.000    0.001    0.000 tree_util.py:1099(tree_flatten_with_path)
#         6    0.000    0.000    0.001    0.000 pxla.py:2731(create_compile_options)
#       572    0.000    0.000    0.001    0.000 partial_eval.py:1856(<lambda>)
#       587    0.000    0.000    0.001    0.000 mlir.py:1099(_get_unconstrained_variants)
#        72    0.000    0.000    0.001    0.000 lax.py:4902(_convert_element_type_lower)
#       619    0.000    0.000    0.001    0.000 mlir.py:893(flatten_ir_types)
#         7    0.000    0.000    0.001    0.000 lax.py:1173(add)
#        79    0.000    0.000    0.001    0.000 utils.py:68(call_sharding_rule)
#       557    0.000    0.000    0.001    0.000 mlir.py:1874(__eq__)
#         3    0.000    0.000    0.001    0.000 lax.py:3383(broadcasted_iota)
#         9    0.000    0.000    0.001    0.000 lax.py:3511(expand_dims)
#        17    0.000    0.000    0.001    0.000 zmqstream.py:676(_update_handler)
#      2058    0.001    0.000    0.001    0.000 core.py:340(manager)
#      3880    0.000    0.000    0.001    0.000 pxla.py:1857(<genexpr>)
#      3236    0.001    0.000    0.001    0.000 _ods_common.py:78(get_default_loc_context)
#        15    0.000    0.000    0.001    0.000 loops.py:82(_promote_weak_typed_inputs)
#       874    0.001    0.000    0.001    0.000 core.py:1943(__eq__)
#       159    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:78(add)
#       213    0.000    0.000    0.001    0.000 partial_eval.py:1716(add_eqn)
#        32    0.000    0.000    0.001    0.000 lax.py:4507(_integer_pow_lowering)
#        16    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        25    0.000    0.000    0.001    0.000 interactiveshell.py:3025(write)
#       680    0.000    0.000    0.001    0.000 core.py:1950(__hash__)
#         7    0.000    0.000    0.001    0.000 loops.py:501(inner)
#        72    0.000    0.000    0.001    0.000 mlir.py:2589(convert_hlo)
#       754    0.000    0.000    0.001    0.000 mlir.py:1858(__init__)
#      3165    0.000    0.000    0.001    0.000 mlir.py:917(len_ir_types)
#        84    0.000    0.000    0.001    0.000 core.py:199(subjaxprs)
#        82    0.000    0.000    0.001    0.000 partial_eval.py:1934(_new_const)
#       380    0.000    0.000    0.001    0.000 mlir.py:2450(<genexpr>)
#         6    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         6    0.000    0.000    0.001    0.000 pxla.py:1170(__call__)
#         8    0.000    0.000    0.001    0.000 slicing.py:902(slice_in_dim)
#       161    0.001    0.000    0.001    0.000 _func_ops_gen.py:236(__init__)
#        14    0.000    0.000    0.001    0.000 iostream.py:259(schedule)
#      1152    0.000    0.000    0.001    0.000 named_sharding.py:147(__hash__)
#         6    0.000    0.000    0.001    0.000 pxla.py:125(shard_args)
#        29    0.000    0.000    0.001    0.000 _module.py:1126(_module_update_wrapper)
#        15    0.000    0.000    0.001    0.000 lax.py:6522(_broadcast_in_dim_abstract_eval)
#         7    0.000    0.000    0.001    0.000 util.py:83(promote_dtypes)
#      1803    0.001    0.000    0.001    0.000 dtypes.py:312(canonicalize_dtype)
#        78    0.000    0.000    0.001    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#        44    0.000    0.000    0.001    0.000 linear_util.py:379(wrap_init)
#       233    0.000    0.000    0.001    0.000 tree_util.py:73(tree_flatten)
#       161    0.000    0.000    0.001    0.000 _func_ops_gen.py:381(return_)
#        74    0.000    0.000    0.001    0.000 util.py:171(check_arraylike)
#       262    0.000    0.000    0.001    0.000 pxla.py:1861(__eq__)
#       360    0.000    0.000    0.001    0.000 core.py:189(jaxprs_in_params)
#         1    0.000    0.000    0.001    0.001 mlir.py:2732(cached_lowering)
#       815    0.000    0.000    0.001    0.000 partial_eval.py:1851(lit)
#         9    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#       181    0.000    0.000    0.001    0.000 dispatch.py:294(check_arg)
#     12024    0.001    0.000    0.001    0.000 sharding_impls.py:192(is_fully_replicated)
#        95    0.000    0.000    0.001    0.000 _stablehlo_ops_gen.py:5120(slice)
#       547    0.000    0.000    0.001    0.000 core.py:1678(__ne__)
#        41    0.000    0.000    0.001    0.000 core.py:1655(physical_element_aval)
#      4078    0.001    0.000    0.001    0.000 mlir.py:2025(_platforms_for_eqn_ctx)
#         1    0.000    0.000    0.001    0.001 mlir.py:1808(_emit_lowering_rule_as_fun)
#      2192    0.000    0.000    0.001    0.000 core.py:1705(_canonicalize_dimension)
#       568    0.000    0.000    0.001    0.000 pxla.py:1845(__init__)
#         6    0.000    0.000    0.001    0.000 lax.py:2853(select)
#        25    0.000    0.000    0.001    0.000 iostream.py:655(write)
#        17    0.000    0.000    0.001    0.000 sharding_impls.py:1183(physical_sharding)
#      1306    0.000    0.000    0.001    0.000 core.py:422(__init__)
#        36    0.000    0.000    0.001    0.000 lax.py:6943(_squeeze_lower)
#         9    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#        86    0.000    0.000    0.000    0.000 xla.py:114(_canonicalize_python_scalar_dtype)
#         8    0.000    0.000    0.000    0.000 mlir.py:2530(iota)
#        17    0.000    0.000    0.000    0.000 sharding_impls.py:1162(make_key_array_phys_sharding)
#       286    0.000    0.000    0.000    0.000 func.py:85(name)
#       534    0.000    0.000    0.000    0.000 getlimits.py:697(__init__)
#        93    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1168(compare)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:415(average)
#     22/20    0.000    0.000    0.000    0.000 util.py:271(cached)
#       161    0.000    0.000    0.000    0.000 func.py:77(type)
#      1001    0.000    0.000    0.000    0.000 mlir.py:2022(<genexpr>)
#         9    0.000    0.000    0.000    0.000 socket.py:700(send_multipart)
#      1183    0.000    0.000    0.000    0.000 mlir.py:1946(<genexpr>)
#         4    0.000    0.000    0.000    0.000 ufuncs.py:2598(power)
#       164    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:55(__init__)
#         7    0.000    0.000    0.000    0.000 session.py:690(serialize)
#        48    0.000    0.000    0.000    0.000 core.py:1496(valid_jaxtype)
#       608    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        37    0.000    0.000    0.000    0.000 mlir.py:2427(reshape)
#        93    0.000    0.000    0.000    0.000 pjit.py:263(_get_fastpath_data)
#         6    0.000    0.000    0.000    0.000 slicing.py:2974(_scatter_lower)
#       161    0.000    0.000    0.000    0.000 _func_ops_gen.py:366(__init__)
#       771    0.000    0.000    0.000    0.000 util.py:209(concatenate)
#         8    0.000    0.000    0.000    0.000 lax.py:2671(broadcast)
#       155    0.000    0.000    0.000    0.000 core.py:401(new_jaxpr_eqn)
#       148    0.000    0.000    0.000    0.000 core.py:876(__getattr__)
#         8    0.000    0.000    0.000    0.000 prng.py:1042(_mul)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#      2842    0.000    0.000    0.000    0.000 mlir.py:2401(<genexpr>)
#        95    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:5064(__init__)
#       134    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:411(and_)
#         1    0.000    0.000    0.000    0.000 lax_numpy.py:4413(stack)
#       719    0.000    0.000    0.000    0.000 core.py:226(out_avals)
#       660    0.000    0.000    0.000    0.000 core.py:222(in_avals)
#       123    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4980(shift_right_logical)
#         6    0.000    0.000    0.000    0.000 compiler.py:113(get_compile_options)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:41(_wrapit)
#        24    0.000    0.000    0.000    0.000 lax.py:6876(_pad_lower)
#       176    0.000    0.000    0.000    0.000 core.py:123(__init__)
#       203    0.000    0.000    0.000    0.000 pjit.py:1914(<genexpr>)
#        18    0.000    0.000    0.000    0.000 array.py:1100(_array_mlir_constant_handler)
#         6    0.000    0.000    0.000    0.000 cache_key.py:123(<lambda>)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3453(cumprod)
#         1    0.000    0.000    0.000    0.000 random.py:222(PRNGKey)
#       160    0.000    0.000    0.000    0.000 inspect.py:2743(__init__)
#         6    0.000    0.000    0.000    0.000 cache_key.py:276(_hash_serialized_compile_options)
#         6    0.000    0.000    0.000    0.000 compiler.py:90(use_detailed_logging)
#      11/6    0.000    0.000    0.000    0.000 dispatch.py:240(get_intermediate_shardings)
#       218    0.000    0.000    0.000    0.000 source_info_util.py:163(raw_frame_to_frame)
#        12    0.000    0.000    0.000    0.000 lax.py:6758(_split_lower)
#       180    0.000    0.000    0.000    0.000 _module.py:848(__setattr__)
#      46/6    0.000    0.000    0.000    0.000 compiler.py:77(_walk_operations)
#         2    0.000    0.000    0.000    0.000 random.py:72(_check_prng_key)
#        30    0.000    0.000    0.000    0.000 abstract_arrays.py:63(_make_shaped_array_for_numpy_scalar)
#        93    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1114(__init__)
#       285    0.000    0.000    0.000    0.000 mlir.py:1383(update_tokens)
#       113    0.000    0.000    0.000    0.000 __init__.py:457(_replace)
#      2662    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        37    0.000    0.000    0.000    0.000 named_sharding.py:236(with_spec)
#         2    0.000    0.000    0.000    0.000 prng.py:722(random_wrap)
#         1    0.000    0.000    0.000    0.000 random.py:281(split)
#         6    0.000    0.000    0.000    0.000 mlir.py:595(__init__)
#      4314    0.000    0.000    0.000    0.000 source_info_util.py:142(__init__)
#        71    0.000    0.000    0.000    0.000 enum.py:1545(__or__)
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         4    0.000    0.000    0.000    0.000 {method 'cumprod' of 'numpy.ndarray' objects}
#        95    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#      12/4    0.000    0.000    0.000    0.000 pjit.py:2574(dce_jaxpr_pjit_rule)
#       165    0.000    0.000    0.000    0.000 dataclasses.py:1278(fields)
#        24    0.000    0.000    0.000    0.000 _methods.py:118(_mean)
#        24    0.000    0.000    0.000    0.000 mlir.py:2513(pad)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         3    0.000    0.000    0.000    0.000 prng.py:612(<lambda>)
#       360    0.000    0.000    0.000    0.000 enum.py:1538(_get_value)
#        16    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         1    0.000    0.000    0.000    0.000 random.py:711(normal)
#         3    0.000    0.000    0.000    0.000 prng.py:1117(threefry_split)
#       571    0.000    0.000    0.000    0.000 mlir.py:1376(effects)
#        25    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#       192    0.000    0.000    0.000    0.000 source_info_util.py:103(extend)
#       360    0.000    0.000    0.000    0.000 _module.py:759(_warn_jax_transformed_function)
#       262    0.000    0.000    0.000    0.000 tree_util.py:81(tree_unflatten)
#      2638    0.000    0.000    0.000    0.000 mlir.py:2361(wrap_xla_metadata_in_place)
#        44    0.000    0.000    0.000    0.000 partial_eval.py:1892(__init__)
#      2041    0.000    0.000    0.000    0.000 mlir.py:1381(<genexpr>)
#       670    0.000    0.000    0.000    0.000 partial_eval.py:1791(apply_var_sub)
#         7    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#       128    0.000    0.000    0.000    0.000 typing.py:392(inner)
#      24/6    0.000    0.000    0.000    0.000 copy.py:118(deepcopy)
#         7    0.000    0.000    0.000    0.000 loops.py:556(_stage_jaxpr)
#        80    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1397(convert)
#       178    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#      2768    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        28    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#       341    0.000    0.000    0.000    0.000 enum.py:720(__call__)
#       497    0.000    0.000    0.000    0.000 partial_eval.py:1950(getvar)
#       151    0.000    0.000    0.000    0.000 partial_eval.py:1655(make_jaxpr_effects)
#        49    0.000    0.000    0.000    0.000 enum.py:1556(__and__)
#      2065    0.000    0.000    0.000    0.000 effects.py:100(filter_in)
#        14    0.000    0.000    0.000    0.000 lax.py:8732(_const)
#       975    0.000    0.000    0.000    0.000 mlir.py:1871(__hash__)
#       479    0.000    0.000    0.000    0.000 core.py:379(replace)
#         1    0.000    0.000    0.000    0.000 random.py:190(_key)
#         2    0.000    0.000    0.000    0.000 prng.py:729(random_wrap_abstract_eval)
#         3    0.000    0.000    0.000    0.000 scalar_types.py:48(__call__)
#      11/6    0.000    0.000    0.000    0.000 dispatch.py:224(jaxpr_has_prim_requiring_devices)
#        93    0.000    0.000    0.000    0.000 pxla.py:3117(reflatten_outputs_for_dispatch)
#       158    0.000    0.000    0.000    0.000 core.py:590(check_avals_context_mesh)
#         4    0.000    0.000    0.000    0.000 lax.py:923(integer_pow)
#       143    0.000    0.000    0.000    0.000 util.py:132(_arraylike)
#       176    0.000    0.000    0.000    0.000 linear_util.py:314(resolve_result_paths)
#       113    0.000    0.000    0.000    0.000 __init__.py:447(_make)
#        62    0.000    0.000    0.000    0.000 tree_util.py:350(tree_map)
#       533    0.000    0.000    0.000    0.000 _ods_common.py:112(get_op_results_or_values)
#        54    0.000    0.000    0.000    0.000 _module.py:521(flatten_module_with_keys)
#       134    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:388(__init__)
#      1356    0.000    0.000    0.000    0.000 source_info_util.py:95(wrap)
#         2    0.000    0.000    0.000    0.000 dispatch.py:94(xla_primitive_callable)
#        95    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 slicing.py:1591(_dynamic_slice_lower)
#         1    0.000    0.000    0.000    0.000 prng.py:543(random_seed)
#        28    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         2    0.000    0.000    0.000    0.000 api.py:154(wrapped)
#         4    0.000    0.000    0.000    0.000 pxla.py:202(_shard_np_array)
#         2    0.000    0.000    0.000    0.000 api.py:181(jit)
#         1    0.000    0.000    0.000    0.000 mlir.py:2463(dynamic_slice)
#         1    0.000    0.000    0.000    0.000 ufuncs.py:2438(true_divide)
#         2    0.000    0.000    0.000    0.000 pjit.py:523(make_jit)
#       2/1    0.000    0.000    0.000    0.000 pjit.py:2566(_dce_jaxpr_pjit)
#      11/6    0.000    0.000    0.000    0.000 pxla.py:1999(jaxpr_transfer_mem_kinds)
#        15    0.000    0.000    0.000    0.000 lax.py:6313(_broadcast_in_dim_shape_rule)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2558(dynamic_slice)
#         3    0.000    0.000    0.000    0.000 sharding_impls.py:1217(logical_sharding)
#       147    0.000    0.000    0.000    0.000 util.py:114(unzip2)
#       123    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4957(__init__)
#       586    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3429(result)
#        32    0.000    0.000    0.000    0.000 lax.py:7403(_select_hlo_lowering)
#       613    0.000    0.000    0.000    0.000 partial_eval.py:2495(_substitute_vars_in_type)
#        19    0.000    0.000    0.000    0.000 mlir.py:2181(_ir_consts)
#       846    0.000    0.000    0.000    0.000 dtypes.py:781(is_weakly_typed)
#         5    0.000    0.000    0.000    0.000 lax.py:7793(_unary_reduce_lower)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2520(__init__)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:2361(expand_dims)
#        46    0.000    0.000    0.000    0.000 lax.py:8705(_check_shapelike)
#        12    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#       567    0.000    0.000    0.000    0.000 core.py:728(<lambda>)
#         6    0.000    0.000    0.000    0.000 pxla.py:2845(_maybe_get_and_check_out_shardings)
#        71    0.000    0.000    0.000    0.000 dtypes.py:881(check_user_dtype_supported)
#        44    0.000    0.000    0.000    0.000 partial_eval.py:1702(__init__)
#        80    0.000    0.000    0.000    0.000 typing.py:1288(__or__)
#         2    0.000    0.000    0.000    0.000 reductions.py:240(sum)
#        30    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:5735(xor)
#      2604    0.000    0.000    0.000    0.000 dtypes.py:594(<genexpr>)
#      2039    0.000    0.000    0.000    0.000 core.py:491(__repr__)
#       206    0.000    0.000    0.000    0.000 util.py:174(<genexpr>)
#        15    0.000    0.000    0.000    0.000 util.py:154(ensure_arraylike)
#        64    0.000    0.000    0.000    0.000 inspect.py:3029(__init__)
#        52    0.000    0.000    0.000    0.000 api_util.py:645(fun_sourceinfo)
#      1654    0.000    0.000    0.000    0.000 named_sharding.py:143(memory_kind)
#        28    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#       267    0.000    0.000    0.000    0.000 getlimits.py:708(min)
#         6    0.000    0.000    0.000    0.000 slicing.py:2232(_scatter_shape_rule)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:2517(__call__)
#       157    0.000    0.000    0.000    0.000 xla.py:111(_canonicalize_ndarray_dtype)
#        13    0.000    0.000    0.000    0.000 lax.py:3902(naryop_dtype_rule)
#      2039    0.000    0.000    0.000    0.000 mlir.py:1936(get_override_lowering_rule)
#        50    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:5271(subtract)
#        99    0.000    0.000    0.000    0.000 partial_eval.py:1846(<genexpr>)
#        88    0.000    0.000    0.000    0.000 source_info_util.py:314(reset_name_stack)
#       122    0.000    0.000    0.000    0.000 partition_spec.py:62(__new__)
#        41    0.000    0.000    0.000    0.000 prng.py:364(physical_element_aval)
#         6    0.000    0.000    0.000    0.000 mlir.py:1271(_set_up_aliases)
#       122    0.000    0.000    0.000    0.000 partition_spec.py:72(__eq__)
#         6    0.000    0.000    0.000    0.000 array.py:1191(_array_shard_arg)
#         6    0.000    0.000    0.000    0.000 pxla.py:2509(get_out_shardings_from_executable)
#         2    0.000    0.000    0.000    0.000 random.py:107(_return_prng_keys)
#         6    0.000    0.000    0.000    0.000 lax_numpy.py:3098(broadcast_to)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:2487(_call_as_normal)
#        23    0.000    0.000    0.000    0.000 partial_eval.py:871(convert_constvars_jaxpr)
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         8    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3123(iota)
#   165/161    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        80    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:1378(__init__)
#         6    0.000    0.000    0.000    0.000 util.py:260(_broadcast_to)
#        40    0.000    0.000    0.000    0.000 mlir.py:2546(add_jaxvals_lowering)
#         5    0.000    0.000    0.000    0.000 inspect.py:2048(_signature_get_partial)
#         1    0.000    0.000    0.000    0.000 util.py:238(promote_args_inexact)
#      2039    0.000    0.000    0.000    0.000 source_info_util.py:239(__init__)
#       152    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 dispatch.py:97(prim_fun)
#      2478    0.000    0.000    0.000    0.000 util.py:266(_ignore)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:2593(_vectorize_call)
#        39    0.000    0.000    0.000    0.000 threading.py:1535(enumerate)
#       160    0.000    0.000    0.000    0.000 mlir.py:1367(create)
#      2058    0.000    0.000    0.000    0.000 core.py:289(__init__)
#         6    0.000    0.000    0.000    0.000 pxla.py:2801(_maybe_get_and_check_in_shardings)
#         3    0.000    0.000    0.000    0.000 lax.py:1355(shift_left)
#        21    0.000    0.000    0.000    0.000 lax.py:6713(_concatenate_lower)
#         2    0.000    0.000    0.000    0.000 prng.py:752(random_unwrap)
#      1108    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 pjit.py:1594(_resolve_in_layouts)
#        55    0.000    0.000    0.000    0.000 _module.py:825(_make_initable_wrapper)
#       337    0.000    0.000    0.000    0.000 partial_eval.py:1462(write)
#         2    0.000    0.000    0.000    0.000 pjit.py:436(_parse_jit_arguments)
#         8    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3095(__init__)
#        28    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
# ...
#         1    0.000    0.000    0.000    0.000 random.py:167(resolve_prng_impl)
#        25    0.000    0.000    0.000    0.000 core.py:1599(<lambda>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         9    0.000    0.000    0.000    0.000 prng.py:1164(<genexpr>)
#         9    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 inspect.py:306(ismethod)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         2    0.000    0.000    0.000    0.000 named_sharding.py:241(_to_xla_hlo_sharding)
#        23    0.000    0.000    0.000    0.000 sharding_impls.py:1268(canonicalize_sharding)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#        25    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#        12    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 pxla.py:2784(<lambda>)
#        31    0.000    0.000    0.000    0.000 lax.py:4796(_convert_element_type_dtype_rule)
#         6    0.000    0.000    0.000    0.000 xla_bridge.py:757(canonicalize_platform)
#        15    0.000    0.000    0.000    0.000 {method 'issubset' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 random.py:123(default_prng_impl)
#         6    0.000    0.000    0.000    0.000 <string>:2(__hash__)
#        24    0.000    0.000    0.000    0.000 base_events.py:2017(get_debug)
#        31    0.000    0.000    0.000    0.000 lax.py:4800(_convert_element_type_weak_type_rule)
#         6    0.000    0.000    0.000    0.000 prng.py:103(__hash__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2919(kwargs)
#        16    0.000    0.000    0.000    0.000 api_util.py:258(<genexpr>)
#        29    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#        20    0.000    0.000    0.000    0.000 pxla.py:2247(<genexpr>)
#         5    0.000    0.000    0.000    0.000 prng.py:854(rotate_list)
#        12    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#        35    0.000    0.000    0.000    0.000 dispatch.py:257(<genexpr>)
#         2    0.000    0.000    0.000    0.000 api_util.py:346(rebase_donate_argnums)
#        11    0.000    0.000    0.000    0.000 lax.py:6918(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:4631(update_computation)
#         4    0.000    0.000    0.000    0.000 prng.py:345(base_arr_shape_to_keys_shape)
#         8    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         7    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        24    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:345(<genexpr>)
#        20    0.000    0.000    0.000    0.000 dispatch.py:175(__init__)
#        20    0.000    0.000    0.000    0.000 monitoring.py:84(record_event_time_span)
#         9    0.000    0.000    0.000    0.000 lax.py:3837(<genexpr>)
#        37    0.000    0.000    0.000    0.000 inspect.py:2800(default)
#        28    0.000    0.000    0.000    0.000 mlir.py:942(sharded_aval)
#        20    0.000    0.000    0.000    0.000 pxla.py:2263(<genexpr>)
#        10    0.000    0.000    0.000    0.000 api_util.py:125(__hash__)
#        12    0.000    0.000    0.000    0.000 dtypes.py:872(<genexpr>)
#         2    0.000    0.000    0.000    0.000 api_util.py:551(_assert_no_intersection)
#         1    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2554(result)
#         6    0.000    0.000    0.000    0.000 pxla.py:2173(_concretize_abstract_out_shardings)
#        16    0.000    0.000    0.000    0.000 base_events.py:543(_check_closed)
#         4    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:5003(result)
#         7    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 prng.py:472(__eq__)
#        10    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#        20    0.000    0.000    0.000    0.000 pxla.py:2248(<genexpr>)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         2    0.000    0.000    0.000    0.000 config.py:313(__call__)
#         2    0.000    0.000    0.000    0.000 sharding_impls.py:177(devices_indices_map)
#        26    0.000    0.000    0.000    0.000 pxla.py:123(identity)
#        18    0.000    0.000    0.000    0.000 slicing.py:1319(<genexpr>)
#        18    0.000    0.000    0.000    0.000 lax.py:7307(<genexpr>)
#         1    0.000    0.000    0.000    0.000 lax.py:259(_merge_dyn_shape)
#        16    0.000    0.000    0.000    0.000 api_util.py:259(<genexpr>)
#        14    0.000    0.000    0.000    0.000 sharding_impls.py:180(_device_assignment)
#        12    0.000    0.000    0.000    0.000 enum.py:1286(value)
#        12    0.000    0.000    0.000    0.000 lax.py:7270(<genexpr>)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#        15    0.000    0.000    0.000    0.000 lax.py:6331(<genexpr>)
#         3    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         9    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         7    0.000    0.000    0.000    0.000 mlir.py:2190(lower_fun)
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#        12    0.000    0.000    0.000    0.000 pxla.py:2282(<genexpr>)
#        20    0.000    0.000    0.000    0.000 dtypes.py:846(<genexpr>)
#        12    0.000    0.000    0.000    0.000 indexing.py:1033(<genexpr>)
#         5    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         8    0.000    0.000    0.000    0.000 array.py:265(dtype)
#         7    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 slicing.py:1479(<genexpr>)
#         2    0.000    0.000    0.000    0.000 loops.py:2117(_fori_scan_body_fun)
#         3    0.000    0.000    0.000    0.000 util.py:213(<genexpr>)
#        16    0.000    0.000    0.000    0.000 pxla.py:161(<genexpr>)
#         5    0.000    0.000    0.000    0.000 inspect.py:524(isbuiltin)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:2675(_cov_dispatcher)
#         3    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:3365(result)
#      32/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 config.py:345(__enter__)
#        12    0.000    0.000    0.000    0.000 _function_base_impl.py:410(_average_dispatcher)
#         6    0.000    0.000    0.000    0.000 monitoring.py:63(record_event)
#         6    0.000    0.000    0.000    0.000 dispatch.py:323(needs_check_special)
#         8    0.000    0.000    0.000    0.000 pxla.py:140(<lambda>)
#         6    0.000    0.000    0.000    0.000 indexing.py:1115(<genexpr>)
#         3    0.000    0.000    0.000    0.000 op_shardings.py:27(get_num_ways_dim_sharded)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 _stablehlo_ops_gen.py:2683(result)
#         6    0.000    0.000    0.000    0.000 compilation_cache.py:163(is_persistent_cache_enabled)
#        12    0.000    0.000    0.000    0.000 multiarray.py:761(dot)
#        16    0.000    0.000    0.000    0.000 pjit.py:1953(<genexpr>)
#         6    0.000    0.000    0.000    0.000 slicing.py:1732(_dims_in_range)
#         2    0.000    0.000    0.000    0.000 _chlo_ops_gen.py:1460(result)
#         3    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#         6    0.000    0.000    0.000    0.000 pxla.py:3133(__init__)
#        12    0.000    0.000    0.000    0.000 profiler.py:419(trace)
#         6    0.000    0.000    0.000    0.000 array_methods.py:743(__init__)
#         2    0.000    0.000    0.000    0.000 core.py:234(eqns)
#         6    0.000    0.000    0.000    0.000 array_methods.py:762(__init__)
#         6    0.000    0.000    0.000    0.000 mlir.py:691(__init__)
#         9    0.000    0.000    0.000    0.000 prng.py:458(__init__)
#        12    0.000    0.000    0.000    0.000 _stride_tricks_impl.py:363(_broadcast_to_dispatcher)
#         7    0.000    0.000    0.000    0.000 loops.py:227(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 partial_eval.py:1447(has_effects)
#         7    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         6    0.000    0.000    0.000    0.000 pxla.py:2440(__init__)
#         8    0.000    0.000    0.000    0.000 pjit.py:688(__init__)
#         5    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         6    0.000    0.000    0.000    0.000 _function_base_impl.py:1365(_diff_dispatcher)
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:6331(<genexpr>)
#         4    0.000    0.000    0.000    0.000 lax.py:6638(<genexpr>)
#         6    0.000    0.000    0.000    0.000 sharding_impls.py:765(__post_init__)
#         7    0.000    0.000    0.000    0.000 loops.py:239(<genexpr>)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         8    0.000    0.000    0.000    0.000 pjit.py:802(_flat_axes_specs)
#         5    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         6    0.000    0.000    0.000    0.000 mlir.py:525(dump_module_to_file)
#         2    0.000    0.000    0.000    0.000 sharding_impls.py:650(_device_assignment)
#        12    0.000    0.000    0.000    0.000 cache_key.py:350(<genexpr>)
#        12    0.000    0.000    0.000    0.000 copy.py:172(_deepcopy_atomic)
#         3    0.000    0.000    0.000    0.000 {built-in method math.prod}
#         2    0.000    0.000    0.000    0.000 mlir.py:1361(__len__)
#         6    0.000    0.000    0.000    0.000 compiler.py:372(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 dtypes.py:276(to_inexact_dtype)
#         8    0.000    0.000    0.000    0.000 pjit.py:657(<genexpr>)
#         1    0.000    0.000    0.000    0.000 warnings.py:421(__init__)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         6    0.000    0.000    0.000    0.000 core.py:2348(<genexpr>)
#         2    0.000    0.000    0.000    0.000 pxla.py:2679(is_user_xla_layout_equal)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:2014(_nonzero_dispatcher)
#         6    0.000    0.000    0.000    0.000 prng.py:739(random_wrap_lowering)
#         2    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 util.py:56(<genexpr>)
#         5    0.000    0.000    0.000    0.000 util.py:331(__init__)
#         6    0.000    0.000    0.000    0.000 dispatch.py:200(should_tuple_args)
#         9    0.000    0.000    0.000    0.000 lax.py:6896(_squeeze_dtype_rule)
#         6    0.000    0.000    0.000    0.000 slicing.py:2317(<genexpr>)
#         7    0.000    0.000    0.000    0.000 sharding_impls.py:184(_to_xla_hlo_sharding)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 config.py:350(__exit__)
#         6    0.000    0.000    0.000    0.000 pxla.py:2160(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pjit.py:282(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 util.py:399(wraps)
#         2    0.000    0.000    0.000    0.000 api_util.py:381(is_hashable)
#         6    0.000    0.000    0.000    0.000 pxla.py:2199(_get_context_mesh)
#         2    0.000    0.000    0.000    0.000 slicing.py:1466(<genexpr>)
#         6    0.000    0.000    0.000    0.000 slicing.py:2318(<genexpr>)
#         6    0.000    0.000    0.000    0.000 pxla.py:1186(__init__)
#         2    0.000    0.000    0.000    0.000 functools.py:424(_unwrap_partial)
#         2    0.000    0.000    0.000    0.000 sharding_impls.py:654(_to_xla_hlo_sharding)
#         6    0.000    0.000    0.000    0.000 compiler.py:72(get_latest_profile_version)
#         1    0.000    0.000    0.000    0.000 loops.py:2108(_fori_body_fun)
#         3    0.000    0.000    0.000    0.000 lax_numpy.py:6754(<lambda>)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:3449(_cumprod_dispatcher)
#         4    0.000    0.000    0.000    0.000 api_util.py:466(infer_argnums_and_argnames)
#         7    0.000    0.000    0.000    0.000 mlir.py:2256(check_backend_matches)
#         6    0.000    0.000    0.000    0.000 cache_key.py:50(get_flag_prefixes)
#         6    0.000    0.000    0.000    0.000 pxla.py:2148(<genexpr>)
#         6    0.000    0.000    0.000    0.000 cache_key.py:56(custom_hook)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         4    0.000    0.000    0.000    0.000 util.py:343(__init__)
#         3    0.000    0.000    0.000    0.000 prng.py:769(random_unwrap_lowering)
#         4    0.000    0.000    0.000    0.000 lax.py:6657(<genexpr>)
#         2    0.000    0.000    0.000    0.000 core.py:1831(<genexpr>)
#         3    0.000    0.000    0.000    0.000 sharding_impls.py:1211(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base_events.py:1917(_timer_handle_cancelled)
#         2    0.000    0.000    0.000    0.000 config.py:328(__init__)
#         2    0.000    0.000    0.000    0.000 pxla.py:3104(contains_explicit_attributes)
#         4    0.000    0.000    0.000    0.000 lax.py:244(_identity)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 random.py:351(maybe_auto_axes)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         4    0.000    0.000    0.000    0.000 pjit.py:416(<lambda>)
#         4    0.000    0.000    0.000    0.000 sharding_impls.py:682(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 mesh.py:491(abstract_mesh)
#         1    0.000    0.000    0.000    0.000 hmc.py:375(delta_mom)
#         3    0.000    0.000    0.000    0.000 hmc.py:370(delta_X)
#         3    0.000    0.000    0.000    0.000 multiarray.py:1194(packbits)
#         2    0.000    0.000    0.000    0.000 slicing.py:1462(<genexpr>)
#         1    0.000    0.000    0.000    0.000 error.py:68(_set_error_if_nan)
#         2    0.000    0.000    0.000    0.000 pjit.py:324(_get_cpp_global_cache)
#         1    0.000    0.000    0.000    0.000 base_events.py:724(is_closed)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 error.py:87(_set_error_if_divide_by_zero)
#         2    0.000    0.000    0.000    0.000 lax.py:265(<genexpr>)
#         1    0.000    0.000    0.000    0.000 hmc.py:369(delta_fields)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         2    0.000    0.000    0.000    0.000 api_util.py:122(__init__)
#         2    0.000    0.000    0.000    0.000 reductions.py:217(force)
#         1    0.000    0.000    0.000    0.000 prng.py:765(random_unwrap_impl)

# %%
plt.errorbar(all_eps**2, gv.mean(m2_HMD), gv.sdev(m2_HMD), ls=' ', marker='s', color='red', label='MD')
plt.errorbar(all_eps**2, gv.mean(m2_HMC), gv.sdev(m2_HMC), ls=' ', marker='*', color='forestgreen', label='HMC')

plt.xlim(0,0.07)
plt.xlabel('$\epsilon^2$')
plt.ylabel('$<m^2>$')
plt.legend()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# <>:5: SyntaxWarning: invalid escape sequence '\e'
# /var/folders/vz/k6mgc8_d28v0gskwh5xd08mr0000gn/T/ipykernel_28206/1386904723.py:5: SyntaxWarning: invalid escape sequence '\e'
#   plt.xlabel('$\epsilon^2$')

# %% [markdown]
# Finally the big physics result, figure 2.5!

# %%
from tqdm import tqdm

d = 3

all_kappa = np.array([0.05, 0.10, 0.15, 0.16, 0.17, 0.175, 0.18, 0.185, 0.19, 0.195, 0.2, 0.21, 0.22])
all_L = (6,8,10)

mag_k = {}
rng_key = jax.random.PRNGKey(58105)

for L in tqdm(all_L):
    mag_k[L] = []

    Lat = lat.SquareLattice(st_dims=((L,)*d))
    phi_L = lat.LatticeField(lattice=Lat, F=1)

    for k in all_kappa:
        raw_mag = []
        fields = {'phi': phi_L}
        Sk = ScalarAction(field_names=['phi'], params={'kappa': k, 'lambda': 1.1689})
    
        HMC = lhmc.HMCRewrite(
            action=Sk,
            integrator=lhmc.OmelyanIntegrator(eps=0.1, Nstep=10),
        )

        fields, _, rng_key = HMC.evolve_many(fields, rng_key, traj=100, warmup=True)
    
        for _ in range(200):
            fields, _, rng_key = HMC.evolve_many(fields, rng_key, traj=100)
            raw_mag.append(mag(fields['phi'])[0])
    
        raw_m = np.abs(np.array(raw_mag))/L**d
    
        mag_k[L].append(gv.dataset.avg_data(raw_m))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/var/folders/vz/k6mgc8_d28v0gskwh5xd08mr0000gn/T/ipykernel_28206/2342133672.py:15: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   phi_L = lat.LatticeField(lattice=Lat, F=1)
# /var/folders/vz/k6mgc8_d28v0gskwh5xd08mr0000gn/T/ipykernel_28206/2342133672.py:20: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   Sk = ScalarAction(field_names=['phi'], params={'kappa': k, 'lambda': 1.1689})
# 100%|██████████| 3/3 [01:55<00:00, 38.52s/it]

# %%
plt.plot(all_kappa, gv.mean(mag_k[6]), ls=' ', marker='x')
plt.plot(all_kappa, gv.mean(mag_k[8]), ls=' ', marker='o', color='red')
plt.plot(all_kappa, gv.mean(mag_k[10]), ls=' ', marker='^', color='green')

plt.xlim(0.15, 0.22)
# Out:
# (0.15, 0.22)

# %% [markdown]
# Autocorrelation analysis...

# %%
d = 3
Lat6 = lat.SquareLattice(st_dims=((6,)*d))
phi6 = lat.LatticeField(lattice=Lat6, F=1)

# HMC = lhmc.HMCEvolver(
#     action=ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689}),
#     seed=21245,
#     init_fields={'phi': phi6},
#     integrator=lhmc.OmelyanIntegrator(eps=0.1, Nstep=10),
#     observables={'mag': (mag_obs, 1)},
# )

HMC = lhmc.HMCRewrite(
    action=ScalarAction(field_names=['phi'], params={'kappa': 0.185825, 'lambda': 1.1689}),
    integrator=lhmc.LeapfrogIntegrator(eps=0.1, Nstep=10),
)

F6 = {'phi': phi6}
rng_key = jax.random.PRNGKey(29759)
F6, _, rng_key = HMC.evolve_many(F6, rng_key, traj=1000, warmup=True)

m2 = []
dH = []

for _ in tqdm(range(100000)):
    F6, mon, rng_key = HMC.evolve_many(F6, rng_key, traj=1)
    dH.append(np.mean(mon['delta_H']))
    m2.append(mag(F6['phi'])[1]/6**d)
# Out:
# /var/folders/vz/k6mgc8_d28v0gskwh5xd08mr0000gn/T/ipykernel_28206/3376543419.py:3: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   phi6 = lat.LatticeField(lattice=Lat6, F=1)
# 100%|██████████| 100000/100000 [00:10<00:00, 9123.69it/s]

# %%
gv.dataset.avg_data(np.exp(-np.asarray(dH)))
# Out:
# 1.0013(11)

# %%
#m = np.array(HMC.obs_chain['mag'])[:,0]
plt.plot(m2)
m2

#gv.dataset.avg_data(m[::100]/6**3)
# Out:
# [Array(74.16398422, dtype=float64),
#  Array(75.40130109, dtype=float64),
#  Array(68.98404388, dtype=float64),
#  Array(105.46343707, dtype=float64),
#  Array(114.90217795, dtype=float64),
#  Array(73.59443252, dtype=float64),
#  Array(82.0620639, dtype=float64),
#  Array(79.50955904, dtype=float64),
#  Array(61.68039345, dtype=float64),
#  Array(42.95876094, dtype=float64),
#  Array(59.35241336, dtype=float64),
#  Array(61.81873722, dtype=float64),
#  Array(51.17476337, dtype=float64),
#  Array(44.11023946, dtype=float64),
#  Array(46.41991128, dtype=float64),
#  Array(65.08941289, dtype=float64),
#  Array(62.27098558, dtype=float64),
#  Array(51.80734039, dtype=float64),
#  Array(55.54882695, dtype=float64),
#  Array(50.54289382, dtype=float64),
#  Array(36.36743111, dtype=float64),
#  Array(36.36743111, dtype=float64),
#  Array(46.29574302, dtype=float64),
#  Array(22.97397185, dtype=float64),
#  Array(38.03902064, dtype=float64),
#  Array(60.57896424, dtype=float64),
#  Array(68.2791064, dtype=float64),
#  Array(49.27066488, dtype=float64),
#  Array(46.08475891, dtype=float64),
#  Array(30.18589007, dtype=float64),
#  Array(36.38417286, dtype=float64),
#  Array(34.14891891, dtype=float64),
#  Array(14.85684376, dtype=float64),
#  Array(30.07927321, dtype=float64),
#  Array(30.07927321, dtype=float64),
#  Array(15.97887311, dtype=float64),
#  Array(22.56878015, dtype=float64),
#  Array(22.56878015, dtype=float64),
#  Array(19.75615154, dtype=float64),
#  Array(24.09171161, dtype=float64),
#  Array(45.54216832, dtype=float64),
#  Array(30.5520531, dtype=float64),
#  Array(25.61436217, dtype=float64),
#  Array(30.61169504, dtype=float64),
#  Array(33.75760689, dtype=float64),
#  Array(37.59437119, dtype=float64),
#  Array(35.97175464, dtype=float64),
#  Array(31.92140497, dtype=float64),
#  Array(39.30640019, dtype=float64),
#  Array(26.98780389, dtype=float64),
#  Array(28.50592335, dtype=float64),
#  Array(28.50592335, dtype=float64),
#  Array(28.59222494, dtype=float64),
#  Array(28.01555259, dtype=float64),
#  Array(28.76278432, dtype=float64),
#  Array(42.96841869, dtype=float64),
#  Array(41.24961555, dtype=float64),
#  Array(41.81505377, dtype=float64),
#  Array(39.7669012, dtype=float64),
#  Array(39.7669012, dtype=float64),
#  Array(46.36405132, dtype=float64),
#  Array(50.45269224, dtype=float64),
#  Array(56.16370858, dtype=float64),
#  Array(65.88177682, dtype=float64),
#  Array(64.43403325, dtype=float64),
#  Array(68.06779916, dtype=float64),
#  Array(72.66287767, dtype=float64),
#  Array(78.30249614, dtype=float64),
#  Array(57.7078838, dtype=float64),
#  Array(57.95750116, dtype=float64),
#  Array(37.67858493, dtype=float64),
#  Array(37.15742452, dtype=float64),
#  Array(30.19298039, dtype=float64),
#  Array(35.63606079, dtype=float64),
#  Array(42.82923549, dtype=float64),
#  Array(58.53456521, dtype=float64),
#  Array(41.10620915, dtype=float64),
#  Array(63.04275914, dtype=float64),
#  Array(43.6155957, dtype=float64),
#  Array(48.78519366, dtype=float64),
#  Array(30.0223622, dtype=float64),
#  Array(32.88106089, dtype=float64),
#  Array(15.35963683, dtype=float64),
#  Array(12.00233627, dtype=float64),
#  Array(6.87567537, dtype=float64),
#  Array(4.45399782, dtype=float64),
#  Array(9.4901184, dtype=float64),
#  Array(6.74341974, dtype=float64),
#  Array(9.6673896, dtype=float64),
#  Array(20.76417357, dtype=float64),
#  Array(21.30464501, dtype=float64),
#  Array(21.30464501, dtype=float64),
#  Array(11.03167659, dtype=float64),
#  Array(15.99576099, dtype=float64),
#  Array(25.27997571, dtype=float64),
#  Array(19.04430674, dtype=float64),
#  Array(30.99209703, dtype=float64),
#  Array(30.99209703, dtype=float64),
#  Array(30.44860185, dtype=float64),
#  Array(40.52835465, dtype=float64),
#  Array(21.72919404, dtype=float64),
#  Array(21.97830917, dtype=float64),
#  Array(20.106338, dtype=float64),
#  Array(19.79528147, dtype=float64),
#  Array(12.79835495, dtype=float64),
#  Array(6.07849752, dtype=float64),
#  Array(12.28939389, dtype=float64),
#  Array(15.15097606, dtype=float64),
#  Array(19.40088909, dtype=float64),
#  Array(26.75619818, dtype=float64),
#  Array(33.23755282, dtype=float64),
#  Array(24.78110678, dtype=float64),
#  Array(15.49053208, dtype=float64),
#  Array(14.63975934, dtype=float64),
#  Array(15.58280008, dtype=float64),
#  Array(30.10797979, dtype=float64),
#  Array(27.64937792, dtype=float64),
#  Array(23.24733443, dtype=float64),
#  Array(21.2357842, dtype=float64),
#  Array(15.44380428, dtype=float64),
#  Array(22.74542219, dtype=float64),
#  Array(19.05958116, dtype=float64),
#  Array(22.57730316, dtype=float64),
#  Array(45.59722904, dtype=float64),
#  Array(48.60339653, dtype=float64),
#  Array(40.0483631, dtype=float64),
#  Array(51.5212794, dtype=float64),
#  Array(61.96468725, dtype=float64),
#  Array(61.96468725, dtype=float64),
#  Array(37.74235893, dtype=float64),
#  Array(35.44099423, dtype=float64),
#  Array(35.44099423, dtype=float64),
#  Array(34.63035048, dtype=float64),
#  Array(25.88542603, dtype=float64),
#  Array(51.58093239, dtype=float64),
#  Array(51.58093239, dtype=float64),
#  Array(55.5260547, dtype=float64),
#  Array(42.73751551, dtype=float64),
#  Array(42.73751551, dtype=float64),
#  Array(42.73751551, dtype=float64),
#  Array(28.77059289, dtype=float64),
#  Array(16.29935506, dtype=float64),
#  Array(24.39583797, dtype=float64),
#  Array(19.19699959, dtype=float64),
#  Array(24.72928285, dtype=float64),
#  Array(19.78557517, dtype=float64),
#  Array(20.87685509, dtype=float64),
#  Array(19.02536627, dtype=float64),
#  Array(45.12380291, dtype=float64),
#  Array(45.88129325, dtype=float64),
#  Array(44.67892314, dtype=float64),
#  Array(44.67892314, dtype=float64),
#  Array(47.54914123, dtype=float64),
#  Array(35.04818529, dtype=float64),
#  Array(40.56644379, dtype=float64),
#  Array(26.04136068, dtype=float64),
#  Array(24.45257763, dtype=float64),
#  Array(24.45257763, dtype=float64),
#  Array(41.66791969, dtype=float64),
#  Array(48.26262975, dtype=float64),
#  Array(48.26262975, dtype=float64),
#  Array(51.30825547, dtype=float64),
#  Array(43.04950487, dtype=float64),
#  Array(39.05339284, dtype=float64),
#  Array(39.05339284, dtype=float64),
#  Array(32.65159841, dtype=float64),
#  Array(32.06340948, dtype=float64),
#  Array(34.49213087, dtype=float64),
#  Array(45.73307679, dtype=float64),
#  Array(50.37991702, dtype=float64),
#  Array(50.37991702, dtype=float64),
#  Array(39.19650914, dtype=float64),
#  Array(35.54486478, dtype=float64),
#  Array(45.79277184, dtype=float64),
#  Array(57.03876556, dtype=float64),
#  Array(82.41590058, dtype=float64),
#  Array(78.24773062, dtype=float64),
#  Array(84.91668979, dtype=float64),
#  Array(77.84278634, dtype=float64),
#  Array(68.31798696, dtype=float64),
#  Array(54.3160421, dtype=float64),
#  Array(58.04650607, dtype=float64),
#  Array(80.06815335, dtype=float64),
#  Array(66.1753289, dtype=float64),
#  Array(95.53821559, dtype=float64),
#  Array(95.08020339, dtype=float64),
#  Array(116.09422486, dtype=float64),
#  Array(82.51388814, dtype=float64),
#  Array(89.13773521, dtype=float64),
#  Array(114.14978556, dtype=float64),
#  Array(109.66771915, dtype=float64),
#  Array(101.93401223, dtype=float64),
#  Array(107.60501559, dtype=float64),
#  Array(80.26808193, dtype=float64),
#  Array(80.26808193, dtype=float64),
#  Array(92.5051639, dtype=float64),
#  Array(89.43861149, dtype=float64),
#  Array(94.60944795, dtype=float64),
#  Array(82.91999329, dtype=float64),
#  Array(78.70838606, dtype=float64),
#  Array(76.29491742, dtype=float64),
#  Array(76.2178122, dtype=float64),
#  Array(72.38589445, dtype=float64),
#  Array(63.71696076, dtype=float64),
#  Array(63.74049913, dtype=float64),
#  Array(72.32311229, dtype=float64),
#  Array(65.03235899, dtype=float64),
#  Array(58.56460194, dtype=float64),
#  Array(53.4630722, dtype=float64),
#  Array(56.45496039, dtype=float64),
#  Array(55.05605066, dtype=float64),
#  Array(61.65959943, dtype=float64),
#  Array(53.66051956, dtype=float64),
#  Array(80.36837404, dtype=float64),
#  Array(74.21145185, dtype=float64),
#  Array(63.54876941, dtype=float64),
#  Array(59.66556265, dtype=float64),
#  Array(80.45715757, dtype=float64),
#  Array(73.9068553, dtype=float64),
#  Array(66.13563605, dtype=float64),
#  Array(52.23206568, dtype=float64),
#  Array(38.17645056, dtype=float64),
#  Array(38.17645056, dtype=float64),
#  Array(48.28659119, dtype=float64),
#  Array(48.28659119, dtype=float64),
#  Array(40.32444765, dtype=float64),
#  Array(37.50058755, dtype=float64),
#  Array(35.97706626, dtype=float64),
#  Array(21.20260709, dtype=float64),
#  Array(26.75989429, dtype=float64),
#  Array(36.41681162, dtype=float64),
#  Array(46.48504068, dtype=float64),
#  Array(46.48504068, dtype=float64),
#  Array(30.31986387, dtype=float64),
#  Array(30.31986387, dtype=float64),
#  Array(47.20460617, dtype=float64),
#  Array(64.17868983, dtype=float64),
#  Array(43.24242943, dtype=float64),
#  Array(48.32049851, dtype=float64),
#  Array(27.1166965, dtype=float64),
#  Array(38.35606745, dtype=float64),
#  Array(35.09935942, dtype=float64),
#  Array(38.50109059, dtype=float64),
#  Array(15.85877111, dtype=float64),
#  Array(23.07672518, dtype=float64),
#  Array(23.07672518, dtype=float64),
#  Array(23.07672518, dtype=float64),
#  Array(22.04453646, dtype=float64),
#  Array(22.04453646, dtype=float64),
#  Array(23.38367268, dtype=float64),
#  Array(23.38367268, dtype=float64),
#  Array(20.51443895, dtype=float64),
#  Array(25.41521581, dtype=float64),
#  Array(25.41521581, dtype=float64),
#  Array(32.05731764, dtype=float64),
#  Array(35.44610601, dtype=float64),
#  Array(41.11888728, dtype=float64),
#  Array(53.6204066, dtype=float64),
#  Array(50.70406917, dtype=float64),
#  Array(42.34575708, dtype=float64),
#  Array(41.68653143, dtype=float64),
#  Array(45.0942815, dtype=float64),
#  Array(45.0942815, dtype=float64),
#  Array(30.04281469, dtype=float64),
#  Array(35.69619117, dtype=float64),
#  Array(39.25240767, dtype=float64),
#  Array(39.25240767, dtype=float64),
#  Array(37.76669597, dtype=float64),
#  Array(37.76669597, dtype=float64),
#  Array(50.97544032, dtype=float64),
#  Array(52.11901359, dtype=float64),
#  Array(70.23308488, dtype=float64),
#  Array(67.64454627, dtype=float64),
#  Array(67.64454627, dtype=float64),
#  Array(67.64454627, dtype=float64),
#  Array(77.96227024, dtype=float64),
#  Array(72.7548028, dtype=float64),
#  Array(63.44634083, dtype=float64),
#  Array(76.86118074, dtype=float64),
#  Array(71.34059224, dtype=float64),
#  Array(82.35542783, dtype=float64),
#  Array(78.68545332, dtype=float64),
#  Array(73.8579803, dtype=float64),
#  Array(104.58018112, dtype=float64),
#  Array(104.58018112, dtype=float64),
#  Array(90.79903103, dtype=float64),
#  Array(74.91892787, dtype=float64),
#  Array(69.28160571, dtype=float64),
#  Array(48.98811456, dtype=float64),
#  Array(60.90564204, dtype=float64),
#  Array(59.49675289, dtype=float64),
#  Array(53.43863326, dtype=float64),
#  Array(49.54924879, dtype=float64),
#  Array(39.72242532, dtype=float64),
#  Array(37.99456463, dtype=float64),
#  Array(36.46739535, dtype=float64),
#  Array(47.17193535, dtype=float64),
#  Array(47.17193535, dtype=float64),
#  Array(47.17193535, dtype=float64),
#  Array(38.34937451, dtype=float64),
#  Array(55.41820978, dtype=float64),
#  Array(41.03522251, dtype=float64),
#  Array(50.12518498, dtype=float64),
#  Array(50.12518498, dtype=float64),
#  Array(52.76016521, dtype=float64),
#  Array(51.30020379, dtype=float64),
#  Array(33.60257404, dtype=float64),
#  Array(28.93041306, dtype=float64),
#  Array(28.59835132, dtype=float64),
#  Array(22.5410081, dtype=float64),
#  Array(11.64752147, dtype=float64),
#  Array(8.79747536, dtype=float64),
#  Array(11.89608164, dtype=float64),
#  Array(3.15075509, dtype=float64),
#  Array(2.70378717, dtype=float64),
#  Array(7.95391192, dtype=float64),
#  Array(2.44270435, dtype=float64),
#  Array(1.76130014, dtype=float64),
#  Array(1.76130014, dtype=float64),
#  Array(7.36670064, dtype=float64),
#  Array(7.08171778, dtype=float64),
#  Array(4.26846798, dtype=float64),
#  Array(0.0654264, dtype=float64),
#  Array(0.61116925, dtype=float64),
#  Array(0.67497732, dtype=float64),
#  Array(0.10790649, dtype=float64),
#  Array(0.38883951, dtype=float64),
#  Array(7.75107555, dtype=float64),
#  Array(7.75107555, dtype=float64),
#  Array(2.04577281, dtype=float64),
#  Array(1.27740755, dtype=float64),
#  Array(2.6813792, dtype=float64),
#  Array(3.9740908, dtype=float64),
#  Array(6.0515045, dtype=float64),
#  Array(0.71288081, dtype=float64),
#  Array(1.06080832, dtype=float64),
#  Array(0.85580129, dtype=float64),
#  Array(1.43990237, dtype=float64),
#  Array(0.92389902, dtype=float64),
#  Array(0.74790254, dtype=float64),
#  Array(1.01317145, dtype=float64),
#  Array(2.07406951, dtype=float64),
#  Array(1.88227801, dtype=float64),
#  Array(0.23861076, dtype=float64),
#  Array(0.5858222, dtype=float64),
#  Array(0.5858222, dtype=float64),
#  Array(0.5858222, dtype=float64),
#  Array(0.5858222, dtype=float64),
#  Array(0.02362823, dtype=float64),
#  Array(0.00086715, dtype=float64),
#  Array(0.00354453, dtype=float64),
#  Array(0.73986592, dtype=float64),
#  Array(0.56270293, dtype=float64),
#  Array(0.40298252, dtype=float64),
#  Array(0.40298252, dtype=float64),
#  Array(1.20562939, dtype=float64),
#  Array(1.20562939, dtype=float64),
#  Array(0.07712258, dtype=float64),
#  Array(0.16838655, dtype=float64),
#  Array(0.00382894, dtype=float64),
#  Array(0.00382894, dtype=float64),
#  Array(0.00382894, dtype=float64),
#  Array(1.4684297, dtype=float64),
#  Array(1.4684297, dtype=float64),
#  Array(0.00240829, dtype=float64),
#  Array(0.05814643, dtype=float64),
#  Array(2.30423543, dtype=float64),
#  Array(3.11538841, dtype=float64),
#  Array(3.12328946, dtype=float64),
#  Array(0.00076317, dtype=float64),
#  Array(0.2305952, dtype=float64),
#  Array(0.970002, dtype=float64),
#  Array(6.05422976, dtype=float64),
#  Array(9.07555804, dtype=float64),
#  Array(22.58189394, dtype=float64),
#  Array(13.56305355, dtype=float64),
#  Array(8.84054134, dtype=float64),
#  Array(13.34382324, dtype=float64),
#  Array(18.74506926, dtype=float64),
#  Array(23.77750221, dtype=float64),
#  Array(26.41235605, dtype=float64),
#  Array(18.69557801, dtype=float64),
#  Array(29.71991868, dtype=float64),
#  Array(45.16481168, dtype=float64),
#  Array(45.16481168, dtype=float64),
#  Array(35.70611497, dtype=float64),
#  Array(40.65041024, dtype=float64),
#  Array(27.83764626, dtype=float64),
#  Array(31.35160944, dtype=float64),
#  Array(30.9012345, dtype=float64),
#  Array(22.21373253, dtype=float64),
#  Array(17.51182885, dtype=float64),
#  Array(17.51182885, dtype=float64),
#  Array(26.37520806, dtype=float64),
#  Array(26.37520806, dtype=float64),
#  Array(26.37520806, dtype=float64),
#  Array(45.18873091, dtype=float64),
#  Array(70.06742436, dtype=float64),
#  Array(56.82504805, dtype=float64),
#  Array(68.63852515, dtype=float64),
#  Array(56.87850938, dtype=float64),
#  Array(56.87850938, dtype=float64),
#  Array(63.4195189, dtype=float64),
#  Array(38.50112034, dtype=float64),
#  Array(30.5091924, dtype=float64),
#  Array(40.09106646, dtype=float64),
#  Array(36.27744944, dtype=float64),
#  Array(37.80563656, dtype=float64),
#  Array(37.80563656, dtype=float64),
#  Array(37.80563656, dtype=float64),
#  Array(35.77893585, dtype=float64),
#  Array(35.77893585, dtype=float64),
#  Array(35.77893585, dtype=float64),
#  Array(29.47806935, dtype=float64),
#  Array(29.47806935, dtype=float64),
#  Array(43.63468142, dtype=float64),
#  Array(55.03906056, dtype=float64),
#  Array(64.75079399, dtype=float64),
#  Array(70.72205999, dtype=float64),
#  Array(70.72205999, dtype=float64),
#  Array(70.72205999, dtype=float64),
#  Array(70.72205999, dtype=float64),
#  Array(70.72205999, dtype=float64),
#  Array(64.47539184, dtype=float64),
#  Array(60.77321011, dtype=float64),
#  Array(64.173795, dtype=float64),
#  Array(54.17505524, dtype=float64),
#  Array(44.59557109, dtype=float64),
#  Array(44.59557109, dtype=float64),
#  Array(37.516321, dtype=float64),
#  Array(51.32117846, dtype=float64),
#  Array(33.77551942, dtype=float64),
#  Array(27.41079683, dtype=float64),
#  Array(24.92702812, dtype=float64),
#  Array(29.74573144, dtype=float64),
#  Array(28.22036517, dtype=float64),
#  Array(35.12899779, dtype=float64),
#  Array(48.4595384, dtype=float64),
#  Array(61.14167758, dtype=float64),
#  Array(47.56815809, dtype=float64),
#  Array(40.21991303, dtype=float64),
#  Array(52.82574147, dtype=float64),
#  Array(50.64126536, dtype=float64),
#  Array(52.95909661, dtype=float64),
#  Array(52.95909661, dtype=float64),
#  Array(46.90421053, dtype=float64),
#  Array(48.78480356, dtype=float64),
#  Array(64.85690264, dtype=float64),
#  Array(43.50040875, dtype=float64),
#  Array(48.44268857, dtype=float64),
#  Array(33.34661477, dtype=float64),
#  Array(54.35114671, dtype=float64),
#  Array(17.476014, dtype=float64),
#  Array(23.60284181, dtype=float64),
#  Array(17.80691789, dtype=float64),
#  Array(17.70762259, dtype=float64),
#  Array(26.67115333, dtype=float64),
#  Array(24.77968769, dtype=float64),
#  Array(34.13933402, dtype=float64),
#  Array(21.16248481, dtype=float64),
#  Array(39.46092881, dtype=float64),
#  Array(43.19065021, dtype=float64),
#  Array(63.0820109, dtype=float64),
#  Array(37.65357594, dtype=float64),
#  Array(44.08710514, dtype=float64),
#  Array(33.6834688, dtype=float64),
#  Array(43.53265689, dtype=float64),
#  Array(43.53265689, dtype=float64),
#  Array(54.83617029, dtype=float64),
#  Array(48.34220011, dtype=float64),
#  Array(59.98846463, dtype=float64),
#  Array(42.48565531, dtype=float64),
#  Array(33.53524347, dtype=float64),
#  Array(33.53524347, dtype=float64),
#  Array(33.53524347, dtype=float64),
#  Array(32.88565949, dtype=float64),
#  Array(20.20966271, dtype=float64),
#  Array(19.87258345, dtype=float64),
#  Array(15.70124273, dtype=float64),
#  Array(29.21892267, dtype=float64),
#  Array(29.21892267, dtype=float64),
#  Array(33.48206397, dtype=float64),
#  Array(14.92072024, dtype=float64),
#  Array(12.26741287, dtype=float64),
#  Array(16.12590728, dtype=float64),
#  Array(13.13102918, dtype=float64),
#  Array(14.93631045, dtype=float64),
#  Array(23.33425329, dtype=float64),
#  Array(38.05956469, dtype=float64),
#  Array(21.86635455, dtype=float64),
#  Array(10.69371147, dtype=float64),
#  Array(15.13450773, dtype=float64),
#  Array(11.64088368, dtype=float64),
#  Array(12.95711804, dtype=float64),
#  Array(9.80623006, dtype=float64),
#  Array(11.36121996, dtype=float64),
#  Array(13.76115362, dtype=float64),
#  Array(11.26049524, dtype=float64),
#  Array(13.89857179, dtype=float64),
#  Array(5.43358433, dtype=float64),
#  Array(9.97009526, dtype=float64),
#  Array(3.59330725, dtype=float64),
#  Array(6.56605797, dtype=float64),
#  Array(6.56605797, dtype=float64),
#  Array(12.35907951, dtype=float64),
#  Array(17.1408452, dtype=float64),
#  Array(9.48334229, dtype=float64),
#  Array(8.54565053, dtype=float64),
#  Array(8.54565053, dtype=float64),
#  Array(6.60236193, dtype=float64),
#  Array(3.68554965, dtype=float64),
#  Array(6.84211152, dtype=float64),
#  Array(5.58491947, dtype=float64),
#  Array(0.08396862, dtype=float64),
#  Array(0.47712557, dtype=float64),
#  Array(1.53408245, dtype=float64),
#  Array(1.71186188, dtype=float64),
#  Array(2.20293818, dtype=float64),
#  Array(5.56203428, dtype=float64),
#  Array(8.23979261, dtype=float64),
#  Array(6.46442072, dtype=float64),
#  Array(11.68468329, dtype=float64),
#  Array(8.95257598, dtype=float64),
#  Array(8.95257598, dtype=float64),
#  Array(21.54874063, dtype=float64),
#  Array(22.35780562, dtype=float64),
#  Array(24.68590795, dtype=float64),
#  Array(13.980986, dtype=float64),
#  Array(18.98069546, dtype=float64),
#  Array(7.45223606, dtype=float64),
#  Array(8.35766806, dtype=float64),
#  Array(4.02368432, dtype=float64),
#  Array(19.95277938, dtype=float64),
#  Array(32.25546314, dtype=float64),
#  Array(32.25546314, dtype=float64),
#  Array(30.49638271, dtype=float64),
#  Array(30.49638271, dtype=float64),
#  Array(24.72616904, dtype=float64),
#  Array(16.02422638, dtype=float64),
#  Array(10.10158779, dtype=float64),
#  Array(9.27673782, dtype=float64),
#  Array(5.8871913, dtype=float64),
#  Array(3.77128035, dtype=float64),
#  Array(3.27737387, dtype=float64),
#  Array(10.69700399, dtype=float64),
#  Array(10.69700399, dtype=float64),
#  Array(10.69700399, dtype=float64),
#  Array(7.88827491, dtype=float64),
#  Array(7.88827491, dtype=float64),
#  Array(14.35194451, dtype=float64),
#  Array(31.01630147, dtype=float64),
#  Array(28.0650278, dtype=float64),
#  Array(44.03702818, dtype=float64),
#  Array(25.96711, dtype=float64),
#  Array(27.34647547, dtype=float64),
#  Array(24.12087197, dtype=float64),
#  Array(34.04191182, dtype=float64),
#  Array(36.30402176, dtype=float64),
#  Array(46.50494649, dtype=float64),
#  Array(48.31274442, dtype=float64),
#  Array(47.24849883, dtype=float64),
#  Array(49.65134672, dtype=float64),
#  Array(42.36588251, dtype=float64),
#  Array(48.88847737, dtype=float64),
#  Array(30.82417064, dtype=float64),
#  Array(40.52621695, dtype=float64),
#  Array(27.76429059, dtype=float64),
#  Array(16.04030645, dtype=float64),
#  Array(25.23742549, dtype=float64),
#  Array(25.23742549, dtype=float64),
#  Array(14.50509418, dtype=float64),
#  Array(14.50509418, dtype=float64),
#  Array(15.86497468, dtype=float64),
#  Array(17.52123191, dtype=float64),
#  Array(17.52123191, dtype=float64),
#  Array(24.99193103, dtype=float64),
#  Array(27.05015496, dtype=float64),
#  Array(23.46220261, dtype=float64),
#  Array(23.46220261, dtype=float64),
#  Array(23.44249036, dtype=float64),
#  Array(28.79938465, dtype=float64),
#  Array(27.7344968, dtype=float64),
#  Array(27.7344968, dtype=float64),
#  Array(10.22909616, dtype=float64),
#  Array(21.41759611, dtype=float64),
#  Array(10.12138459, dtype=float64),
#  Array(5.94033451, dtype=float64),
#  Array(13.21802801, dtype=float64),
#  Array(17.5695564, dtype=float64),
#  Array(33.68556869, dtype=float64),
#  Array(30.83971213, dtype=float64),
#  Array(42.4873651, dtype=float64),
#  Array(34.94842893, dtype=float64),
#  Array(34.94842893, dtype=float64),
#  Array(31.7058387, dtype=float64),
#  Array(49.11031532, dtype=float64),
#  Array(54.92481394, dtype=float64),
#  Array(43.96095588, dtype=float64),
#  Array(32.80494984, dtype=float64),
#  Array(25.26919325, dtype=float64),
#  Array(21.29199579, dtype=float64),
#  Array(11.60243635, dtype=float64),
#  Array(17.87500139, dtype=float64),
#  Array(16.19732186, dtype=float64),
#  Array(19.08942061, dtype=float64),
#  Array(18.07943698, dtype=float64),
#  Array(22.62584762, dtype=float64),
#  Array(21.34686133, dtype=float64),
#  Array(8.32881565, dtype=float64),
#  Array(8.32881565, dtype=float64),
#  Array(8.32881565, dtype=float64),
#  Array(10.42447214, dtype=float64),
#  Array(2.89665338, dtype=float64),
#  Array(2.26960606, dtype=float64),
#  Array(0.78167208, dtype=float64),
#  Array(5.14465503, dtype=float64),
#  Array(4.69690093, dtype=float64),
#  Array(13.55783788, dtype=float64),
#  Array(11.15706511, dtype=float64),
#  Array(6.07721211, dtype=float64),
#  Array(5.27851999, dtype=float64),
#  Array(1.39037228, dtype=float64),
#  Array(1.16025842, dtype=float64),
#  Array(1.35897444, dtype=float64),
#  Array(4.31015167, dtype=float64),
#  Array(2.13267418, dtype=float64),
#  Array(0.8988826, dtype=float64),
#  Array(0.01529616, dtype=float64),
#  Array(0.01529616, dtype=float64),
#  Array(2.2372122, dtype=float64),
#  Array(5.35969572, dtype=float64),
#  Array(5.6669496, dtype=float64),
#  Array(3.14118291, dtype=float64),
#  Array(7.45656788, dtype=float64),
#  Array(0.60530925, dtype=float64),
#  Array(2.7826283, dtype=float64),
#  Array(1.16360658, dtype=float64),
#  Array(1.75500144, dtype=float64),
#  Array(5.77121702, dtype=float64),
#  Array(6.2612232, dtype=float64),
#  Array(9.94940794, dtype=float64),
#  Array(5.61875297, dtype=float64),
#  Array(6.34102902, dtype=float64),
#  Array(13.71869531, dtype=float64),
#  Array(14.53503445, dtype=float64),
#  Array(22.51148574, dtype=float64),
#  Array(23.44219267, dtype=float64),
#  Array(37.87323256, dtype=float64),
#  Array(16.03623644, dtype=float64),
#  Array(25.3589538, dtype=float64),
#  Array(16.3195116, dtype=float64),
#  Array(9.92562414, dtype=float64),
#  Array(4.13504336, dtype=float64),
#  Array(0.55122752, dtype=float64),
#  Array(0.02909543, dtype=float64),
#  Array(0.00014451, dtype=float64),
#  Array(0.05472431, dtype=float64),
#  Array(0.89322575, dtype=float64),
#  Array(0.2724625, dtype=float64),
#  Array(1.32967448, dtype=float64),
#  Array(0.30942571, dtype=float64),
#  Array(1.11029763, dtype=float64),
#  Array(1.11555019, dtype=float64),
#  Array(1.11555019, dtype=float64),
#  Array(1.35122733, dtype=float64),
#  Array(1.49871781, dtype=float64),
#  Array(5.4031274, dtype=float64),
#  Array(5.4031274, dtype=float64),
#  Array(10.58176937, dtype=float64),
#  Array(13.97775909, dtype=float64),
#  Array(11.98794956, dtype=float64),
#  Array(22.03474381, dtype=float64),
#  Array(22.03474381, dtype=float64),
#  Array(14.71889222, dtype=float64),
#  Array(15.39234514, dtype=float64),
#  Array(15.39234514, dtype=float64),
#  Array(12.75742268, dtype=float64),
#  Array(6.60203562, dtype=float64),
#  Array(0.0015715, dtype=float64),
#  Array(1.58328324, dtype=float64),
#  Array(2.57548926, dtype=float64),
#  Array(1.12326829, dtype=float64),
#  Array(3.08881233, dtype=float64),
#  Array(2.00865007, dtype=float64),
#  Array(1.96634651, dtype=float64),
#  Array(1.03644803, dtype=float64),
#  Array(0.99266639, dtype=float64),
#  Array(4.60349119, dtype=float64),
#  Array(3.01989551, dtype=float64),
#  Array(1.57234341, dtype=float64),
#  Array(0.04643051, dtype=float64),
#  Array(0.10243727, dtype=float64),
#  Array(0.0013146, dtype=float64),
#  Array(0.0013146, dtype=float64),
#  Array(0.0013146, dtype=float64),
#  Array(0.42779154, dtype=float64),
#  Array(3.33909045, dtype=float64),
#  Array(6.95915101, dtype=float64),
#  Array(4.52877732, dtype=float64),
#  Array(5.02736364, dtype=float64),
#  Array(5.02736364, dtype=float64),
#  Array(2.35502821, dtype=float64),
#  Array(3.01882536, dtype=float64),
#  Array(3.01882536, dtype=float64),
#  Array(2.56660884, dtype=float64),
#  Array(1.08256712, dtype=float64),
#  Array(5.10555385, dtype=float64),
#  Array(4.51503392, dtype=float64),
#  Array(3.33530531, dtype=float64),
#  Array(1.24322607, dtype=float64),
#  Array(1.0002264, dtype=float64),
#  Array(1.83077426, dtype=float64),
#  Array(0.43133506, dtype=float64),
#  Array(0.72270135, dtype=float64),
#  Array(0.72270135, dtype=float64),
#  Array(0.72270135, dtype=float64),
#  Array(1.9867729, dtype=float64),
#  Array(0.00048438, dtype=float64),
#  Array(0.03319973, dtype=float64),
#  Array(0.00056741, dtype=float64),
#  Array(0.67676358, dtype=float64),
#  Array(2.77422195, dtype=float64),
#  Array(7.02732476, dtype=float64),
#  Array(14.63739939, dtype=float64),
#  Array(17.54892694, dtype=float64),
#  Array(8.20187841, dtype=float64),
#  Array(8.20187841, dtype=float64),
#  Array(9.57384042, dtype=float64),
#  Array(19.95669995, dtype=float64),
#  Array(37.29333315, dtype=float64),
#  Array(28.32735533, dtype=float64),
#  Array(29.09930613, dtype=float64),
#  Array(42.6654522, dtype=float64),
#  Array(45.91570811, dtype=float64),
#  Array(31.44945159, dtype=float64),
#  Array(34.95873882, dtype=float64),
#  Array(30.53986332, dtype=float64),
#  Array(25.77619837, dtype=float64),
#  Array(47.66687812, dtype=float64),
#  Array(37.10519478, dtype=float64),
#  Array(41.52675618, dtype=float64),
#  Array(41.43338246, dtype=float64),
#  Array(61.60341062, dtype=float64),
#  Array(67.74240962, dtype=float64),
#  Array(41.90083676, dtype=float64),
#  Array(35.19095061, dtype=float64),
#  Array(59.78233433, dtype=float64),
#  Array(43.64739394, dtype=float64),
#  Array(41.84911934, dtype=float64),
#  Array(48.00336296, dtype=float64),
#  Array(27.99550707, dtype=float64),
#  Array(37.07829882, dtype=float64),
#  Array(32.8807306, dtype=float64),
#  Array(27.35574313, dtype=float64),
#  Array(43.77225804, dtype=float64),
#  Array(31.48750475, dtype=float64),
#  Array(33.59687028, dtype=float64),
#  Array(26.30327774, dtype=float64),
#  Array(26.29303312, dtype=float64),
#  Array(25.88483372, dtype=float64),
#  Array(25.62509187, dtype=float64),
#  Array(15.45868748, dtype=float64),
#  Array(22.63792827, dtype=float64),
#  Array(30.0586843, dtype=float64),
#  Array(23.66073766, dtype=float64),
#  Array(26.78431288, dtype=float64),
#  Array(47.19633599, dtype=float64),
#  Array(47.19633599, dtype=float64),
#  Array(37.97461042, dtype=float64),
#  Array(37.97461042, dtype=float64),
#  Array(51.34521574, dtype=float64),
#  Array(67.79422992, dtype=float64),
#  Array(67.79422992, dtype=float64),
#  Array(79.73256097, dtype=float64),
#  Array(64.04631397, dtype=float64),
#  Array(74.03649112, dtype=float64),
#  Array(63.51854285, dtype=float64),
#  Array(83.77771528, dtype=float64),
#  Array(65.91409039, dtype=float64),
#  Array(82.6721702, dtype=float64),
#  Array(81.8499507, dtype=float64),
#  Array(81.8499507, dtype=float64),
#  Array(81.8499507, dtype=float64),
#  Array(71.51102877, dtype=float64),
#  Array(71.51102877, dtype=float64),
#  Array(75.6739074, dtype=float64),
#  Array(89.59086551, dtype=float64),
#  Array(71.34389824, dtype=float64),
#  Array(58.33002795, dtype=float64),
#  Array(50.95347281, dtype=float64),
#  Array(45.20274842, dtype=float64),
#  Array(39.91426753, dtype=float64),
#  Array(26.35276679, dtype=float64),
#  Array(26.86451073, dtype=float64),
#  Array(7.94973609, dtype=float64),
#  Array(10.95437948, dtype=float64),
#  Array(15.7340129, dtype=float64),
#  Array(18.87154738, dtype=float64),
#  Array(15.27135707, dtype=float64),
#  Array(12.8788834, dtype=float64),
#  Array(12.13198693, dtype=float64),
#  Array(12.13198693, dtype=float64),
#  Array(12.13198693, dtype=float64),
#  Array(9.94561895, dtype=float64),
#  Array(12.32875175, dtype=float64),
#  Array(18.74213468, dtype=float64),
#  Array(31.87969935, dtype=float64),
#  Array(19.98214582, dtype=float64),
#  Array(29.52309697, dtype=float64),
#  Array(27.69635388, dtype=float64),
#  Array(28.5111864, dtype=float64),
#  Array(28.5111864, dtype=float64),
#  Array(28.5111864, dtype=float64),
#  Array(33.37624318, dtype=float64),
#  Array(23.38153606, dtype=float64),
#  Array(26.84688117, dtype=float64),
#  Array(21.67421883, dtype=float64),
#  Array(16.39340726, dtype=float64),
#  Array(10.86138692, dtype=float64),
#  Array(18.20955414, dtype=float64),
#  Array(12.90296802, dtype=float64),
#  Array(22.96510653, dtype=float64),
#  Array(33.8797133, dtype=float64),
#  Array(33.98894118, dtype=float64),
#  Array(33.98894118, dtype=float64),
#  Array(18.82174237, dtype=float64),
#  Array(21.85806122, dtype=float64),
#  Array(27.42449067, dtype=float64),
#  Array(25.57161599, dtype=float64),
#  Array(20.4997669, dtype=float64),
#  Array(23.37395555, dtype=float64),
#  Array(19.77348097, dtype=float64),
#  Array(10.53799736, dtype=float64),
#  Array(20.14053739, dtype=float64),
#  Array(13.07784772, dtype=float64),
#  Array(15.54689792, dtype=float64),
#  Array(7.28650197, dtype=float64),
#  Array(9.49255174, dtype=float64),
#  Array(12.3964417, dtype=float64),
#  Array(16.58670721, dtype=float64),
#  Array(16.58670721, dtype=float64),
#  Array(9.98424411, dtype=float64),
#  Array(21.49385556, dtype=float64),
#  Array(13.88043652, dtype=float64),
#  Array(16.54066161, dtype=float64),
#  Array(21.90978864, dtype=float64),
#  Array(26.4538691, dtype=float64),
#  Array(37.04352006, dtype=float64),
#  Array(26.1731431, dtype=float64),
#  Array(39.27440128, dtype=float64),
#  Array(26.33074949, dtype=float64),
#  Array(17.26053741, dtype=float64),
#  Array(17.26053741, dtype=float64),
#  Array(7.8443059, dtype=float64),
#  Array(17.48847246, dtype=float64),
#  Array(8.08067098, dtype=float64),
#  Array(8.08067098, dtype=float64),
#  Array(8.88624947, dtype=float64),
#  Array(17.76035136, dtype=float64),
#  Array(17.76035136, dtype=float64),
#  Array(17.76035136, dtype=float64),
#  Array(16.24657245, dtype=float64),
#  Array(18.54441005, dtype=float64),
#  Array(22.31088655, dtype=float64),
#  Array(16.18441071, dtype=float64),
#  Array(17.22560352, dtype=float64),
#  Array(34.92903942, dtype=float64),
#  Array(18.00254907, dtype=float64),
#  Array(10.32414975, dtype=float64),
#  Array(15.64511852, dtype=float64),
#  Array(7.21113274, dtype=float64),
#  Array(18.07182551, dtype=float64),
#  Array(8.39870299, dtype=float64),
#  Array(9.55578831, dtype=float64),
#  Array(10.2481716, dtype=float64),
#  Array(6.62861281, dtype=float64),
#  Array(7.21127163, dtype=float64),
#  Array(2.88617831, dtype=float64),
#  Array(0.46045507, dtype=float64),
#  Array(0.40816088, dtype=float64),
#  Array(0.49210344, dtype=float64),
#  Array(1.53797415, dtype=float64),
#  Array(0.49929284, dtype=float64),
#  Array(2.04583038, dtype=float64),
#  Array(3.96391836, dtype=float64),
#  Array(5.57325651, dtype=float64),
#  Array(5.57325651, dtype=float64),
#  Array(5.57325651, dtype=float64),
#  Array(7.63429482, dtype=float64),
#  Array(3.032867, dtype=float64),
#  Array(3.41534652, dtype=float64),
#  Array(7.20645475, dtype=float64),
#  Array(6.03886306, dtype=float64),
#  Array(6.03886306, dtype=float64),
#  Array(12.27435137, dtype=float64),
#  Array(20.30805126, dtype=float64),
#  Array(11.11014845, dtype=float64),
#  Array(2.57538532, dtype=float64),
#  Array(4.57321676, dtype=float64),
#  Array(3.81322741, dtype=float64),
#  Array(2.78386403, dtype=float64),
#  Array(22.78891479, dtype=float64),
#  Array(24.73258215, dtype=float64),
#  Array(19.79244346, dtype=float64),
#  Array(28.96619074, dtype=float64),
#  Array(24.66420983, dtype=float64),
#  Array(27.28941623, dtype=float64),
#  Array(33.81291432, dtype=float64),
#  Array(42.46775008, dtype=float64),
#  Array(42.46775008, dtype=float64),
#  Array(28.89218753, dtype=float64),
#  Array(21.78436285, dtype=float64),
#  Array(25.08032152, dtype=float64),
#  Array(36.16391254, dtype=float64),
#  Array(34.14991739, dtype=float64),
#  Array(34.14991739, dtype=float64),
#  Array(39.59375745, dtype=float64),
#  Array(35.56583073, dtype=float64),
#  Array(31.354565, dtype=float64),
#  Array(47.57076082, dtype=float64),
#  Array(53.00693975, dtype=float64),
#  Array(56.7820738, dtype=float64),
#  Array(50.54637709, dtype=float64),
#  Array(24.9386444, dtype=float64),
#  Array(25.84540049, dtype=float64),
#  Array(47.81949945, dtype=float64),
#  Array(39.21097046, dtype=float64),
#  Array(26.32733859, dtype=float64),
#  Array(26.9674542, dtype=float64),
#  Array(17.47727503, dtype=float64),
#  Array(20.94246806, dtype=float64),
#  Array(24.76711258, dtype=float64),
#  Array(27.6136035, dtype=float64),
#  Array(31.70285321, dtype=float64),
#  Array(32.91583742, dtype=float64),
#  Array(44.17196325, dtype=float64),
#  Array(48.15458348, dtype=float64),
#  Array(56.37341447, dtype=float64),
#  Array(35.65817997, dtype=float64),
#  Array(47.21758962, dtype=float64),
#  Array(43.36811179, dtype=float64),
#  Array(43.81774662, dtype=float64),
#  Array(52.90165548, dtype=float64),
#  Array(52.90165548, dtype=float64),
#  Array(47.86295703, dtype=float64),
#  Array(44.19302687, dtype=float64),
#  Array(55.03479007, dtype=float64),
#  Array(57.80455056, dtype=float64),
#  Array(50.97644273, dtype=float64),
#  Array(45.63284342, dtype=float64),
#  Array(49.9045272, dtype=float64),
#  Array(47.4717823, dtype=float64),
#  Array(53.68984246, dtype=float64),
#  Array(60.81459432, dtype=float64),
#  Array(31.75688257, dtype=float64),
#  Array(45.8049012, dtype=float64),
#  Array(48.86630366, dtype=float64),
#  Array(52.95227053, dtype=float64),
#  Array(52.95227053, dtype=float64),
#  Array(52.27223121, dtype=float64),
#  Array(67.73182946, dtype=float64),
#  Array(67.73182946, dtype=float64),
#  Array(58.84324278, dtype=float64),
#  Array(56.45190719, dtype=float64),
#  Array(69.46362842, dtype=float64),
#  Array(77.04069113, dtype=float64),
#  Array(87.16662383, dtype=float64),
#  Array(100.35179869, dtype=float64),
#  Array(79.28926902, dtype=float64),
#  Array(79.28926902, dtype=float64),
#  Array(79.28926902, dtype=float64),
#  Array(102.23328611, dtype=float64),
#  Array(88.51792002, dtype=float64),
#  Array(100.23321174, dtype=float64),
#  Array(91.83343434, dtype=float64),
#  Array(94.59923123, dtype=float64),
#  Array(109.74865399, dtype=float64),
#  Array(72.32216358, dtype=float64),
#  Array(71.72220756, dtype=float64),
#  Array(42.42740615, dtype=float64),
#  Array(68.88555725, dtype=float64),
#  Array(81.33317679, dtype=float64),
#  Array(75.8147468, dtype=float64),
#  Array(75.8147468, dtype=float64),
#  Array(78.83648173, dtype=float64),
#  Array(57.82669035, dtype=float64),
#  Array(79.47980758, dtype=float64),
#  Array(57.3395778, dtype=float64),
#  Array(56.1412178, dtype=float64),
#  Array(53.40329758, dtype=float64),
#  Array(52.78310361, dtype=float64),
#  Array(52.78310361, dtype=float64),
#  Array(56.21671372, dtype=float64),
#  Array(67.23360749, dtype=float64),
#  Array(67.23360749, dtype=float64),
#  Array(61.59760303, dtype=float64),
#  Array(54.433201, dtype=float64),
#  Array(39.87216646, dtype=float64),
#  Array(47.09549524, dtype=float64),
#  Array(48.04794794, dtype=float64),
#  ...]

# %%
mu, Ns = np.mean(m2), len(m2)
print(mu, Ns)
print(len(m2))

def Gamma(t):
    C1 = m2 - mu
    C2 = np.roll(m2, t) - mu
    return gv.dataset.avg_data(C1[:Ns-t] * C2[:Ns-t] / (Ns - t))

# %timeit Gamma(800)
# Out:
# 33.0806971937291 100000
# 100000
# 605 ms ± 3.31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
600*800/1000/60
# Out:
# 8.0

# %%
gam = [ Gamma(t)/Gamma(0) for t in range(0,800,10) ]
plt.errorbar(range(0,800,10), gv.mean(gam), gv.sdev(gam), ls=' ', marker='.')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def tau(W):
    return 0.5 + np.sum(gam[:W])

taus = [ tau(W) for W in range(0,60) ]
plt.errorbar(range(0,60), gv.mean(taus), gv.sdev(taus), ls=' ', marker='.', color='red')
# Out:
# <ErrorbarContainer object of 3 artists>
